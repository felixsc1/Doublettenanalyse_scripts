# %% [markdown]
# For some analyses not related to Doublettenerkennung

# %% [markdown]
# ## Setup

# %%
import pandas as pd
from helper_functions.file_io_functions import load_processed_data
import probablepeople as pp
import pickle

# %%
# Assuming the data has been processed and pickled with other Doublettenanalyse notebooks

data_dfs_sonstiges = load_processed_data(file_path="data/calculated/personen_organisationen_dfs_processed_with_sonstiges_personen.pickle")

df_personen = data_dfs_sonstiges["personen"]

# %% [markdown]
# Reminder: Name column should always be FIRSTNAME + LASTNAME, not the other way around

# %%
df_personen["Name_original"]
# Out:
# 0         Karim Fassatoui
# 1            Simon Kramis
# 2          Patrick Leplat
# 3           Joerg Schwarz
# 4           Patrick Storz
#                ...
# 38853     David Deslarzes
# 38854         Ivan Schmid
# 38855      Mustafa Tuskan
# 38856       Mathieu Raoux
# 38857    Eric Freienstein
# Name: Name_original, Length: 38858, dtype: object

# %% [markdown]
# Probablepeople library:  produces a lot of false positives. Seems confused when names have more than two words

# %%
def check_name_order(name):
    try:
        parsed_name = pp.parse(name)
        print(f"Parsed name: {parsed_name}")  # Debug print
        
        # Check if any part is tagged as GivenName or FirstInitial
        has_given_name = any(tag.startswith('GivenName') or tag == 'FirstInitial' for _, tag in parsed_name)
        
        # Check if any part is tagged as Surname
        has_surname = any(tag == 'Surname' for _, tag in parsed_name)
        
        # If we have both, check their order
        if has_given_name and has_surname:
            given_name_index = next((i for i, (_, tag) in enumerate(parsed_name) if tag.startswith('GivenName') or tag == 'FirstInitial'), -1)
            surname_index = next((i for i, (_, tag) in enumerate(parsed_name) if tag == 'Surname'), -1)
            
            if given_name_index != -1 and surname_index != -1:
                return surname_index < given_name_index  # Incorrect if surname comes before given name
        
        # If we don't have both or can't determine order, assume it's correct
        return False
    except pp.RepeatedLabelError:
        print(f"Warning: Couldn't parse name '{name}'")
        return False


# Apply the function to the first few rows for testing
# for name in df_personen['Name_original'].head(10):
#     result = check_name_order(name)
#     print(f"Name: {name}, Incorrect: {result}")
    
    
df_personen['Name_incorrect'] = df_personen['Name_original'].apply(check_name_order)

# print(df_personen[['Name_original', 'Name_incorrect']].head(10))
print("\nTotal incorrect names:", df_personen['Name_incorrect'].sum())
# Out:
# Parsed name: [('Karim', 'CorporationName'), ('Fassatoui', 'CorporationName')]
# Parsed name: [('Simon', 'GivenName'), ('Kramis', 'Surname')]
# Parsed name: [('Patrick', 'GivenName'), ('Leplat', 'Surname')]
# Parsed name: [('Joerg', 'CorporationName'), ('Schwarz', 'CorporationName')]
# Parsed name: [('Patrick', 'GivenName'), ('Storz', 'Surname')]
# Parsed name: [('johann', 'GivenName'), ('Frain', 'Surname')]
# Parsed name: [('Pedro', 'GivenName'), ('Dias', 'Surname')]
# Parsed name: [('Paolo', 'GivenName'), ('Ferrara', 'Surname')]
# Parsed name: [('Tobias', 'GivenName'), ('Bichsel', 'Surname')]
# Parsed name: [('Valentin', 'GivenName'), ('Wepfer', 'Surname')]
# Parsed name: [('Florian', 'GivenName'), ('Vollmer', 'Surname')]
# Parsed name: [('Loris', 'GivenName'), ('Bernardini', 'Surname')]
# Parsed name: [('Lorenzo', 'GivenName'), ('De', 'Surname'), ('Pietri', 'Surname')]
# Parsed name: [('Bruno', 'GivenName'), ('Dietrich', 'Surname')]
# Parsed name: [('Fabian', 'GivenName'), ('Schafflützel', 'Surname')]
# Parsed name: [('Roger', 'GivenName'), ('Geser', 'Surname')]
# Parsed name: [('KENNETH', 'CorporationName'), ('COSTANTINO', 'CorporationName')]
# Parsed name: [('Mirco', 'GivenName'), ('Beerli', 'Surname')]
# Parsed name: [('Luca', 'GivenName'), ('Tagli', 'Surname')]
# Parsed name: [('Jürg', 'GivenName'), ('Rietmann', 'Surname')]
# Parsed name: [('Corinne', 'GivenName'), ('Pfister', 'Surname')]
# Parsed name: [('Markus', 'GivenName'), ('Keller', 'Surname')]
# Parsed name: [('Marco', 'GivenName'), ('Furrer', 'Surname')]
# Parsed name: [('Andreas', 'GivenName'), ('Grüner', 'Surname')]
# Parsed name: [('Sabine', 'GivenName'), ('Schuitemaker', 'Surname')]
# Parsed name: [('Rada', 'GivenName'), ('Boskovic', 'Surname')]
# Parsed name: [('Christelle', 'CorporationName'), ('Marclay', 'CorporationName')]
# Parsed name: [('bernd', 'GivenName'), ('wagner', 'Surname')]
# Parsed name: [('Nicole', 'GivenName'), ('Dechev', 'Surname')]
# Parsed name: [('Anne-Marie', 'GivenName'), ('Dubuis', 'Surname')]
# Parsed name: [('Aida', 'GivenName'), ('Morelli', 'Surname')]
# Parsed name: [('Martin', 'GivenName'), ('Haller', 'Surname')]
# Parsed name: [('Michael', 'GivenName'), ('Schirling', 'Surname')]
# Parsed name: [('Marco', 'GivenName'), ('Villiger', 'Surname')]
# Parsed name: [('Marc', 'GivenName'), ('Storck', 'Surname')]
# Parsed name: [('Walter', 'GivenName'), ('Greter', 'Surname')]
# Parsed name: [('Manuela', 'GivenName'), ('daSilva', 'Surname')]
# Parsed name: [('Claude', 'GivenName'), ('Talaber', 'Surname')]
# Parsed name: [('Erradi', 'CorporationName'), ('El', 'CorporationName'), ('Khattab', 'CorporationName')]
# Parsed name: [('Jörg', 'GivenName'), ('Becker', 'Surname')]
# Parsed name: [('Andre', 'GivenName'), ('Hagen', 'Surname')]
# Parsed name: [('Santana', 'CorporationName'), ('Fonseca', 'CorporationName'), ('Mathieu', 'CorporationName'), ('Marineide', 'CorporationName')]
# Parsed name: [('Rainer', 'GivenName'), ('Többicke', 'Surname')]
# Parsed name: [('Jean-Robert', 'GivenName'), ('Oppliger', 'Surname')]
# Parsed name: [('Jeroen', 'GivenName'), ('Hermans', 'Surname')]
# Parsed name: [('Leander', 'GivenName'), ('Schüpfer', 'Surname')]
# Parsed name: [('Nico', 'GivenName'), ('Zehnder', 'Surname')]
# Parsed name: [('Christof', 'GivenName'), ('Moser', 'Surname')]
# Parsed name: [('Andrea', 'GivenName'), ('Plieninger', 'Surname')]
# Parsed name: [('Gabriele', 'GivenName'), ('Da', 'Surname'), ('Tos', 'SuffixOther')]
# Parsed name: [('Marc', 'GivenName'), ('Grosjean', 'Surname')]
# Parsed name: [('Boris', 'GivenName'), ('Rapp', 'Surname')]
# Parsed name: [('Eduard', 'CorporationName'), ('Blenkers', 'CorporationName')]
# Parsed name: [('Doris', 'GivenName'), ('Aebi', 'Surname')]
# Parsed name: [('Carole', 'GivenName'), ('Croset', 'Surname')]
# Parsed name: [('Ferenc', 'GivenName'), ('Hosszu', 'Surname')]
# Parsed name: [('Robert', 'GivenName'), ('de', 'Surname'), ('Boer', 'Surname')]
# Parsed name: [('Peter', 'GivenName'), ('Sterk', 'Surname')]
# Parsed name: [('Laurent', 'GivenName'), ('Ducasse', 'Surname')]
# Parsed name: [('Felix', 'GivenName'), ('Weber', 'Surname')]
# Parsed name: [('Janosch', 'GivenName'), ('Nikolic', 'Surname')]
# Parsed name: [('Marc', 'GivenName'), ('Nagel', 'Surname')]
# Parsed name: [('André', 'GivenName'), ('Stoller', 'Surname')]
# Parsed name: [('arlo', 'GivenName'), ('gonser', 'Surname')]
# Parsed name: [('Raphael', 'GivenName'), ('lutz', 'Surname')]
# Parsed name: [('Cetin', 'GivenName'), ('Alpan', 'Surname')]
# Parsed name: [('Lukas', 'GivenName'), ('Häfliger', 'Surname')]
# Parsed name: [('Arben', 'GivenName'), ('Himaj', 'Surname')]
# Parsed name: [('Christoph', 'GivenName'), ('Kohler', 'Surname')]
# Parsed name: [('Patrick', 'GivenName'), ('Meylan', 'Surname')]
# Parsed name: [('Graziella', 'GivenName'), ('Chakroun-Ciglie', 'Surname')]
# Parsed name: [('Anton', 'GivenName'), ('Wanner', 'Surname')]
# Parsed name: [('Christoph', 'GivenName'), ('Helbling', 'Surname')]
# Parsed name: [('Stefan', 'GivenName'), ('Sterchi', 'Surname')]
# Parsed name: [('Florentina', 'GivenName'), ('Heer', 'Surname')]
# Parsed name: [('Redha', 'GivenName'), ('Houari', 'Surname')]
# Parsed name: [('Aude', 'GivenName'), ('Girod', 'Surname')]
# Parsed name: [('Krenar', 'GivenName'), ('Kuci', 'Surname')]
# Parsed name: [('Raquel', 'GivenName'), ('Brea', 'Surname')]
# Parsed name: [('Anastasiia', 'GivenName'), ('Tkachova', 'Surname')]
# Parsed name: [('Ian', 'GivenName'), ('Kaltenrieder', 'Surname')]
# Parsed name: [('Christiana', 'GivenName'), ('Wild', 'Surname')]
# Parsed name: [('Patrick', 'GivenName'), ('AUCHLIN', 'Surname')]
# Parsed name: [('Eric', 'GivenName'), ('Schmalz', 'Surname')]
# Parsed name: [('Heinz', 'CorporationName'), ('Isken', 'CorporationName')]
# Parsed name: [('Hauser', 'GivenName'), ('Kanton', 'Surname')]
# Parsed name: [('Samuel', 'GivenName'), ('Meier', 'Surname')]
# Parsed name: [('Mark', 'GivenName'), ('Lammert', 'Surname')]
# Parsed name: [('Silvio', 'GivenName'), ('Kämpf', 'Surname')]
# Parsed name: [('Florian', 'GivenName'), ('Hagen', 'Surname')]
# Parsed name: [('Kareen', 'GivenName'), ('Martin', 'Surname')]
# Parsed name: [('Jochen', 'GivenName'), ('Nüchter', 'Surname')]
# Parsed name: [('Ewald', 'CorporationName'), ('Struggl', 'CorporationName')]
# Parsed name: [('Ersin', 'GivenName'), ('Rahimi', 'Surname')]
# Parsed name: [('Michael', 'GivenName'), ('Glatz', 'Surname')]
# Parsed name: [('Laura', 'GivenName'), ('Dubach', 'Surname')]
# Parsed name: [('Pauline', 'CorporationName'), ('Elisabeth', 'CorporationName'), ('Bétrisey', 'CorporationName'), ('Nanchen', 'CorporationName')]
# Parsed name: [('Joëlle', 'GivenName'), ('Egger', 'Surname')]
# Parsed name: [('Martin', 'Surname'), ('Adama', 'Surname')]
# Parsed name: [('Roger', 'GivenName'), ('Berner', 'Surname')]
# Parsed name: [('Tamara', 'GivenName'), ('Poggiolini', 'Surname')]
# Parsed name: [('Peter', 'GivenName'), ('Rubi', 'Surname')]
# Parsed name: [('Andrea', 'GivenName'), ('Kalita', 'Surname')]
# Parsed name: [('François', 'GivenName'), ('Weissmann', 'Surname')]
# Parsed name: [('Charles', 'GivenName'), ('Jaggi', 'Surname')]
# Parsed name: [('Chevalley', 'CorporationName'), ('Chevalley', 'CorporationName')]
# Parsed name: [('Isabelle', 'GivenName'), ('Voisard', 'Surname')]
# Parsed name: [('Jacqueline', 'GivenName'), ('Perriot', 'Surname')]
# Parsed name: [('Christoph', 'GivenName'), ('Studer', 'Surname')]
# Parsed name: [('Steven', 'GivenName'), ('Dobson', 'Surname')]
# Parsed name: [('Urs', 'PrefixOther'), ('Daniel', 'GivenName'), ('Schmid', 'Surname')]
# Parsed name: [('Marie-Clarie', 'CorporationName'), ('Bürgy', 'CorporationName')]
# Parsed name: [('Elena', 'GivenName'), ('Portmann', 'Surname')]
# Parsed name: [('Ramiz', 'GivenName'), ('Kastrati', 'Surname')]
# Parsed name: [('Elio', 'GivenName'), ('Benassi', 'Surname')]
# Parsed name: [('Andreas', 'GivenName'), ('Dannmeyer', 'Surname')]
# Parsed name: [('Volkan', 'GivenName'), ('Celebi', 'Surname')]
# Parsed name: [('Peter', 'GivenName'), ('Weber', 'Surname')]
# Parsed name: [('Edgar', 'GivenName'), ('Hupfer', 'Surname')]
# Parsed name: [('Evgeny', 'CorporationName'), ('Boltukhov', 'CorporationName')]
# Parsed name: [('Florence', 'CorporationName'), ('Corbaz', 'CorporationName')]
# Parsed name: [('Enrico', 'GivenName'), ('Buchs', 'Surname')]
# Parsed name: [('Kurt', 'GivenName'), ('Berger', 'Surname')]
# Parsed name: [('Ambre', 'GivenName'), ('Souverain', 'Surname')]
# Parsed name: [('Daniel', 'GivenName'), ('Kyburz', 'Surname')]
# Parsed name: [('Harold', 'GivenName'), ('Barnes', 'Surname')]
# Parsed name: [('Jean-François', 'GivenName'), ('Lanleau', 'Surname')]
# Parsed name: [('Andrea', 'GivenName'), ('Beneforti', 'Surname')]
# Parsed name: [('Thomas', 'GivenName'), ('Dantz', 'Surname')]
# Parsed name: [('Goncalo', 'GivenName'), ('Nuno', 'Surname'), ('Joia', 'Surname')]
# Parsed name: [('Christoph', 'GivenName'), ('Richner', 'Surname')]
# Parsed name: [('Monika', 'GivenName'), ('Schmid', 'Surname')]
# Parsed name: [('Sandro', 'GivenName'), ('Pauli', 'Surname')]
# Parsed name: [('Roland', 'GivenName'), ('Fritschi', 'Surname')]
# Parsed name: [('Thomas', 'GivenName'), ('Kundert', 'Surname')]
# Parsed name: [('Diana', 'GivenName'), ('Peneva', 'Surname')]
# Parsed name: [('Markus', 'CorporationName'), ('Hatt', 'CorporationName')]
# Parsed name: [('Willy', 'GivenName'), ('Bürgin', 'Surname')]
# Parsed name: [('Julian', 'GivenName'), ('Friedli', 'Surname')]
# Parsed name: [('Nico', 'GivenName'), ('Wild', 'Surname')]
# Parsed name: [('Martin', 'GivenName'), ('Schuler', 'Surname')]
# Parsed name: [('dummy', 'GivenName'), ('doublette', 'Surname')]
# Parsed name: [('Adrian', 'GivenName'), ('Roth', 'Surname')]
# Parsed name: [('Mathias', 'GivenName'), ('Tgetgel', 'Surname')]
# Parsed name: [('Allison', 'GivenName'), ('Weber', 'Surname')]
# Parsed name: [('Ina', 'GivenName'), ('Martinuci', 'Surname')]
# Parsed name: [('Sheila', 'GivenName'), ('Buletti', 'Surname')]
# Parsed name: [('Muhammed', 'GivenName'), ('Vilic', 'Surname')]
# Parsed name: [('Lukacs', 'Surname'), ('Attila', 'SuffixOther')]
# Parsed name: [('Lisbeth', 'GivenName'), ('Bühler', 'Surname')]
# Parsed name: [('Madabeni', 'GivenName'), ('B.', 'MiddleInitial'), ('AG', 'And'), ('Walter', 'GivenName'), ('Kasper', 'Surname')]
# Parsed name: [('Gabriele', 'GivenName'), ('Gianolli', 'Surname')]
# Parsed name: [('Karen', 'GivenName'), ('Kruse', 'Surname')]
# Parsed name: [('Jürg', 'GivenName'), ('Gubler', 'Surname')]
# Parsed name: [('Christiane', 'GivenName'), ('Sottas', 'Surname')]
# Parsed name: [('Hans-Otto', 'GivenName'), ('Walkling', 'Surname')]
# Parsed name: [('Reto', 'GivenName'), ('Steiner', 'Surname')]
# Parsed name: [('Johann', 'CorporationName'), ('Furrer', 'CorporationName')]
# Parsed name: [('Pierre', 'GivenName'), ('Müller', 'Surname')]
# Parsed name: [('Christoph', 'GivenName'), ('Scheuermann', 'Surname')]
# Parsed name: [('Marcel', 'GivenName'), ('Fischer', 'Surname')]
# Parsed name: [('Günther', 'GivenName'), ('Wasser', 'Surname')]
# Parsed name: [('Pascale', 'CorporationName'), ('Hoch', 'CorporationName')]
# Parsed name: [('Michel', 'GivenName'), ('Gomes', 'Surname')]
# Parsed name: [('Dominique', 'GivenName'), ('BOULBES', 'Surname')]
# Parsed name: [('Simon', 'GivenName'), ('Gantner', 'Surname')]
# Parsed name: [('Francisco', 'GivenName'), ('Baños', 'Surname')]
# Parsed name: [('Paul', 'GivenName'), ('Diener', 'Surname')]
# Parsed name: [('Patricia', 'GivenName'), ('Kettner', 'Surname')]
# Parsed name: [('Thomas', 'GivenName'), ('Mumenthaler', 'Surname')]
# Parsed name: [('Thomas', 'GivenName'), ('Saner', 'Surname')]
# Parsed name: [('David', 'GivenName'), ('Perrot', 'Surname')]
# Parsed name: [('Sylvestre', 'CorporationName'), ('Vecchi', 'CorporationName')]
# Parsed name: [('Lutz', 'GivenName'), ('Schneider', 'Surname')]
# Parsed name: [('Markus', 'GivenName'), ('Kast', 'Surname')]
# Parsed name: [('Christian', 'GivenName'), ('Bigger', 'Surname')]
# Parsed name: [('Michael', 'GivenName'), ('Wierz', 'Surname')]
# Parsed name: [('Joachim', 'GivenName'), ('Schlumpf', 'Surname')]
# Parsed name: [('Patrick', 'GivenName'), ('Guisolan', 'Surname')]
# Parsed name: [('René', 'GivenName'), ('Halbherr', 'Surname')]
# Parsed name: [('Gergana', 'GivenName'), ('Rohner', 'Surname')]
# Parsed name: [('Patrick', 'GivenName'), ('Guélat', 'Surname')]
# Parsed name: [('Gentile', 'CorporationName'), ('Jean-Charles', 'CorporationName')]
# Parsed name: [('Christian', 'GivenName'), ('Wege', 'Surname')]
# Parsed name: [('Helmut', 'GivenName'), ('Borer', 'Surname')]
# Parsed name: [('Thierry', 'GivenName'), ('Kramis', 'Surname')]
# Parsed name: [('Samuel', 'CorporationName'), ('ten', 'CorporationName'), ('Doornkaat', 'CorporationName')]
# Parsed name: [('Anouchka', 'GivenName'), ('Maret', 'Surname')]
# Parsed name: [('Francis', 'GivenName'), ('Cobbi', 'Surname')]
# Parsed name: [('Benny', 'GivenName'), ('Reiter', 'Surname')]
# Parsed name: [('Niall', 'GivenName'), ('Stive', 'Surname')]
# Parsed name: [('Hans', 'GivenName'), ('Brühlmann', 'Surname')]
# Parsed name: [('Dieter', 'GivenName'), ('Baldensperger', 'Surname')]
# Parsed name: [('Johann', 'GivenName'), ('Widmer', 'Surname')]
# Parsed name: [('Peter', 'GivenName'), ('Gabriel', 'Surname')]
# Parsed name: [('Alexander', 'GivenName'), ('Häusler', 'Surname')]
# Parsed name: [('Peter', 'GivenName'), ('Anderegg', 'Surname')]
# Parsed name: [('Markus', 'GivenName'), ('Frauenfelder', 'Surname')]
# Parsed name: [('Thomas', 'GivenName'), ('Lang', 'Surname')]
# Parsed name: [('Claude', 'GivenName'), ('Hofer', 'Surname')]
# Parsed name: [('marcel', 'GivenName'), ('zimmermann', 'Surname')]
# Parsed name: [('Herve', 'GivenName'), ('Andrieu', 'Surname')]
# Parsed name: [('Juliette', 'GivenName'), ('Pauline', 'MiddleName'), ('Arter', 'Surname')]
# Parsed name: [('Antoine', 'GivenName'), ('Delva', 'Surname')]
# Parsed name: [('Mirco', 'GivenName'), ('Signorell', 'Surname')]
# Parsed name: [('Canna', 'GivenName'), ('Beringer', 'Surname')]
# Parsed name: [('Consuelo', 'GivenName'), ('Rudolf', 'Surname')]
# Parsed name: [('Rolf', 'GivenName'), ('Widmer', 'Surname')]
# Parsed name: [('Sébastien', 'GivenName'), ('Baumann', 'Surname')]
# Parsed name: [('Dominik', 'GivenName'), ('Gasser', 'Surname')]
# Parsed name: [('Andy', 'GivenName'), ('Michel', 'MiddleName'), ('Straubhaar', 'Surname')]
# Parsed name: [('Torsten', 'GivenName'), ('Auerbach', 'Surname')]
# Parsed name: [('Ludivine', 'CorporationName'), ('Kaenel', 'CorporationName')]
# Parsed name: [('Matthias', 'GivenName'), ('Forster', 'Surname')]
# Parsed name: [('Carole', 'GivenName'), ('Koller', 'Surname')]
# Parsed name: [('Thomas', 'GivenName'), ('Schange', 'Surname')]
# Parsed name: [('Pascal', 'GivenName'), ('Cadonau', 'Surname')]
# Parsed name: [('Franco', 'GivenName'), ('Tonizzo', 'Surname')]
# Parsed name: [('Anne-Marie', 'GivenName'), ('Devaux', 'Surname')]
# Parsed name: [('Christine', 'GivenName'), ('Lanz', 'Surname')]
# Parsed name: [('Urs', 'GivenName'), ('Walthert', 'Surname')]
# Parsed name: [('Damian', 'GivenName'), ('Zahnd', 'Surname')]
# Parsed name: [('Yakup', 'GivenName'), ('Cifci', 'Surname')]
# Parsed name: [('Michel', 'GivenName'), ('Carigiet', 'Surname')]
# Parsed name: [('Matthias', 'GivenName'), ('Luchsinger', 'Surname')]
# Parsed name: [('Andreas', 'GivenName'), ('Glarner', 'Surname')]
# Parsed name: [('Frédéric', 'GivenName'), ('Wyss', 'Surname')]
# Parsed name: [('Dejan', 'GivenName'), ('Simovic', 'Surname')]
# Parsed name: [('Adrian', 'GivenName'), ('Harnisch', 'Surname')]
# Parsed name: [('Roman', 'GivenName'), ('Dobler', 'Surname')]
# Parsed name: [('Fatimétou', 'GivenName'), ("N'GAIDE-DIOUF", 'Surname')]
# Parsed name: [('Johannes', 'GivenName'), ('Kisling', 'Surname')]
# Parsed name: [('Mauerer', 'GivenName'), ('Hans', 'Surname')]
# Parsed name: [('Tiziana', 'GivenName'), ('Pichon-Leccese', 'Surname')]
# Parsed name: [('Thomas', 'GivenName'), ('Stauffer', 'Surname')]
# Parsed name: [('Eric', 'CorporationName'), ('Alberto', 'CorporationName'), ('Marco', 'CorporationName'), ('Bartolmoei', 'CorporationName')]
# Parsed name: [('Roberto', 'GivenName'), ('Hayer', 'Surname')]
# Parsed name: [('Ellen', 'GivenName'), ('Goris', 'Surname')]
# Parsed name: [('Pascal', 'GivenName'), ('Grun', 'Surname')]
# Parsed name: [('Manuel', 'GivenName'), ('Zurita', 'MiddleName'), ('Garcia', 'Surname')]
# Parsed name: [('Romaine', 'GivenName'), ('In-Albon', 'Surname')]
# Parsed name: [('Marcel', 'GivenName'), ('Rüdlinger', 'Surname')]
# Parsed name: [('Jean-Michel', 'GivenName'), ('Galley', 'Surname')]
# Parsed name: [('Simon', 'GivenName'), ('Schläppi', 'Surname')]
# Parsed name: [('Buchhaltung', 'GivenName')]
# Parsed name: [('Stefan', 'GivenName'), ('Aregger', 'Surname')]
# Parsed name: [('Nicola', 'GivenName'), ('De', 'Surname'), ('Ieso', 'Surname')]
# Parsed name: [('Paolo', 'GivenName'), ('Romani', 'Surname')]
# Parsed name: [('Marcel', 'GivenName'), ('Kipfer', 'Surname')]
# Parsed name: [('Thomas', 'GivenName'), ('Balmer', 'Surname')]
# Parsed name: [('Daniel', 'GivenName'), ('Theiler', 'Surname')]
# Parsed name: [('Gerd', 'GivenName'), ('Frera', 'Surname')]
# Parsed name: [('Eric', 'GivenName'), ('Drigatti', 'Surname')]
# Parsed name: [('S.', 'CorporationName'), ('Wüst', 'CorporationName')]
# Parsed name: [('John', 'GivenName'), ('Barret', 'Surname')]
# Parsed name: [('Ana', 'GivenName'), ('Isabel', 'MiddleName'), ('Nascimento', 'Surname'), ('dos', 'Surname'), ('Santos', 'Surname')]
# Parsed name: [('Timo', 'GivenName'), ('Nothhelfer', 'Surname')]
# Parsed name: [('Conti', 'CorporationName'), ('Saverio', 'CorporationName')]
# Parsed name: [('Regula', 'GivenName'), ('Modolo', 'Surname')]
# Parsed name: [('Jerez', 'Surname'), ('Belen', 'GivenName')]
# Parsed name: [('Bastien', 'GivenName'), ('Meier', 'Surname')]
# Parsed name: [('Gabor', 'GivenName'), ('Barsi', 'Surname')]
# Parsed name: [('Silvana', 'GivenName'), ('Petrillo', 'Surname')]
# Parsed name: [('Roman', 'GivenName'), ('Feierabend', 'Surname')]
# Parsed name: [('Fabrice', 'GivenName'), ('JOUANNEAU', 'Surname')]
# Parsed name: [('Urs', 'GivenName'), ('Röthlisberger', 'Surname')]
# Parsed name: [('Sven', 'GivenName'), ('Rohner', 'Surname')]
# Parsed name: [('Ajsella', 'GivenName'), ('Shala-Murtezi', 'Surname')]
# Parsed name: [('Oliver', 'GivenName'), ('Comi', 'Surname')]
# Parsed name: [('Vasco', 'Surname'), ('Manente', 'Surname')]
# Parsed name: [('Mathias', 'GivenName'), ('Müller', 'Surname')]
# Parsed name: [('Hans', 'GivenName'), ('Beer', 'Surname')]
# Parsed name: [('Jan', 'GivenName'), ('Körbitz', 'Surname')]
# Parsed name: [('Ference', 'GivenName'), ('Kovacs', 'Surname')]
# Parsed name: [('Carmine', 'CorporationName'), ('De', 'CorporationName'), ('Simone', 'CorporationName')]
# Parsed name: [('Peter', 'GivenName'), ('Besmer', 'Surname')]
# Parsed name: [('Jérémy', 'CorporationName'), ('Christillin', 'CorporationName')]
# Parsed name: [('Jurgen', 'CorporationName'), ('M.', 'CorporationName'), ('J.', 'CorporationName'), ('Borgt', 'CorporationName')]
# Parsed name: [('Daniel', 'GivenName'), ('Haas', 'Surname')]
# Parsed name: [('Tristan', 'GivenName'), ('Brockelmanns', 'Surname')]
# Parsed name: [('Ralf', 'GivenName'), ('Sturzenegger', 'Surname')]
# Parsed name: [('Martin', 'GivenName'), ('Huber', 'Surname')]
# Parsed name: [('Martin', 'Surname'), ('Adama', 'Surname')]
# Parsed name: [('Cornelia', 'GivenName'), ('Richard', 'Surname')]
# Parsed name: [('Bajna', 'GivenName'), ('Philippe', 'Surname')]
# Parsed name: [('Peter', 'GivenName'), ('Farmer', 'Surname')]
# Parsed name: [('Ray', 'GivenName'), ('Brand', 'Surname')]
# Parsed name: [('Armin', 'Surname'), ('Rohner', 'Surname')]
# Parsed name: [('Matteo', 'GivenName'), ('Riva', 'Surname')]
# Parsed name: [('Urs', 'GivenName'), ('Aregger', 'Surname')]
# Parsed name: [('Catherine', 'GivenName'), ('De', 'Surname'), ('chambrier', 'Surname')]
# Parsed name: [('David', 'CorporationName'), ('Crisinel', 'CorporationName')]
# Parsed name: [('Juergen', 'GivenName'), ('GUENTHER', 'Surname')]
# Parsed name: [('Alex', 'GivenName'), ('Kromwel', 'Surname')]
# Parsed name: [('Patrick', 'GivenName'), ('Grassler', 'Surname')]
# Parsed name: [('Ahmet', 'GivenName'), ('Yilmaz', 'Surname')]
# Parsed name: [('Julia', 'GivenName'), ('Binder', 'Surname')]
# Parsed name: [('Emilie', 'GivenName'), ('DELBARRE', 'Surname')]
# Parsed name: [('Evelyne', 'GivenName'), ('Diaz', 'Surname')]
# Parsed name: [('Roland', 'GivenName'), ('Marti', 'Surname')]
# Parsed name: [('Roger', 'GivenName'), ('Wassmer', 'Surname')]
# Parsed name: [('Clara-Ann', 'GivenName'), ('Gordon', 'Surname')]
# Parsed name: [('Hans-Peter', 'GivenName'), ('AMANN', 'Surname')]
# Parsed name: [('André', 'GivenName'), ('Twerenbold', 'Surname')]
# Parsed name: [('Andreas', 'GivenName'), ('Fink', 'Surname')]
# Parsed name: [('Eric', 'GivenName'), ('Brouwer', 'Surname')]
# Parsed name: [('Hans', 'GivenName'), ('Mosimann', 'Surname')]
# Parsed name: [('Michael', 'GivenName'), ('Geissmann', 'Surname')]
# Parsed name: [('Martin', 'CorporationName'), ('Hüppi', 'CorporationName')]
# Parsed name: [('Michel', 'GivenName'), ('Oestreich', 'Surname')]
# Parsed name: [('Michal', 'GivenName'), ('Lato', 'Surname')]
# Parsed name: [('Andree', 'GivenName'), ('van', 'Surname'), ('Boven', 'Surname')]
# Parsed name: [('Jessica', 'GivenName'), ('Zwahlen', 'Surname')]
# Parsed name: [('Steve', 'GivenName'), ('Cand', 'Surname')]
# Parsed name: [('Aldo', 'GivenName'), ('Britschgi', 'Surname')]
# Parsed name: [('Marcel', 'GivenName'), ('Eckstein', 'Surname')]
# Parsed name: [('Andreas', 'GivenName'), ('Casutt', 'Surname')]
# Parsed name: [('Danijel', 'GivenName'), ('Podbreznik', 'Surname')]
# Parsed name: [('Victor', 'GivenName'), ('Gnehm', 'Surname')]
# Parsed name: [('Bernard', 'GivenName'), ('Peyresblanques', 'Surname')]
# Parsed name: [('Doriana', 'GivenName'), ('Sabbatini', 'Surname')]
# Parsed name: [('Gabriel', 'GivenName'), ('Jäger', 'Surname')]
# Parsed name: [('Bernard', 'GivenName'), ('Verdonnet', 'Surname')]
# Parsed name: [('Matthieu', 'GivenName'), ('Carbonnier', 'Surname')]
# Parsed name: [('Stephan', 'GivenName'), ('Wick', 'Surname')]
# Parsed name: [('Beat', 'CorporationName'), ('Flepp', 'CorporationName')]
# Parsed name: [('Victoria', 'GivenName'), ('Grunholzer', 'Surname')]
# Parsed name: [('Stéphane', 'CorporationName'), ('Panchaud', 'CorporationName')]
# Parsed name: [('Christian', 'GivenName'), ('Ribeaud', 'Surname')]
# Parsed name: [('Andrea', 'GivenName'), ('Gut', 'Surname')]
# Parsed name: [('Celia', 'GivenName'), ('Alayo', 'MiddleName'), ('Argumedo', 'Surname')]
# Parsed name: [('Beat', 'GivenName'), ('Ritschard', 'Surname')]
# Parsed name: [('Paul', 'GivenName'), ('Messmer', 'Surname')]
# Parsed name: [('sté', 'CorporationName'), ('rapidofoos', 'CorporationName'), ('sa', 'CorporationName')]
# Parsed name: [('Gutter', 'GivenName'), ('Patrick', 'Surname')]
# Parsed name: [('EFE', 'GivenName'), ('DEMIR', 'Surname')]
# Parsed name: [('Marcel', 'GivenName'), ('Andrey', 'Surname')]
# Parsed name: [('Val', 'GivenName'), ('Ilchenko', 'Surname')]
# Parsed name: [('M.', 'FirstInitial'), ('Bertschinger', 'Surname')]
# Parsed name: [('Luca', 'GivenName'), ('Bernasconi', 'Surname')]
# Parsed name: [('Jean-Luc', 'CorporationName'), ('Schenk', 'CorporationName')]
# Parsed name: [('Martin', 'CorporationName'), ('Fluck', 'CorporationName')]
# Parsed name: [('Dali', 'CorporationName'), ('Horvat', 'CorporationName')]
# Parsed name: [('George', 'GivenName'), ('Studer', 'Surname')]
# Parsed name: [('Daniel', 'GivenName'), ('Bärtschi', 'Surname')]
# Parsed name: [('Berger', 'Surname'), ('Jimmy', 'GivenName')]
# Parsed name: [('Aaron', 'GivenName'), ('Herceg', 'Surname')]
# Parsed name: [('Willy', 'GivenName'), ('Oppliger', 'Surname')]
# Parsed name: [('Beatrice', 'GivenName'), ('Bähr', 'Surname')]
# Parsed name: [('Simone', 'GivenName'), ('Edera', 'Surname')]
# Parsed name: [('Giuseppe', 'GivenName'), ('Gioiello', 'Surname')]
# Parsed name: [('Bruno', 'GivenName'), ('Huber', 'Surname')]
# Parsed name: [('Erkan', 'GivenName'), ('Yilmaz', 'Surname')]
# Parsed name: [('Daniel', 'GivenName'), ('Waldner', 'Surname')]
# Parsed name: [('Nicola', 'GivenName'), ('LoPresti', 'Surname')]
# Parsed name: [('Pierre', 'GivenName'), ('Abramowski', 'Surname')]
# Parsed name: [('Belinda', 'GivenName'), ('Lehmann', 'Surname')]
# Parsed name: [('Ulrich', 'CorporationName'), ('Link', 'CorporationName')]
# Parsed name: [('Martin', 'GivenName'), ('Becker', 'Surname')]
# Parsed name: [('Andreas', 'GivenName'), ('Pöll', 'Surname')]
# Parsed name: [('Herwig', 'GivenName'), ('Bonin', 'Surname')]
# Parsed name: [('Johnson', 'GivenName'), ('Francis', 'Surname')]
# Parsed name: [('Otto', 'GivenName'), ('Reinmann', 'Surname')]
# Parsed name: [('Ursula', 'GivenName'), ('Kaya', 'Surname')]
# Parsed name: [('Daniel', 'GivenName'), ('Müller', 'Surname')]
# Parsed name: [('Simone', 'GivenName'), ('Cicalissi', 'Surname')]
# Parsed name: [('Séverin', 'GivenName'), ('Voisin', 'Surname')]
# Parsed name: [('Linus', 'GivenName'), ('Bläsi', 'Surname')]
# Parsed name: [('Charles', 'GivenName'), ('Smith', 'Surname')]
# Parsed name: [('Christine', 'GivenName'), ('Horner', 'Surname')]
# Parsed name: [('Monika', 'GivenName'), ('Fricker', 'Surname')]
# Parsed name: [('BERGKVIST', 'GivenName'), ('PETER', 'Surname')]
# Parsed name: [('Bernd', 'CorporationName'), ('Büdenbender', 'CorporationName')]
# Parsed name: [('Urs', 'CorporationName'), ('Schläpfer', 'CorporationName')]
# Parsed name: [('Carlo', 'GivenName'), ('Laudati', 'Surname')]
# Parsed name: [('Francine', 'GivenName'), ('Ludinard', 'Surname')]
# Parsed name: [('Phil', 'GivenName'), ('Newman', 'Surname')]
# Parsed name: [('Beat', 'GivenName'), ('Aeschlimann', 'Surname')]
# Parsed name: [('Giancarlo', 'GivenName'), ('De', 'Surname'), ('Giorgi', 'Surname')]
# Parsed name: [('Marcel', 'GivenName'), ('Fehr', 'Surname')]
# Parsed name: [('Mario', 'GivenName'), ('Steiger', 'Surname')]
# Parsed name: [('Claudia', 'GivenName'), ('Beck', 'Surname')]
# Parsed name: [('Max', 'GivenName'), ('Muster', 'Surname')]
# Parsed name: [('Brian', 'GivenName'), ('Boroff', 'Surname')]
# Parsed name: [('Fredj', 'CorporationName'), ('Trabelsi', 'CorporationName')]
# Parsed name: [('Jessica', 'GivenName'), ('Da', 'Surname'), ('Silva', 'GivenName'), ('Villacastin', 'Surname')]
# Parsed name: [('Stefan', 'GivenName'), ('Huber', 'Surname')]
# Parsed name: [('Jorge', 'GivenName'), ('DA', 'Surname'), ('SILVA', 'Surname')]
# Parsed name: [('Auf', 'GivenName'), ('der', 'Surname'), ('Maur', 'Surname'), ('David', 'Surname')]
# Parsed name: [('Olivier', 'GivenName'), ('Bianco', 'Surname')]
# Parsed name: [('Marc', 'GivenName'), ('Walpoth', 'Surname')]
# Parsed name: [('James', 'GivenName'), ('Ibbetson', 'Surname')]
# Parsed name: [('Karnjanart', 'GivenName'), ('Breu', 'Surname')]
# Parsed name: [('Jürg', 'PrefixOther'), ('Robert', 'GivenName'), ('Karlen', 'Surname')]
# Parsed name: [('Onno', 'GivenName'), ('Behr', 'Surname')]
# Parsed name: [('Lars', 'GivenName'), ('Begert', 'Surname')]
# Parsed name: [('Manieri', 'Surname'), ('Filomena', 'GivenName')]
# Parsed name: [('Marco', 'GivenName'), ('Pulfer', 'Surname')]
# Parsed name: [('Sarah', 'GivenName'), ('Waller', 'Surname')]
# Parsed name: [('Vincent', 'GivenName'), ('Peek', 'Surname')]
# Parsed name: [('Andy', 'GivenName'), ('Russ', 'Surname')]
# Parsed name: [('manuela', 'GivenName'), ('Schweighofer', 'Surname')]
# Parsed name: [('Sandie', 'GivenName'), ('Lancashire', 'Surname')]
# Parsed name: [('Jean-Claude', 'CorporationName'), ('Dehl', 'CorporationName')]
# Parsed name: [('Fredy', 'GivenName'), ('Riner', 'Surname')]
# Parsed name: [('Nadine', 'GivenName'), ('Cohen', 'Surname')]
# Parsed name: [('Bondier', 'GivenName'), ('Nicolas', 'Surname')]
# Parsed name: [('Rene', 'GivenName'), ('von', 'MiddleName'), ('Euw', 'Surname')]
# Parsed name: [('Ingrid', 'GivenName'), ('Häfelin', 'Surname')]
# Parsed name: [('Alessia', 'GivenName'), ('Sicilia', 'Surname')]
# Parsed name: [('Raphaël', 'GivenName'), ('Perruchoud', 'Surname')]
# Parsed name: [('David', 'GivenName'), ('Lämmler', 'Surname')]
# Parsed name: [('Maya', 'GivenName'), ('Repele', 'Surname')]
# Parsed name: [('Arnaud', 'CorporationName'), ('Claivaz', 'CorporationName')]
# Parsed name: [('Alexander', 'GivenName'), ('Esslinger', 'Surname')]
# Parsed name: [('Benedikt', 'CorporationName'), ('Fassbind', 'CorporationName')]
# Parsed name: [('Cédric', 'CorporationName'), ('Bossart', 'CorporationName')]
# Parsed name: [('Verena', 'GivenName'), ('Saxer', 'Surname')]
# Parsed name: [('Galvin', 'Surname'), ('Ernest', 'GivenName')]
# Parsed name: [('Manuela', 'GivenName'), ('Cadan', 'Surname')]
# Parsed name: [('Rainer', 'GivenName'), ('Feldner', 'Surname')]
# Parsed name: [('Hakan', 'GivenName'), ('Oezkan', 'Surname')]
# Parsed name: [('Andrea', 'GivenName'), ('Mondini', 'Surname')]
# Parsed name: [('Nebi', 'GivenName'), ('Nuh', 'MiddleName'), ('Akcakaya', 'Surname')]
# Parsed name: [('Marlene', 'GivenName'), ('Schadegg', 'Surname')]
# Parsed name: [('Angineh', 'GivenName'), ('Gevorken', 'Surname')]
# Parsed name: [('Christian', 'GivenName'), ('Weber', 'Surname')]
# Parsed name: [('STEFAN', 'GivenName'), ('WEISS', 'Surname')]
# Parsed name: [('Aurélie', 'GivenName'), ('Ledermann', 'Surname')]
# Parsed name: [('Epsilon', 'GivenName'), ('Legal', 'Surname')]
# Parsed name: [('Claudia', 'GivenName'), ('Bisagno', 'Surname')]
# Parsed name: [('Michael', 'GivenName'), ('Edion', 'Surname')]
# Parsed name: [('Alfredo', 'GivenName'), ('Ciciulla', 'Surname')]
# Parsed name: [('Johannes', 'CorporationName'), ('Iten', 'CorporationName')]
# Parsed name: [('André', 'GivenName'), ('Brice', 'Surname')]
# Parsed name: [('Davide', 'Surname'), ('Alfano', 'Surname')]
# Parsed name: [('Joen', 'GivenName'), ('Fricker', 'Surname')]
# Parsed name: [('Vincenzo', 'GivenName'), ('Vito', 'Surname')]
# Parsed name: [('Gregory', 'GivenName'), ('Lanz', 'Surname')]
# Parsed name: [('Frédéric', 'CorporationName'), ('Fischlin', 'CorporationName')]
# Parsed name: [('Kurt', 'GivenName'), ('Gerne', 'Surname')]
# Parsed name: [('Beate', 'GivenName'), ('Noll', 'Surname')]
# Parsed name: [('Stockier', 'GivenName')]
# Parsed name: [('Michel', 'GivenName'), ('Müller', 'Surname')]
# Parsed name: [('keine', 'GivenName'), ('Person', 'Surname')]
# Parsed name: [('Peter', 'GivenName'), ('Hässig', 'Surname')]
# Parsed name: [('Mirand', 'CorporationName'), ('Murseli', 'CorporationName')]
# Parsed name: [('Marco', 'GivenName'), ('von', 'GivenName'), ('Gunten', 'Surname')]
# Parsed name: [('Richard', 'GivenName'), ('Martin', 'Surname')]
# Parsed name: [('Thierry', 'GivenName'), ('Weckner', 'Surname')]
# Parsed name: [('Daniel', 'GivenName'), ('Schär', 'Surname')]
# Parsed name: [('Arianna', 'GivenName'), ('Alexander', 'Surname')]
# Parsed name: [('Marlon', 'GivenName'), ('Marasligil', 'Surname')]
# Parsed name: [('Franziska', 'GivenName'), ('Schweizer', 'Surname')]
# Parsed name: [('Maica', 'Surname'), ('Labella', 'Surname'), ('Romera', 'Surname')]
# Parsed name: [('Corinne', 'GivenName'), ('Besson', 'Surname')]
# Parsed name: [('Martin', 'GivenName'), ('Kuratli', 'Surname')]
# Parsed name: [('Maria', 'GivenName'), ('Finardi', 'Surname')]
# Parsed name: [('Izone', 'CorporationName'), ('Kuhnen', 'CorporationName'), ('Barras', 'CorporationNameOrganization')]
# Parsed name: [('Luigi', 'GivenName'), ('Carrisi', 'Surname')]
# Parsed name: [('Yildiz', 'CorporationName'), ('Bülent', 'CorporationNameOrganization')]
# Parsed name: [('Tina', 'GivenName'), ('Salerno', 'Surname')]
# Parsed name: [('Süleyman', 'GivenName'), ('Oygur', 'Surname')]
# Parsed name: [('Alexandre', 'CorporationName'), ('Del', 'CorporationName'), ('Zenero', 'CorporationName')]
# Parsed name: [('Orlando', 'GivenName'), ('TOGNINA', 'Surname')]
# Parsed name: [('Jonas', 'GivenName'), ('Kümin', 'Surname')]
# Parsed name: [('Roxana', 'GivenName'), ('Cuepa', 'Surname')]
# Parsed name: [('G.', 'FirstInitial'), ('Rhyner', 'Surname')]
# Parsed name: [('Mario', 'GivenName'), ('Maldini', 'Surname')]
# Parsed name: [('Sabrina', 'GivenName'), ('Nourine', 'Surname')]
# Parsed name: [('Romeo', 'GivenName'), ('Minini', 'Surname')]
# Parsed name: [('Gian', 'CorporationName'), ('Piero', 'CorporationName'), ('Cervellera', 'CorporationName')]
# Parsed name: [('Müller', 'CorporationName'), ('Ueli', 'CorporationName')]
# Parsed name: [('Suzanne', 'GivenName'), ('Lienhard', 'Surname')]
# Parsed name: [('Nicola', 'GivenName'), ('Schwegler', 'Surname')]
# Parsed name: [('Claude', 'GivenName'), ('Fahrni', 'Surname')]
# Parsed name: [('Patrick', 'GivenName'), ('Meier', 'Surname')]
# Parsed name: [('Celestina', 'GivenName'), ('Neto', 'Surname')]
# Parsed name: [('BERNARD', 'GivenName'), ('KACZMAREK', 'Surname')]
# Parsed name: [('Peter', 'GivenName'), ('Leemann', 'Surname')]
# Parsed name: [('marie-françoise', 'CorporationName'), ('trottet', 'CorporationName')]
# Parsed name: [('Christina', 'GivenName'), ('Vetsch', 'Surname')]
# Parsed name: [('Thomas', 'GivenName'), ('Streit', 'Surname')]
# Parsed name: [('Manuela', 'GivenName'), ('Schaffner', 'Surname')]
# Parsed name: [('Kathrin', 'GivenName'), ('Schläppi', 'Surname')]
# Parsed name: [('Görkem', 'GivenName'), ('Yilmazer', 'Surname')]
# Parsed name: [('Amer', 'CorporationName'), ('Barjaktarevic', 'CorporationName')]
# Parsed name: [('Anne', 'GivenName'), ('Ngono', 'Surname')]
# Parsed name: [('KIEFFER', 'GivenName'), ('PHILIPPE', 'Surname')]
# Parsed name: [('Samuel', 'GivenName'), ('Manz', 'Surname')]
# Parsed name: [('Karin', 'GivenName'), ('Annen', 'Surname')]
# Parsed name: [('Alain', 'CorporationName'), ('Bulliard', 'CorporationName')]
# Parsed name: [('Emilio', 'GivenName'), ('Guerini', 'Surname')]
# Parsed name: [('Ralf', 'GivenName'), ('Tonezzer', 'Surname')]
# Parsed name: [('Yannick', 'GivenName'), ('Evrard', 'Surname')]
# Parsed name: [('Franziska', 'CorporationName'), ('Sigrist', 'CorporationName')]
# Parsed name: [('Paul', 'GivenName'), ('Euler', 'Surname')]
# Parsed name: [('Hanspeter', 'GivenName'), ('Weisskopf', 'Surname')]
# Parsed name: [('Nikolaos', 'CorporationName'), ('Velentzas', 'CorporationName')]
# Parsed name: [('Nicole', 'GivenName'), ('Darioli', 'Surname')]
# Parsed name: [('Sara', 'GivenName'), ('Tanner', 'Surname')]
# Parsed name: [('Barbara', 'GivenName'), ('Thür', 'Surname')]
# Parsed name: [('Tiziana', 'CorporationName'), ('Pichon', 'CorporationName'), ('Leccese', 'CorporationName')]
# Parsed name: [('David', 'GivenName'), ('Hosslin', 'Surname')]
# Parsed name: [('Markus', 'GivenName'), ('Nickel', 'Surname')]
# Parsed name: [('Erika', 'GivenName'), ('Schmidlin', 'Surname')]
# Parsed name: [('Anaïs', 'GivenName'), ('Güdel', 'Surname')]
# Parsed name: [('Vincent', 'GivenName'), ('Meyer', 'Surname')]
# Parsed name: [('Regula', 'GivenName'), ('Senn', 'Surname')]
# Parsed name: [('Ursula', 'GivenName'), ('Barker', 'Surname')]
# Parsed name: [('Jörg', 'GivenName'), ('Kramer', 'Surname')]
# Parsed name: [('Timcke', 'GivenName'), ('Henning', 'Surname')]
# Parsed name: [('Beat', 'GivenName'), ('Stettler', 'Surname')]
# Parsed name: [('Florian', 'GivenName'), ('Gygax', 'Surname')]
# Parsed name: [('Tommy', 'GivenName'), ('Frei', 'Surname')]
# Parsed name: [('Roger', 'GivenName'), ('Gassmann', 'Surname')]
# Parsed name: [('Lara', 'GivenName'), ('Luci', 'Surname')]
# Parsed name: [('Aydin', 'GivenName'), ('Yilmaz', 'Surname')]
# Parsed name: [('Susanne', 'GivenName'), ('Bärtschi', 'Surname')]
# Parsed name: [('Dagmar', 'GivenName'), ('Anderes', 'Surname')]
# Parsed name: [('Cédric', 'CorporationName'), ('Burkhalter', 'CorporationName')]
# Parsed name: [('Rachel', 'GivenName'), ('Montandon', 'Surname')]
# Parsed name: [('Sonja', 'GivenName'), ('Loop', 'Surname')]
# Parsed name: [('Chris', 'GivenName'), ('Weingartner', 'Surname')]
# Parsed name: [('Eric', 'GivenName'), ('Gilliard', 'Surname')]
# Parsed name: [('Wilfred', 'GivenName'), ('Mathanaraj', 'Surname')]
# Parsed name: [('Giambattista', 'GivenName'), ('Ravanne', 'Surname')]
# Parsed name: [('Abejón', 'GivenName'), ('Beatriz', 'Surname')]
# Parsed name: [('Pier', 'GivenName'), ('Sciurti', 'Surname')]
# Parsed name: [('Serpil', 'GivenName'), ('Oruc', 'Surname')]
# Parsed name: [('Claudio', 'GivenName'), ('PISANI', 'Surname')]
# Parsed name: [('Nicole', 'GivenName'), ('Perrin', 'Surname')]
# Parsed name: [('Nicolas', 'GivenName'), ('Wyss', 'Surname')]
# Parsed name: [('Marc', 'GivenName'), ('Aeschlimann', 'Surname')]
# Parsed name: [('Dominik', 'GivenName'), ('P.', 'MiddleInitial'), ('Rubli', 'Surname')]
# Parsed name: [('Salah', 'GivenName'), ('Walo', 'Surname')]
# Parsed name: [('Maria', 'GivenName'), ('Georgiou', 'Surname')]
# Parsed name: [('Margarita', 'GivenName'), ('Gonzalez', 'Surname')]
# Parsed name: [('Gerda', 'GivenName'), ('Grisiger', 'Surname')]
# Parsed name: [('Kalliopi', 'GivenName'), ('Sotiropoulou', 'Surname')]
# Parsed name: [('Ben', 'CorporationName'), ('Amer', 'CorporationName'), ('Walid', 'CorporationName')]
# Parsed name: [('Sandra', 'GivenName'), ('Leutenegger', 'Surname')]
# Parsed name: [('Marc', 'GivenName'), ('Ott', 'Surname')]
# Parsed name: [('Vincent', 'GivenName'), ('Jambou', 'Surname')]
# Parsed name: [('Kristina', 'GivenName'), ('Mülhauser', 'Surname')]
# Parsed name: [('Guido', 'GivenName'), ('Melzer', 'Surname')]
# Parsed name: [('pia', 'GivenName'), ('bieri', 'Surname')]
# Parsed name: [('Jane', 'GivenName'), ('Flückiger', 'Surname')]
# Parsed name: [('Daniel', 'GivenName'), ('Hitz', 'Surname')]
# Parsed name: [('Manfred', 'CorporationName'), ('Zosso', 'CorporationName')]
# Parsed name: [('Dominique', 'GivenName'), ('Chassot', 'Surname')]
# Parsed name: [('Marco', 'GivenName'), ('Jörg', 'Surname')]
# Parsed name: [('François', 'GivenName'), ('Brun', 'Surname')]
# Parsed name: [('Damien', 'GivenName'), ('Wilhelm', 'Surname')]
# Parsed name: [('Alan', 'GivenName'), ('Saklican', 'Surname')]
# Parsed name: [('Claudio', 'GivenName'), ('Gubitosa', 'Surname')]
# Parsed name: [('DAVID', 'GivenName'), ('COHEN', 'Surname')]
# Parsed name: [('Rudolf', 'GivenName'), ('Widmer', 'Surname')]
# Parsed name: [('Denise', 'GivenName'), ('Stofer', 'Surname')]
# Parsed name: [('Oliver', 'GivenName'), ('Jäger', 'Surname')]
# Parsed name: [('Daniel', 'GivenName'), ('Aebi', 'Surname')]
# Parsed name: [('Fathi', 'GivenName'), ('Hajjaji', 'Surname')]
# Parsed name: [('Maass', 'GivenName'), ('Matthias', 'Surname')]
# Parsed name: [('Niklas', 'GivenName'), ('Heimer', 'Surname')]
# Parsed name: [('Jocelyn', 'GivenName'), ('Evequoz', 'Surname')]
# Parsed name: [('Pierre', 'GivenName'), ('Alian', 'MiddleName'), ('Carruzzo', 'Surname')]
# Parsed name: [('Roland', 'GivenName'), ('Mettler', 'Surname')]
# Parsed name: [('Dominik', 'GivenName'), ('Bettler', 'Surname')]
# Parsed name: [('Thierry', 'CorporationName'), ('Laurence', 'CorporationName')]
# Parsed name: [('Peter', 'GivenName'), ('Burkhalter', 'Surname')]
# Parsed name: [('Rita', 'GivenName'), ('Barros', 'Surname')]
# Parsed name: [('Ivo', 'GivenName'), ('Haerdi', 'Surname')]
# Parsed name: [('Boris', 'GivenName'), ('Trinkler', 'Surname')]
# Parsed name: [('Charly', 'GivenName'), ('Lee', 'Surname')]
# Parsed name: [('Bruno', 'GivenName'), ('Wolf', 'Surname')]
# Parsed name: [('Kathy', 'GivenName'), ('Berset', 'Surname')]
# Parsed name: [('Claudio', 'GivenName'), ('Sartorelli', 'Surname')]
# Parsed name: [('Jean-Paul', 'GivenName'), ('Holenstein', 'Surname')]
# Parsed name: [('Felipe', 'GivenName'), ('Solari', 'Surname')]
# Parsed name: [('Philippe', 'CorporationName'), ('Herzog', 'CorporationName')]
# Parsed name: [('Hansrudolf', 'GivenName'), ('Kull', 'Surname')]
# Parsed name: [('Marcel', 'GivenName'), ('Bachmann', 'Surname')]
# Parsed name: [('Katja', 'GivenName'), ('Locher', 'Surname')]
# Parsed name: [('Roberto', 'GivenName'), ('Cabot', 'Surname')]
# Parsed name: [('Devorah', 'GivenName'), ('Debever', 'Surname')]
# Parsed name: [('Ivana', 'GivenName'), ('Cosic', 'Surname')]
# Parsed name: [('Sara', 'GivenName'), ('Zanon', 'Surname')]
# Parsed name: [('Jürg', 'GivenName'), ('Weilenmann', 'Surname')]
# Parsed name: [('Pascal', 'CorporationName'), ('Pegaz', 'CorporationName'), ('Paquet', 'CorporationName')]
# Parsed name: [('Angela', 'GivenName'), ('Glükler', 'Surname')]
# Parsed name: [('Stefan', 'GivenName'), ('Scharrenbroich', 'Surname')]
# Parsed name: [('Jessica', 'GivenName'), ('Salvi', 'Surname')]
# Parsed name: [('Pedro', 'GivenName'), ('Marta', 'Surname')]
# Parsed name: [('Marcello', 'GivenName'), ('Tonini', 'Surname')]
# Parsed name: [('Richard', 'GivenName'), ('Landheer', 'Surname')]
# Parsed name: [('Carla', 'GivenName'), ('Fidecaro', 'Surname')]
# Parsed name: [('Antonio', 'GivenName'), ('Brigant', 'Surname')]
# Parsed name: [('Thomas', 'GivenName'), ('Boillat', 'Surname')]
# Parsed name: [('Harry', 'GivenName'), ('Bucklar', 'Surname')]
# Parsed name: [('Rick', 'GivenName'), ('Bollard', 'Surname')]
# Parsed name: [('Michael', 'GivenName'), ('Geilenkirchen', 'Surname')]
# Parsed name: [('Margot', 'GivenName'), ('Annen', 'Surname')]
# Parsed name: [('Andreas', 'GivenName'), ('Gisler', 'Surname')]
# Parsed name: [('Ant', 'GivenName'), ('Stone', 'Surname')]
# Parsed name: [('Daniel', 'GivenName'), ('Ducret', 'Surname')]
# Parsed name: [('Dagmar', 'GivenName'), ('Wegmann', 'Surname')]
# Parsed name: [('Margrit', 'GivenName'), ('Hard', 'Surname')]
# Parsed name: [('Jean', 'GivenName'), ('Philippe', 'Surname'), ('Dr.', 'PrefixOther'), ('Haesler', 'Surname')]
# Parsed name: [('Patrick', 'GivenName'), ('Donzel', 'Surname')]
# Parsed name: [('Peter', 'GivenName'), ('Maurer', 'Surname')]
# Parsed name: [('Peter', 'GivenName'), ('Müller', 'Surname')]
# Parsed name: [('Lydia', 'GivenName'), ('Lambert', 'Surname')]
# Parsed name: [('Benjamin', 'CorporationName'), ('Freisberg', 'CorporationName')]
# Parsed name: [('Susanna', 'GivenName'), ('Göldi', 'Surname')]
# Parsed name: [('Helen', 'GivenName'), ('Begert', 'Surname')]
# Parsed name: [('Cornelia', 'GivenName'), ('Lehne', 'Surname')]
# Parsed name: [('Brigitta', 'GivenName'), ('Kunz', 'Surname')]
# Parsed name: [('Reinhold', 'CorporationName'), ('Müller', 'CorporationName')]
# Parsed name: [('Niky', 'CorporationName'), ('Alexander', 'CorporationName'), ('Thomet', 'CorporationName')]
# Parsed name: [('Stéphane', 'GivenName'), ('MOGNOL', 'Surname')]
# Parsed name: [('Stiepan', 'GivenName'), ('Kovac', 'Surname')]
# Parsed name: [('Thomas', 'GivenName'), ('Leisenberg', 'Surname')]
# Parsed name: [('Andreas', 'GivenName'), ('Glarner', 'Surname')]
# Parsed name: [('Werner', 'GivenName'), ('Fuchs', 'Surname')]
# Parsed name: [('Daniel', 'GivenName'), ('Ruiz', 'Surname')]
# Parsed name: [('Stefan', 'GivenName'), ('Gächter', 'Surname')]
# Parsed name: [('Lurko', 'GivenName'), ('Gombay', 'Surname')]
# Parsed name: [('Christel', 'GivenName'), ('Muri', 'Surname')]
# Parsed name: [('Amanda', 'GivenName'), ('Casagrande', 'Surname')]
# Parsed name: [('Philippe', 'CorporationName'), ('Carron', 'CorporationName')]
# Parsed name: [('christine', 'GivenName'), ('zaghet', 'Surname')]
# Parsed name: [('Urs', 'GivenName'), ('Hafner', 'Surname')]
# Parsed name: [('Christian', 'GivenName'), ('Hutter', 'Surname')]
# Parsed name: [('Jerry', 'GivenName'), ('Lay', 'Surname')]
# Parsed name: [('Thomas', 'GivenName'), ('Scheurer', 'Surname')]
# Parsed name: [('Marcel', 'GivenName'), ('Wappler', 'Surname')]
# Parsed name: [('Rosmarie', 'GivenName'), ('Hunziker', 'Surname')]
# Parsed name: [('Robert', 'GivenName'), ('Berger', 'Surname')]
# Parsed name: [('Oskar', 'CorporationName'), ('Fehr', 'CorporationName')]
# Parsed name: [('Hamblin', 'Surname'), ('Damani', 'Surname')]
# Parsed name: [('François', 'GivenName'), ('Martel', 'Surname')]
# Parsed name: [('Hansruedi', 'GivenName'), ('Huber', 'Surname')]
# Parsed name: [('Stefan', 'GivenName'), ('Althaus', 'Surname')]
# Parsed name: [('Sabine', 'GivenName'), ('Bandi', 'Surname')]
# Parsed name: [('Kelley', 'GivenName'), ('Diana', 'Surname')]
# Parsed name: [('Andreas', 'GivenName'), ('Borer', 'Surname')]
# Parsed name: [('Obuchowski', 'Surname'), ('Adam', 'GivenName')]
# Parsed name: [('Claudia', 'GivenName'), ('Giorgetti', 'Surname')]
# Parsed name: [('Roger', 'GivenName'), ('Matter', 'Surname')]
# Parsed name: [('Christophe', 'GivenName'), ('Vila', 'Surname')]
# Parsed name: [('Milena', 'CorporationName'), ('Filomena', 'CorporationName'), ('La', 'CorporationName'), ('Cioppa', 'CorporationName')]
# Parsed name: [('Martin', 'GivenName'), ('Gerber', 'Surname')]
# Parsed name: [('Mohsin', 'GivenName'), ('Ehsan', 'MiddleName'), ('Butt', 'Surname')]
# Parsed name: [('René', 'GivenName'), ('Rahm', 'Surname')]
# Parsed name: [('Marco', 'GivenName'), ('Dahinden', 'Surname')]
# Parsed name: [('Lawrence', 'GivenName'), ('Blakeley', 'Surname')]
# Parsed name: [('Nicolas', 'GivenName'), ('Sieger', 'Surname')]
# Parsed name: [('Gyozo', 'GivenName'), ('Kmethy', 'Surname')]
# Parsed name: [('Anne-Laure', 'CorporationName'), ('Haissly', 'CorporationName')]
# Parsed name: [('Marc', 'GivenName'), ('Meyer', 'Surname')]
# Parsed name: [('Alain', 'GivenName'), ('Valentino', 'Surname')]
# Parsed name: [('Thomas', 'GivenName'), ('Goodwin', 'Surname')]
# Parsed name: [('Olivier', 'GivenName'), ('Rey', 'Surname')]
# Parsed name: [('Rainer', 'GivenName'), ('Hollenstein', 'Surname')]
# Parsed name: [('Remo', 'GivenName'), ('Buetikofer', 'Surname')]
# Parsed name: [('Andreas', 'GivenName'), ('Jermann', 'Surname')]
# Parsed name: [('Ariane', 'GivenName'), ('Perny', 'Surname')]
# Parsed name: [('Adrian', 'GivenName'), ('Spahn', 'Surname')]
# Parsed name: [('Martin', 'CorporationName'), ('Tichy-Ruch', 'CorporationName')]
# Parsed name: [('Isabelle', 'GivenName'), ('Sahli', 'Surname')]
# Parsed name: [('Joerg', 'GivenName'), ('Kessler', 'Surname')]
# Parsed name: [('Christian', 'GivenName'), ('Donatsch', 'Surname')]
# Parsed name: [('Armin', 'CorporationName'), ('Ris', 'CorporationName')]
# Parsed name: [('Frank', 'GivenName'), ('Valley', 'Surname')]
# Parsed name: [('Thomas', 'GivenName'), ('Hiltbrunner', 'Surname')]
# Parsed name: [('James', 'GivenName'), ('Salvador', 'Surname')]
# Parsed name: [('Roman', 'GivenName'), ('Dissauer', 'Surname')]
# Parsed name: [('Fernando', 'GivenName'), ('Marques', 'Surname')]
# Parsed name: [('Jorge', 'GivenName'), ('Luis', 'MiddleName'), ('Mariuzzo', 'Surname')]
# Parsed name: [('Luc', 'Surname'), ('van', 'GivenName'), ('Deuzen', 'Surname')]
# Parsed name: [('Eduard', 'GivenName'), ('Kolly', 'Surname')]
# Parsed name: [('Giger', 'Surname')]
# Parsed name: [('Jacqueline', 'GivenName'), ('Oertle', 'Surname')]
# Parsed name: [('Oskar', 'GivenName'), ('Bernauer', 'Surname')]
# Parsed name: [('Oliver', 'GivenName'), ('Ernst', 'Surname')]
# Parsed name: [('Bülent', 'GivenName'), ('Yildiz', 'Surname')]
# Parsed name: [('Rohregger', 'GivenName'), ('Bernd', 'Surname')]
# Parsed name: [('Hürlimann', 'CorporationName'), ('Elsbeth', 'CorporationName')]
# Parsed name: [('Urs', 'GivenName'), ('Buchwalder', 'Surname')]
# Parsed name: [('Erich', 'GivenName'), ('Staub', 'Surname')]
# Parsed name: [('Thierry', 'GivenName'), ('Affolter', 'Surname')]
# Parsed name: [('Richard', 'GivenName'), ('Landheer', 'Surname')]
# Parsed name: [('Carlo', 'GivenName'), ('Franchini', 'Surname')]
# Parsed name: [('Peter', 'GivenName'), ('Link', 'Surname')]
# Parsed name: [('Pierre', 'GivenName'), ('Schoeffel', 'Surname')]
# Parsed name: [('Pius', 'GivenName'), ('Häfliger', 'Surname')]
# Parsed name: [('Lorenz', 'GivenName'), ('Altenhoff', 'Surname')]
# Parsed name: [('Daniel', 'GivenName'), ('Arni', 'Surname')]
# Parsed name: [('Alexandra', 'GivenName'), ('Denervaud', 'Surname')]
# Parsed name: [('Monika', 'GivenName'), ('Ursula', 'MiddleName'), ('Vodica', 'Surname')]
# Parsed name: [('Maurice', 'GivenName'), ('B.', 'MiddleInitial'), ('Grosjean', 'Surname')]
# Parsed name: [('Myrta', 'GivenName'), ('Estermann', 'Surname')]
# Parsed name: [('Beaudelaire', 'GivenName'), ('KATEU', 'Surname')]
# Parsed name: [('David', 'GivenName'), ('Valente', 'Surname')]
# Parsed name: [('Patrick', 'GivenName'), ('Studer', 'Surname')]
# Parsed name: [('Giuliana', 'GivenName'), ('Tedesco', 'Surname')]
# Parsed name: [('Holger', 'GivenName'), ('Reinking', 'Surname')]
# Parsed name: [('maria-dolores', 'CorporationName'), ('lopez-germano', 'CorporationName')]
# Parsed name: [('Aydin', 'GivenName'), ('Sar', 'Surname')]
# Parsed name: [('Julio', 'GivenName'), ('Anivaro', 'Surname')]
# Parsed name: [('Laurent', 'GivenName'), ('Schaffter', 'Surname')]
# Parsed name: [('Stefanie', 'GivenName'), ('Schmid', 'Surname')]
# Parsed name: [('Jean-Charles', 'CorporationName'), ('Petignat', 'CorporationName')]
# Parsed name: [('Alban', 'CorporationName'), ('Suljevic', 'CorporationName')]
# Parsed name: [('Andreas', 'GivenName'), ('Gössnitzer', 'Surname')]
# Parsed name: [('Martine', 'GivenName'), ('Partouche', 'MiddleName')]
# Parsed name: [('Karim', 'CorporationName'), ('Abdus', 'CorporationName'), ('Salam', 'CorporationName'), ('Subhan', 'CorporationName')]
# Parsed name: [('Hugh', 'GivenName'), ('Reeves', 'Surname')]
# Parsed name: [('Sarah', 'GivenName'), ('Emonet', 'Surname')]
# Parsed name: [('damien', 'GivenName'), ('briet', 'Surname')]
# Parsed name: [('Kerim', 'GivenName'), ('Rozajac', 'Surname')]
# Parsed name: [('Roger', 'GivenName'), ('Müller', 'Surname')]
# ...
# Parsed name: [('Hans', 'GivenName'), ('Huggler', 'Surname')]
# Parsed name: [('Lukas', 'GivenName'), ('Störi', 'Surname')]
# Parsed name: [('Elizabeth', 'GivenName'), ('Niehaus', 'Surname')]
# Parsed name: [('Denise', 'GivenName'), ('Tanner', 'Surname')]
# Parsed name: [('Patrick', 'GivenName'), ('Meier', 'Surname')]
# Parsed name: [('Alice', 'GivenName'), ('Aganmennone', 'Surname')]
# Parsed name: [('Manuel', 'GivenName'), ('Gangel', 'Surname')]
# Parsed name: [('Andrea', 'GivenName'), ('Paradiso', 'Surname')]
# Parsed name: [('Andreas', 'GivenName'), ('Schneider', 'Surname')]
# Parsed name: [('David', 'GivenName'), ('Hawellek', 'Surname')]
# Parsed name: [('Serena', 'GivenName'), ('Carlino', 'Surname')]
# Parsed name: [('Isabelle', 'GivenName'), ('Hadji', 'Surname')]
# Parsed name: [('Thomas', 'GivenName'), ('Hobi', 'Surname')]
# Parsed name: [('Dario', 'GivenName'), ('Portmann', 'Surname')]
# Parsed name: [('Andreas', 'GivenName'), ('Züblin', 'Surname')]
# Parsed name: [('Cyrille', 'CorporationName'), ('robert', 'CorporationName')]
# Parsed name: [('Evelyn', 'GivenName'), ('Lanz', 'Surname')]
# Parsed name: [('Hans', 'CorporationName'), ('Rudolf', 'CorporationName'), ('Gräf', 'CorporationName')]
# Parsed name: [('David', 'GivenName'), ('Gonzalez', 'Surname'), ('Molina', 'Surname')]
# Parsed name: [('René', 'GivenName'), ('Jaquet', 'Surname')]
# Parsed name: [('Marc', 'GivenName'), ('Zihlmann', 'Surname')]
# Parsed name: [('Philippe', 'CorporationName'), ('Degen', 'CorporationName')]
# Parsed name: [('Dominik', 'GivenName'), ('Schwerzmann', 'Surname')]
# Parsed name: [('Veronica', 'GivenName'), ('Wolf', 'Surname')]
# Parsed name: [('Julia', 'GivenName'), ('Söchtig', 'Surname')]
# Parsed name: [('David', 'GivenName'), ('Vulliez', 'Surname')]
# Parsed name: [('patrick', 'GivenName'), ('verdon', 'Surname')]
# Parsed name: [('Patricia', 'GivenName'), ('Garcia', 'Surname')]
# Parsed name: [('Johannes', 'CorporationName'), ('Marschner', 'CorporationName')]
# Parsed name: [('Marcel', 'GivenName'), ('Ginter', 'Surname')]
# Parsed name: [('Dario', 'GivenName'), ('Nussbaumer', 'Surname')]
# Parsed name: [('Michael', 'CorporationName'), ('Fruet', 'CorporationName')]
# Parsed name: [('Julien', 'CorporationName'), ('Mattenet', 'CorporationName')]
# Parsed name: [('Fabian', 'GivenName'), ('Schaedler', 'Surname')]
# Parsed name: [('Edouard', 'GivenName'), ('Percy', 'Surname')]
# Parsed name: [('Galbusera', 'GivenName'), ('Mattia', 'Surname')]
# Parsed name: [('Thomas', 'GivenName'), ('Zürcher', 'Surname')]
# Parsed name: [('Pascal', 'GivenName'), ('Witprächtiger', 'Surname')]
# Parsed name: [('Goetz', 'GivenName'), ('Ardey', 'Surname')]
# Parsed name: [('Rémi', 'GivenName'), ('Lang', 'Surname')]
# Parsed name: [('Kilian', 'GivenName'), ('Bäbler', 'Surname')]
# Parsed name: [('Yann-Guillaume', 'GivenName'), ('Jaccard', 'Surname')]
# Parsed name: [('Lutz', 'CorporationName'), ('von', 'CorporationName'), ('Strauss', 'CorporationName'), ('und', 'CorporationName'), ('Torney', 'CorporationName')]
# Parsed name: [('Margherita', 'GivenName'), ('Morotti', 'Surname')]
# Parsed name: [('Julio', 'GivenName'), ('Andrade', 'Surname')]
# Parsed name: [('Michela', 'GivenName'), ('Ventre', 'Surname')]
# Parsed name: [('Lars', 'CorporationName'), ('Brand', 'CorporationName')]
# Parsed name: [('Vincent', 'GivenName'), ('Joliat', 'Surname')]
# Parsed name: [('Tauland', 'CorporationName'), ('Arslani', 'CorporationName')]
# Parsed name: [('Claudia', 'GivenName'), ('Rehm', 'Surname')]
# Parsed name: [('Pascal', 'GivenName'), ('Eicher', 'Surname')]
# Parsed name: [('Raphael', 'GivenName'), ('Juillerat', 'Surname')]
# Parsed name: [('Patrick', 'GivenName'), ('Kämpfer', 'Surname')]
# Parsed name: [('Miguel', 'GivenName'), ('Sabino', 'Surname')]
# Parsed name: [('Renato', 'GivenName'), ('Solomita', 'Surname')]
# Parsed name: [('Alexa', 'GivenName'), ('Bezel', 'Surname')]
# Parsed name: [('Ben', 'GivenName'), ('Baczynski', 'Surname')]
# Parsed name: [('Daniel', 'GivenName'), ('Fiechter', 'Surname')]
# Parsed name: [('Benjamin', 'GivenName'), ('Schneck', 'Surname')]
# Parsed name: [('KATHRIN', 'GivenName'), ('URSCHELER', 'Surname')]
# Parsed name: [('Jörg-Ulrich', 'GivenName'), ('Fohrer', 'Surname')]
# Parsed name: [('David', 'GivenName'), ('Strasmann', 'Surname')]
# Parsed name: [('Siegfried', 'GivenName'), ('Feenstra', 'Surname')]
# Parsed name: [('Norbert', 'GivenName'), ('Strub', 'Surname')]
# Parsed name: [('Serge', 'GivenName'), ('Campana', 'Surname')]
# Parsed name: [('laurent', 'GivenName'), ('sobota', 'Surname')]
# Parsed name: [('Diana', 'GivenName'), ('Otth', 'Surname')]
# Parsed name: [('Melanie', 'GivenName'), ('Ridoli', 'Surname')]
# Parsed name: [('Federico', 'GivenName'), ('Pagliarini', 'Surname')]
# Parsed name: [('Reto', 'GivenName'), ('Hunziker', 'Surname')]
# Parsed name: [('Hans', 'GivenName'), ('Peter', 'MiddleName'), ('Munz', 'Surname')]
# Parsed name: [('Marc', 'GivenName'), ('Kleinferchner', 'Surname')]
# Parsed name: [('Franz', 'Surname'), ('Brunner', 'Surname')]
# Parsed name: [('Maurizio', 'GivenName'), ('Gullo', 'Surname')]
# Parsed name: [('Rolf', 'GivenName'), ('Joss', 'Surname')]
# Parsed name: [('Manuel', 'GivenName'), ('Ruchti', 'Surname')]
# Parsed name: [('Regula', 'GivenName'), ('Zingg', 'Surname')]
# Parsed name: [('Marcel', 'CorporationName'), ('Spirig', 'CorporationName')]
# Parsed name: [('Antonia', 'GivenName'), ('Waber', 'Surname')]
# Parsed name: [('Raffaella', 'GivenName'), ('Costanzo', 'Surname')]
# Parsed name: [('Nicolas', 'GivenName'), ('Horner', 'Surname')]
# Parsed name: [('Jason', 'GivenName'), ('Tanner', 'Surname')]
# Parsed name: [('Joel', 'CorporationName'), ('De', 'CorporationName'), ('Sousa', 'CorporationName'), ('Vendeiro', 'CorporationName'), ('Silva', 'CorporationName')]
# Parsed name: [('Sami', 'GivenName'), ('Hafsi', 'Surname')]
# Parsed name: [('Sebastian', 'GivenName'), ('Hurter', 'Surname')]
# Parsed name: [('Neil', 'GivenName'), ('Tennant', 'Surname')]
# Parsed name: [('severin', 'CorporationName'), ('clauss', 'CorporationName')]
# Parsed name: [('Mariano', 'GivenName'), ('Schneeberger', 'Surname')]
# Parsed name: [('Julian', 'GivenName'), ('Oester', 'Surname')]
# Parsed name: [('Severin', 'CorporationName'), ('Suter', 'CorporationName')]
# Parsed name: [('Björn', 'GivenName'), ('van', 'GivenName'), ('Steenoven', 'Surname')]
# Parsed name: [('Gabriel', 'GivenName'), ('Burger', 'Surname')]
# Parsed name: [('Daniela', 'GivenName'), ('Schein', 'Surname')]
# Parsed name: [('Andreas', 'GivenName'), ('Wyniger', 'Surname')]
# Parsed name: [('Samuel', 'GivenName'), ('Sigrist', 'Surname')]
# Parsed name: [('Dominik', 'GivenName'), ('Noger', 'Surname')]
# Parsed name: [('Stephan', 'GivenName'), ('Nanz', 'Surname')]
# Parsed name: [('Alain', 'CorporationName'), ('Robert-Tissot', 'CorporationName')]
# Parsed name: [('Erhard', 'GivenName'), ('Luginbühl', 'Surname')]
# Parsed name: [('Philip', 'GivenName'), ('Stober', 'Surname')]
# Parsed name: [('Petra', 'GivenName'), ('Jenny', 'Surname')]
# Parsed name: [('Bürki', 'CorporationName'), ('Marcel', 'CorporationName')]
# Parsed name: [('Alex', 'GivenName'), ('Willener', 'Surname')]
# Parsed name: [('Maurizio', 'GivenName'), ('Beltrami', 'Surname')]
# Parsed name: [('x', 'FirstInitial'), ('y', 'LastInitial')]
# Parsed name: [('Stephan', 'GivenName'), ('Hottiger', 'Surname')]
# Parsed name: [('Simon', 'GivenName'), ('Maag', 'Surname')]
# Parsed name: [('Alfonso', 'GivenName'), ('Di', 'Surname'), ('Dario', 'Surname')]
# Parsed name: [('Melanie', 'GivenName'), ('DellaTorre', 'Surname')]
# Parsed name: [('Nicole', 'GivenName'), ('Schindler', 'Surname')]
# Parsed name: [('Marco', 'GivenName'), ('Preiser', 'Surname')]
# Parsed name: [('Roger', 'GivenName'), ('Saladin', 'Surname')]
# Parsed name: [('Pierre', 'GivenName'), ('Jacot', 'Surname')]
# Parsed name: [('Paul', 'GivenName'), ('Albisetti', 'Surname')]
# Parsed name: []
# Parsed name: [('Jasmine', 'GivenName'), ('Huynh', 'Surname')]
# Parsed name: [('Andriy', 'GivenName'), ('Romanyuk', 'Surname')]
# Parsed name: [('Katharina', 'GivenName'), ('Beckmann', 'Surname')]
# Parsed name: [('Manuela', 'GivenName'), ('Dürig', 'Surname')]
# Parsed name: [('Basile', 'GivenName'), ('Fontaine', 'Surname')]
# Parsed name: [('Ivan', 'GivenName'), ('Manuel', 'MiddleName'), ('Gutierrez', 'Surname')]
# Parsed name: [('Ernst', 'GivenName'), ('Merz', 'Surname')]
# Parsed name: [('Silvia', 'GivenName'), ('Buchli', 'Surname')]
# Parsed name: [('Julien', 'GivenName'), ('Graf', 'Surname')]
# Parsed name: [('Manuel', 'GivenName'), ('Wyss', 'Surname')]
# Parsed name: [('Nino', 'GivenName'), ('Stauffer', 'Surname')]
# Parsed name: [('Loriano', 'GivenName'), ('Lorini', 'Surname')]
# Parsed name: [('Martin', 'GivenName'), ('Caspar', 'Surname')]
# Parsed name: [('LUCIEN', 'GivenName'), ('moutarlier', 'Surname')]
# Parsed name: [('Christian', 'GivenName'), ('Gubser', 'Surname')]
# Parsed name: [('Anupama', 'GivenName'), ('Fraknlin', 'Surname')]
# Parsed name: [('Yuri', 'GivenName'), ('Loen', 'Surname')]
# Parsed name: [('Jacqueline', 'GivenName'), ('Sturzenegger', 'Surname')]
# Parsed name: [('Nicola', 'GivenName'), ('Nussbaumer', 'Surname')]
# Parsed name: [('Christoph', 'GivenName'), ('Kupper', 'Surname')]
# Parsed name: [('Mike', 'GivenName'), ('Wieland', 'Surname')]
# Parsed name: [('Olaf', 'CorporationName'), ('Meincke', 'CorporationName')]
# Parsed name: [('Leo', 'GivenName'), ('Päffgen', 'Surname')]
# Parsed name: [('Isabelle', 'GivenName'), ('Bürgler', 'Surname')]
# Parsed name: [('Reinhold', 'GivenName'), ('Messmer', 'Surname')]
# Parsed name: [('David', 'GivenName'), ('Geiger', 'Surname')]
# Parsed name: [('Alma', 'GivenName'), ('Valens', 'Surname'), ('Sàrl', 'SuffixOther')]
# Parsed name: [('Roosembert', 'GivenName'), ('Palacios', 'Surname')]
# Parsed name: [('Marcel', 'GivenName'), ('Kaltenbrunner', 'Surname')]
# Parsed name: [('Luigi', 'GivenName'), ('Astorri', 'Surname')]
# Parsed name: [('Philippe', 'CorporationName'), ('Zesiger', 'CorporationName')]
# Parsed name: [('Procurement', 'CorporationName'), ('team', 'CorporationName')]
# Parsed name: [('Jürg', 'GivenName'), ('Zingg', 'Surname')]
# Parsed name: [('Andreas', 'GivenName'), ('Schmid', 'Surname')]
# Parsed name: [('Rico', 'GivenName'), ('Zemp', 'Surname')]
# Parsed name: [('Monika', 'GivenName'), ('Stampfli', 'Surname')]
# Parsed name: [('Daniel', 'GivenName'), ('Jost', 'Surname')]
# Parsed name: [('Thomas', 'GivenName'), ('Kindler', 'Surname')]
# Parsed name: [('Roland', 'CorporationName'), ('Ilg', 'CorporationName')]
# Parsed name: [('Andreas', 'GivenName'), ('Marte', 'Surname')]
# Parsed name: [('Lea', 'GivenName'), ('Voss', 'Surname')]
# Parsed name: [('Marco', 'GivenName'), ('Huwiler', 'Surname')]
# Parsed name: [('Annatina', 'GivenName'), ('Blaser', 'Surname')]
# Parsed name: []
# Parsed name: [('Martin', 'GivenName'), ('Kneifel', 'Surname')]
# Parsed name: [('Ryan', 'GivenName'), ('David', 'MiddleName'), ('Joseph', 'Surname')]
# Parsed name: [('Pascal', 'CorporationName'), ('Michel', 'CorporationName')]
# Parsed name: [('Georg', 'GivenName'), ('Heutschi', 'Surname')]
# Parsed name: [('Brigitte', 'GivenName'), ('Gallati', 'Surname')]
# Parsed name: [('Bruno', 'CorporationName'), ('Micael', 'CorporationName'), ('Simões', 'CorporationName'), ('dos', 'CorporationName'), ('Santos', 'CorporationName')]
# Parsed name: [('Stefan', 'GivenName'), ('Wanner', 'Surname')]
# Parsed name: [('Jürg', 'GivenName'), ('Huber', 'Surname')]
# Parsed name: [('Corinne', 'GivenName'), ('Leu', 'Surname')]
# Parsed name: [('Veronica', 'GivenName'), ('Savu', 'Surname')]
# Parsed name: [('Adrian', 'GivenName'), ('Watney', 'Surname')]
# Parsed name: [('Dylan', 'GivenName'), ('James', 'MiddleName'), ('Barclay', 'Surname')]
# Parsed name: [('Pascal', 'CorporationName'), ('Houlmann', 'CorporationName')]
# Parsed name: []
# Parsed name: [('Sasa', 'GivenName'), ('Jovic', 'Surname')]
# Parsed name: [('Marko', 'GivenName'), ('Juricic', 'Surname')]
# Parsed name: [('Fabian', 'GivenName'), ('Grunder', 'Surname')]
# Parsed name: [('laurent', 'GivenName'), ('Calame', 'Surname')]
# Parsed name: [('Leonid', 'CorporationName'), ('Matveev', 'CorporationName')]
# Parsed name: [('Jean-François', 'GivenName'), ('Auger', 'Surname')]
# Parsed name: [('Walter', 'GivenName'), ('Sonnenfeldt', 'Surname')]
# Parsed name: [('jonas', 'GivenName'), ('buehler', 'Surname')]
# Parsed name: [('Olivier', 'GivenName'), ('Fritschi', 'Surname')]
# Parsed name: [('Jan', 'GivenName'), ('Pieter', 'MiddleName'), ('Gorter', 'Surname')]
# Parsed name: [('John', 'GivenName'), ('Derksen', 'Surname')]
# Parsed name: [('Philipp', 'GivenName'), ('Werner', 'Surname')]
# Parsed name: [('Michal', 'GivenName'), ('Jirku', 'Surname')]
# Parsed name: [('Philipp', 'CorporationName'), ('Purtschert', 'CorporationName')]
# Parsed name: [('Claudia', 'GivenName'), ('Tomasini', 'Surname')]
# Parsed name: [('Ettore', 'GivenName'), ('Ferranti', 'Surname')]
# Parsed name: [('Janik', 'GivenName'), ('Meier', 'Surname')]
# Parsed name: [('Michael', 'GivenName'), ('Gniffke', 'Surname')]
# Parsed name: [('Nicolas', 'GivenName'), ('Berthold', 'Surname')]
# Parsed name: [('Oliver', 'GivenName'), ('Scotoni', 'Surname')]
# Parsed name: [('Christian', 'GivenName'), ('Balmer', 'Surname')]
# Parsed name: [('Rahel', 'GivenName'), ('Aeschlimann', 'Surname')]
# Parsed name: [('Rico', 'GivenName'), ('Manuel', 'GivenName'), ('Keller', 'Surname')]
# Parsed name: [('Jan', 'GivenName'), ('Bietenholz', 'Surname')]
# Parsed name: [('Nicolas', 'GivenName'), ('Vieux', 'Surname')]
# Parsed name: [('Simon', 'GivenName'), ('Hockenhull', 'Surname')]
# Parsed name: [('Cyril-Marc', 'CorporationName'), ('AMBERGER', 'CorporationName')]
# Parsed name: [('Wilhelm', 'CorporationName'), ('Bögershausen', 'CorporationName')]
# Parsed name: [('Florian', 'GivenName'), ('Faust', 'Surname')]
# Parsed name: [('Philip', 'GivenName'), ('Schilling', 'Surname')]
# Parsed name: [('Nadine', 'GivenName'), ('Holzer', 'Surname')]
# Parsed name: [('Aydin', 'GivenName'), ('Kurt-Elli', 'Surname')]
# Parsed name: [('Daniel', 'GivenName'), ('Lüscher', 'Surname')]
# Parsed name: [('Frédéric', 'GivenName'), ('Baudin', 'Surname')]
# Parsed name: [('Fabian', 'GivenName'), ('Blust', 'Surname')]
# Parsed name: [('Roberto', 'GivenName'), ('Benico', 'Surname')]
# Parsed name: [('Cédric', 'CorporationName'), ('Germiquet', 'CorporationName')]
# Parsed name: [('Dominic', 'GivenName'), ('Frank', 'MiddleName'), ('Suter', 'Surname')]
# Parsed name: [('Pierre', 'GivenName'), ('Mall', 'Surname')]
# Parsed name: [('Nicolas', 'GivenName'), ('Stöcklin', 'Surname')]
# Parsed name: [('Alexander', 'GivenName'), ('BONDARENKO', 'Surname')]
# Parsed name: [('Alan', 'GivenName'), ('Arkula', 'Surname')]
# Parsed name: [('Elisa', 'GivenName'), ('Nannini', 'Surname')]
# Parsed name: [('Markus', 'GivenName'), ('Ammann', 'Surname')]
# Parsed name: [('Roksoliana', 'GivenName'), ('Bilovus', 'Surname')]
# Parsed name: [('Flavio', 'GivenName'), ('Ghislini', 'Surname')]
# Parsed name: [('Franco', 'GivenName'), ('Tonizzo', 'Surname')]
# Parsed name: [('anna', 'GivenName'), ('munz', 'Surname')]
# Parsed name: [('Dijana', 'GivenName'), ('Paunovic', 'Surname')]
# Parsed name: [('Dominique', 'GivenName'), ('Oudakker', 'Surname')]
# Parsed name: []
# Parsed name: [('Thomas', 'GivenName'), ('Fesenmeier', 'Surname')]
# Parsed name: [('Daniel', 'GivenName'), ('Müller', 'Surname')]
# Parsed name: [('Felix', 'GivenName'), ('Ammann', 'Surname')]
# Parsed name: [('Lorena', 'GivenName'), ('Teixeira', 'Surname')]
# Parsed name: [('Yvonne', 'GivenName'), ('Gross', 'Surname')]
# Parsed name: [('Anton', 'GivenName'), ('Rubi', 'Surname')]
# Parsed name: [('Denis', 'GivenName'), ('Amzaj', 'Surname')]
# Parsed name: [('Markus', 'GivenName'), ('Ehrmann', 'Surname')]
# Parsed name: [('Bernhard', 'GivenName'), ('Fehr', 'Surname')]
# Parsed name: [('Saman', 'GivenName'), ('Handschin', 'Surname')]
# Parsed name: [('Sandy', 'GivenName'), ('Grandjean', 'Surname')]
# Parsed name: [('Jonathan', 'GivenName'), ('Merenda', 'Surname')]
# Parsed name: [('David', 'GivenName'), ('Deslarzes', 'Surname')]
# Parsed name: [('Ivan', 'GivenName'), ('Schmid', 'Surname')]
# Parsed name: [('Mustafa', 'GivenName'), ('Tuskan', 'Surname')]
# Parsed name: [('Mathieu', 'GivenName'), ('Raoux', 'Surname')]
# Parsed name: [('Eric', 'GivenName'), ('Freienstein', 'Surname')]
#
# Total incorrect names: 585

# %%
columns_to_keep = ["ReferenceID", "Name_original", "Objekt_link"]
df_personen[df_personen["Name_incorrect"] == True][columns_to_keep].to_excel("data/calculated/personen_with_incorrect_name_order.xlsx", engine="openpyxl", index=False)

# %% [markdown]
# ## Spacy

# %%
import spacy

# Load the larger multilingual model
nlp = spacy.load("xx_sent_ud_sm")

def check_name_order(name):
    doc = nlp(name)
    tokens = [token for token in doc]
    
    if len(tokens) < 2:
        print(f"Warning: Not enough name parts for '{name}'")
        return False
    
    # Check if the first token is more likely to be a last name
    first_token = tokens[0]
    last_token = tokens[-1]
    
    factors = 0
    
    # 1. Capitalization (all caps more likely for last names)
    if first_token.text.isupper():
        factors += 1
    
    # 2. Length (last names tend to be longer)
    if len(first_token.text) > len(last_token.text):
        factors += 1
    
    # 3. Part-of-speech tag (proper nouns are more likely to be last names)
    if first_token.pos_ == "PROPN" and last_token.pos_ != "PROPN":
        factors += 1
    
    # 4. Check for common first name prefixes
    common_first_name_prefixes = ['van', 'von', 'de', 'du', 'di', 'da']
    if any(name.lower().startswith(prefix) for prefix in common_first_name_prefixes):
        factors -= 1
    
    # 5. Check for common last name suffixes
    common_last_name_suffixes = ['jr', 'sr', 'ii', 'iii', 'iv']
    if any(name.lower().endswith(suffix) for suffix in common_last_name_suffixes):
        factors -= 1
    
    # Consider the name incorrect if more factors suggest the first token is a last name
    return factors >= 2

# First, install the new model:
# !python -m spacy download xx_sent_ud_sm

# Apply the function to the first few rows for testing
for name in df_personen['Name_original'].head(10):
    result = check_name_order(name)
    print(f"Name: {name}, Incorrect: {result}")

# Apply to the whole dataset
df_personen['Name_incorrect'] = df_personen['Name_original'].apply(check_name_order)

print("\nTotal incorrect names:", df_personen['Name_incorrect'].sum())

# %%
columns_to_keep = ["ReferenceID", "Name_original", "Objekt_link"]
df_personen[df_personen["Name_incorrect"] == True][columns_to_keep].to_excel("data/calculated/personen_with_incorrect_name_order.xlsx", engine="openpyxl", index=False)

# %%
df_personen[df_personen["Name_incorrect"] == True]
# Out:
#                                 ReferenceID                Objekt  \
# 371    07086432-D904-46A1-87B0-F38D3EC51630       PETER BERGKVIST
# 427    081F5A0C-7419-4F55-A2C3-1B0B0CB2D395          WEISS STEFAN
# 1668   1D40C0FE-E31B-4EBE-9562-1F6BE72A2CB6          NIBA TERENCE
# 1768   1F1627A0-2143-4F70-A2BA-D87B96C8DE12     CARLIER BENEDICTE
# 2902   3272CFC1-1D6F-4B05-834B-67A53E11C733          IMMER FRANCK
# 3014   343FAD0C-3DC8-4D7D-A093-9F788D9F8F04       KREBS GENEVIEVE
# 3549   3E3C4FF2-7683-477B-948C-14CA02712EE0      Gionata PEDRETTI
# 3824   4307B927-13F0-488C-BFA9-DDBA419A97EA          BADEL NADINE
# 4583   4FE692E3-7085-4CAC-A60F-7CA4C628F632     BUGNON CHRISTOPHE
# 4782   5312d6ec-f4ec-4374-8af7-3df3e7a243ed  SONI RAJKUMAR JAIRAM
# 6526   716022B7-76DB-467B-8AC6-07BAA511E24F          VALLI NICOLA
# 6719   74EEC149-B509-4E67-93B4-19F42A9A5677       KOREN ALEXANDER
# 7444   8164AA84-EC0B-4BC8-AA10-03288C4A4141           HUMM PIERRE
# 7570   838E84DF-85CF-4C1B-9BDB-E01B2FBD255D           COL RICHARD
# 7934   89B3551E-B02A-4D01-8A56-43242457FE06      PICCOT SEBASTIEN
# 8006   8B37BCE8-2A2A-4E68-A0C1-DD73BC160ADA            DAIF NADIA
# 8382   91682190-E266-4BC2-BA8F-E051C18BF7D4            ER HÜSEYIN
# 8719   9714D5DC-FD02-4DA6-8D19-52AF5433238B          JEAN JONESCO
# 8987   9BC63E4B-30A0-45B8-9FAE-2FFC0AF6929F  CHEVASSUS CHRISTOPHE
# 9339   A192C5D0-D979-4A75-AD1F-11D4356CFF93         VALLI NICOLAS
# 9355   A1F15E2B-53B5-4247-87AB-02591B22D519        FIODOR MATEUSZ
# 10259  B3668677-C007-4BE2-B8C1-78FEFE38B8A6       ZAROUL MOHAMMED
# 10645  BB263C6C-72BC-45F5-9F45-213395A16E5E         CEP AG CEP AG
# 11935                 CONTACT_PERSON#695940        JOLIN STEPHANE
# 11979                 CONTACT_PERSON#706389          MBAYE LAMINE
# 19442               CUSTOMER_PRIVATE#611416     TESTS BAKOMONLINE
# 22736               CUSTOMER_PRIVATE#649437         SANER YOLANDA
# 25569               CUSTOMER_PRIVATE#681894            AG PATLICO
# 36148  D99D1663-24F2-4B48-9DD1-DDE6B81E2101          MOSER MARKUS
# 36178  DA2D4F81-39B4-46AA-8A32-3A302CFEEA4E        CLERC FRANCOIS
# 37322  EE5458AB-7249-4CB3-946A-CF62BF533E5A       KAMARA HAGUEDIO
# 37792  F7296F25-0FBD-4B12-9385-A13D705C760F       ROMANO MARCELLO
# 38106  FD59E437-C578-474D-BD75-729FD5D209E1    PIEVE AMELIA MARIA
#
#                        Name     Typ  Aktiv           UID_CHID  Zeile2  \
# 371         bergkvist peter  Person   True                        NaN
# 427            stefan weiss  Person   True            5485940     NaN
# 1668           terence niba  Person   True                        NaN
# 1768      benedicte carlier  Person   True                        NaN
# 2902           franck immer  Person   True                        NaN
# 3014        genevieve krebs  Person   True                        NaN
# 3549       pedretti gionata  Person   True                        NaN
# 3824           nadine badel  Person   True                        NaN
# 4583      christophe bugnon  Person   True  NotRegisteredCHId     NaN
# 4782   rajkumar jairam soni  Person   True           11563752     NaN
# 6526           nicola valli  Person   True            4683838     NaN
# 6719        alexander koren  Person   True  NotRegisteredCHId     NaN
# 7444            pierre humm  Person   True                        NaN
# 7570            richard col  Person   True                        NaN
# 7934       sebastien piccot  Person   True                        NaN
# 8006             nadia daif  Person   True  NotRegisteredCHId     NaN
# 8382             hüseyin er  Person   True  NotRegisteredCHId     NaN
# 8719           jonesco jean  Person   True                        NaN
# 8987   christophe chevassus  Person   True                        NaN
# 9339          nicolas valli  Person   True                        NaN
# 9355         mateusz fiodor  Person   True            7840925     NaN
# 10259       mohammed zaroul  Person   True  NotRegisteredCHId     NaN
# 10645         cep ag cep ag  Person   True            8625429     NaN
# 11935        stephane jolin  Person   True           10207978     NaN
# 11979          lamine mbaye  Person   True  NotRegisteredCHId     NaN
# 19442     bakomonline tests  Person   True  NotRegisteredCHId     NaN
# 22736         yolanda saner  Person   True  NotRegisteredCHId     NaN
# 25569            patlico ag  Person   True  NotRegisteredCHId     NaN
# 36148          markus moser  Person   True                        NaN
# 36178        francois clerc  Person   True                        NaN
# 37322       haguedio kamara  Person   True            8211176     NaN
# 37792       marcello romano  Person   True                        NaN
# 38106    amelia maria pieve  Person   True                        NaN
#
#        Zeile2Laenge  Zeile3  Zeile3Laenge  ...  \
# 371               0     NaN             0  ...
# 427               0     NaN             0  ...
# 1668              0     NaN             0  ...
# 1768              0     NaN             0  ...
# 2902              0     NaN             0  ...
# 3014              0     NaN             0  ...
# 3549              0     NaN             0  ...
# 3824              0     NaN             0  ...
# 4583              0     NaN             0  ...
# 4782              0     NaN             0  ...
# 6526              0     NaN             0  ...
# 6719              0     NaN             0  ...
# 7444              0     NaN             0  ...
# 7570              0     NaN             0  ...
# 7934              0     NaN             0  ...
# 8006              0     NaN             0  ...
# 8382              0     NaN             0  ...
# 8719              0     NaN             0  ...
# 8987              0     NaN             0  ...
# 9339              0     NaN             0  ...
# 9355              0     NaN             0  ...
# 10259             0     NaN             0  ...
# 10645             0     NaN             0  ...
# 11935             0     NaN             0  ...
# 11979             0     NaN             0  ...
# 19442             0     NaN             0  ...
# 22736             0     NaN             0  ...
# 25569             0     NaN             0  ...
# 36148             0     NaN             0  ...
# 36178             0     NaN             0  ...
# 37322             0     NaN             0  ...
# 37792             0     NaN             0  ...
# 38106             0     NaN             0  ...
#
#                                            Produkt_RefID Geschaeftspartner  \
# 371                                                   []                []
# 427                                                   []                []
# 1668                                                  []                []
# 1768                                                  []                []
# 2902                                                  []                []
# 3014                                                  []                []
# 3549                                                  []                []
# 3824                                                  []                []
# 4583                                                  []                []
# 4782                                                  []                []
# 6526                                                  []                []
# 6719                                                  []                []
# 7444                                                  []                []
# 7570                                                  []                []
# 7934                                                  []                []
# 8006                                                  []                []
# 8382                                                  []                []
# 8719                                                  []                []
# 8987                                                  []                []
# 9339                                                  []                []
# 9355                                                  []                []
# 10259                                                 []                []
# 10645                                                 []                []
# 11935  [02AF8B93-433D-40CA-9DD4-D1E4BEEA6DE3, 5B96038...                []
# 11979                                                 []                []
# 19442                                                 []                []
# 22736                                                 []                []
# 25569                                                 []                []
# 36148                                                 []                []
# 36178                                                 []                []
# 37322                                                 []                []
# 37792                                                 []                []
# 38106                                       [1000388000]                []
#
#       Verknuepfungsart_list           VerknuepftesObjekt_list  \
# 371           [Mitarbeiter]                         [Telavox]
# 427         [Administrator]                   [FixTrade GmbH]
# 1668          [Mitarbeiter]             [Crédit Populaire SA]
# 1768                     []                                []
# 2902          [Mitarbeiter]                     [DIALARME SA]
# 3014          [Mitarbeiter]                 [Krebs Geneviève]
# 3549          [Mitarbeiter]  [Ordine dei Veterinari Ticinesi]
# 3824          [Mitarbeiter]                 [Coris - N.Badel]
# 4583        [Administrator]                      [cogefin SA]
# 4782                     []                                []
# 6526        [Administrator]                    [Valli Nicola]
# 6719        [Administrator]                  [SoftwareONE AG]
# 7444          [Mitarbeiter]                   [RAJAPACK GmbH]
# 7570          [Mitarbeiter]           [TANIA DECORATION SARL]
# 7934          [Mitarbeiter]                [PIXEL CONSULTING]
# 8006        [Administrator]                          [MOBIYO]
# 8382        [Administrator]                 [Team-Umzug GmbH]
# 8719          [Mitarbeiter]                 [SPECTRA PHYSICS]
# 8987          [Mitarbeiter]                    [Five Finance]
# 9339          [Mitarbeiter]                    [Valli Nicola]
# 9355                     []                                []
# 10259       [Administrator]                      [MOZAR sàrl]
# 10645       [Administrator]                          [CEP AG]
# 11935       [Administrator]                 [AIR KING JET SA]
# 11979       [Administrator]           [Global Jet Concept SA]
# 19442                    []                                []
# 22736                    []                                []
# 25569           [Sonstiges]                      [HUBER Rolf]
# 36148         [Mitarbeiter]                    [Moser Markus]
# 36178         [Mitarbeiter]            [Laboratoire Dentaire]
# 37322                    []                                []
# 37792         [Mitarbeiter]                   [Creativeworld]
# 38106         [Mitarbeiter]              [Twenty-Nine Com SA]
#
#                     VerknuepftesObjektID_list Geschaeftspartner_list  \
# 371    [65162450-6094-431D-B5C9-E37194D5FE16]                     []
# 427    [0BDB4C3C-A52F-4B4F-B689-4B7E00C5B95E]                     []
# 1668   [1FB55C6D-6EB9-425C-A269-4AF9C5868050]                     []
# 1768                                       []                     []
# 2902   [A1C90A5C-DE9C-476F-A9F4-4704B6951821]                     []
# 3014   [26D6D9B9-1B03-40B1-8A21-4262B205D21D]                     []
# 3549   [31C30350-490B-4E9F-BA80-03CBD59C3885]                     []
# 3824   [90BF6EB4-6CF5-4348-8FA0-FFBD02B1DEF7]                     []
# 4583   [5246DB59-4584-42E8-8F44-C013F522565A]                     []
# 4782                                       []                     []
# 6526   [52DA86B8-5FF3-4BA7-BFA7-D00B3D04977F]                     []
# 6719   [0D1D2EC6-DDDC-44F5-9ADB-B944B87B06EB]                     []
# 7444   [D74C99AC-E00C-4262-BB80-FAECDEDE8EA3]                     []
# 7570   [C417D91F-18FB-4C9E-929B-3198AC6BA92A]                     []
# 7934   [0617BA80-72F5-48C7-917C-C1B1030363FE]                     []
# 8006   [6BABD446-A5C9-49BB-8268-0BDF7515FCE9]                     []
# 8382   [2F2225CD-BF29-4B5D-9A77-D10A91A70AB6]                     []
# 8719   [05B6DFF4-6419-47B4-BECC-722E5B6276DE]                     []
# 8987   [18ADCF26-B456-4166-BED0-706A7A59D186]                     []
# 9339   [52DA86B8-5FF3-4BA7-BFA7-D00B3D04977F]                     []
# 9355                                       []                     []
# 10259  [A09CE9BE-8EDD-40A7-845E-F820D73C455E]                     []
# 10645  [458CD83E-2311-45E8-998B-B1F2A54A6F86]                     []
# 11935                       [CUSTOMER#587131]                     []
# 11979                       [CUSTOMER#741831]                     []
# 19442                                      []                     []
# 22736                                      []                     []
# 25569                 [CONTACT_PERSON#697003]                     []
# 36148  [B8CF4B87-7D9C-4EB8-B74F-D6AA62B408E8]                     []
# 36178  [7D6D1A5B-5A84-4CE1-B770-C3C9A303D0C7]                     []
# 37322                                      []                     []
# 37792  [39B25C90-A054-43C1-91C4-A07E06784EA4]                     []
# 38106  [E7602205-D418-424B-AAF2-0E6320622606]                     []
#
#       UID_CHID_check score                                      score_details  \
# 371                0    50                                Verknuepfungsart 50
# 427                2   390  Geschaeftsobjekte 60, UID 100, Verknuepfungsar...
# 1668               0    50                                Verknuepfungsart 50
# 1768               0    30                               Geschaeftsobjekte 30
# 2902               0    50                                Verknuepfungsart 50
# 3014               0    50                                Verknuepfungsart 50
# 3549               0    60               Verknuepfungsart 50, ObjektZeiger 10
# 3824               0    50                                Verknuepfungsart 50
# 4583               1   180  UID 50, Verknuepfungsart 100, ObjektZeiger 10,...
# 4782               2   210                  UID 100, Versandart 100, Email 10
# 6526               2   710  Geschaeftsobjekte 300, UID 100, Verknuepfungsa...
# 6719               1   190  UID 50, Verknuepfungsart 100, ObjektZeiger 20,...
# 7444               0    80               Verknuepfungsart 50, ObjektZeiger 30
# 7570               0    50                                Verknuepfungsart 50
# 7934               0   120               Verknuepfungsart 50, ObjektZeiger 70
# 8006               1   210  UID 50, Verknuepfungsart 100, ObjektZeiger 40,...
# 8382               1   170             UID 50, Verknuepfungsart 100, Email 20
# 8719               0    50                                Verknuepfungsart 50
# 8987               0    50                                Verknuepfungsart 50
# 9339               0   120               Verknuepfungsart 50, ObjektZeiger 70
# 9355               2   300  Geschaeftsobjekte 90, UID 100, Versandart 100,...
# 10259              1   170             UID 50, Verknuepfungsart 100, Email 20
# 10645              2   420  Geschaeftsobjekte 60, UID 100, Verknuepfungsar...
# 11935              2   720  Geschaeftsobjekte 150, UID 100, Verknuepfungsa...
# 11979              1   270  UID 50, Verknuepfungsart 100, Versandart 100, ...
# 19442              1   310  Geschaeftsobjekte 30, UID 50, Versandart 100, ...
# 22736              1   300  Geschaeftsobjekte 30, UID 50, Versandart 100, ...
# 25569              1   410  Geschaeftsobjekte 90, UID 50, Versandart 100, ...
# 36148              0    60               Verknuepfungsart 50, ObjektZeiger 10
# 36178              0    50                                Verknuepfungsart 50
# 37322              2   210                  UID 100, Versandart 100, Email 10
# 37792              0    50                                Verknuepfungsart 50
# 38106              0   160  Verknuepfungsart 50, ObjektZeiger 10, Produktr...
#
#       Name_incorrect
# 371             True
# 427             True
# 1668            True
# 1768            True
# 2902            True
# 3014            True
# 3549            True
# 3824            True
# 4583            True
# 4782            True
# 6526            True
# 6719            True
# 7444            True
# 7570            True
# 7934            True
# 8006            True
# 8382            True
# 8719            True
# 8987            True
# 9339            True
# 9355            True
# 10259           True
# 10645           True
# 11935           True
# 11979           True
# 19442           True
# 22736           True
# 25569           True
# 36148           True
# 36178           True
# 37322           True
# 37792           True
# 38106           True
#
# [33 rows x 53 columns]

# %%
df_personen.head()
# Out:
#                             ReferenceID           Objekt             Name  \
# 0  0000D9C7-6B29-4B1F-9FA0-3685B47682D3  Fassatoui Karim  karim fassatoui
# 1  0003c120-f044-4df6-84ef-330fb82d911e     Kramis Simon     simon kramis
# 2  0004ABC1-956E-4EFD-A6B1-EE142BE3EF09   Leplat Patrick   patrick leplat
# 3  00066A4F-0A0C-48BC-B0BF-30CBC471C1BE    Schwarz Joerg    joerg schwarz
# 4  0008BCBB-7FCE-4A26-9407-4880934BA14B    Storz Patrick    patrick storz
#
#       Typ  Aktiv           UID_CHID  Zeile2  Zeile2Laenge  Zeile3  \
# 0  Person   True                        NaN             0     NaN
# 1  Person   True                        NaN             0     NaN
# 2  Person   True                        NaN             0     NaN
# 3  Person   True                        NaN             0     NaN
# 4  Person   True  NotRegisteredCHId     NaN             0     NaN
#
#    Zeile3Laenge  ... Produkt_RefID Geschaeftspartner Verknuepfungsart_list  \
# 0             0  ...            []                []           [Sonstiges]
# 1             0  ...            []                []                    []
# 2             0  ...            []                []         [Mitarbeiter]
# 3             0  ...            []                []         [Mitarbeiter]
# 4             0  ...            []                []       [Administrator]
#
#    VerknuepftesObjekt_list               VerknuepftesObjektID_list  \
# 0        [Fassatoui Karim]  [966E1EA1-F258-4F75-A030-350CFAEEBC15]
# 1                       []                                      []
# 2         [RCI Finance SA]  [D604A8C4-A867-44F3-BE02-FE9E8FEEBC6C]
# 3  [Girgin Switzerland AG]  [AD4E87D0-A044-4AD8-8AC1-26C94A362812]
# 4       [Great Stuff GmbH]  [6436C7FD-2BCD-4692-B6DF-0908DA51D4D0]
#
#   Geschaeftspartner_list UID_CHID_check score  \
# 0                     []              0     0
# 1                     []              0   120
# 2                     []              0    50
# 3                     []              0    50
# 4                     []              1   170
#
#                             score_details Name_incorrect
# 0                                                  False
# 1        Servicerole_string 100, Email 20          False
# 2                     Verknuepfungsart 50          False
# 3                     Verknuepfungsart 50          False
# 4  UID 50, Verknuepfungsart 100, Email 20          False
#
# [5 rows x 53 columns]

# %% [markdown]
# ## Nameparser

# %%
import nameparser

def check_name_order(df):
    def parse_name(name):
        parsed_name = nameparser.HumanName(name)
        if parsed_name.first and parsed_name.last:
            if name.startswith(parsed_name.first):
                return False  # Correct order
            else:
                return True  # Incorrect order
        else:
            return True  # Unable to determine

    df['Name_incorrect'] = df['Name_original'].apply(parse_name)
    return df


df_personen = check_name_order(df_personen)

# %%
print(df_personen[['Name_original', 'Name_incorrect']].head())
# Out:
#      Name_original  Name_incorrect
# 0  Karim Fassatoui           False
# 1     Simon Kramis           False
# 2   Patrick Leplat           False
# 3    Joerg Schwarz           False
# 4    Patrick Storz           False

# %% [markdown]
# ## Transformers

# %%
# Import the necessary module
from transformers import pipeline

# Download and load the pre-trained model and tokenizer
# Note: This may take some time to download if it's the first time
nlp = pipeline("ner", model="xlm-roberta-base", tokenizer="xlm-roberta-base")

def check_name_order(df):
    def parse_name(name):
        inputs = nlp(name)
        first_names = []
        last_names = []
        for input in inputs:
            if input is not None and "entities" in input:
                for entity in input["entities"]:
                    if entity is not None and "label" in entity and entity["label"] == "PER":
                        if entity["start_position"] < len(name) / 2:
                            first_names.append(entity["word"])
                        else:
                            last_names.append(entity["word"])
        if first_names and last_names:
            return False  # Correct order
        return True  # Incorrect order or unable to determine

    df['Name_incorrect'] = df['Name_original'].apply(parse_name)
    return df

# Apply the function to df_personen
df_personen = check_name_order(df_personen)

# Print the first few rows to verify
print(df_personen[['Name_original', 'Name_incorrect']].head())

# Print the total number of incorrect names
print(f"\nTotal incorrect names: {df_personen['Name_incorrect'].sum()}")
# Out:
# Some weights of XLMRobertaForTokenClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# c:\GitRepos\Doublettenanalyse_scripts\venv\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
#      Name_original  Name_incorrect
# 0  Karim Fassatoui            True
# 1     Simon Kramis            True
# 2   Patrick Leplat            True
# 3    Joerg Schwarz            True
# 4    Patrick Storz            True
#
# Total incorrect names: 38858

# %% [markdown]
# ## GPT - API

# %%
import pandas as pd
from openai import OpenAI

api_key = 'INSERT OPENAI API KEY HERE'
client = OpenAI(api_key=api_key)

# %%
# maybe improved version
import time
import json

def check_name_order_and_company_batch(names):
    messages = [
    {"role": "system", "content": "You are a helpful assistant. Respond only with the requested format, without any additional text."},
    {"role": "user", "content": f"""For each name in this list {names}, provide three answers separated by commas:
1) The original name as provided, without any changes.
2) Is the name in correct order (first name followed by last name)? Answer 'Yes' or 'No'. Ignore capitalization when making this determination. Consider the name to be in the correct order if the first part appears to be a first name, even if there are two first names or abbreviations.
3) Is it a company name or person name? Answer 'Company' or 'Person'.
Separate each name's results with a semicolon. Do not include any other text in your response."""}
]
    
    max_retries = 3
    for attempt in range(max_retries):
        try:
            chat_completion = client.chat.completions.create(
                messages=messages,
                model="gpt-4o-2024-08-06",
                temperature=0.7,
            )
            response_text = chat_completion.choices[0].message.content.strip()
            
            # Split the response and filter out any empty results
            results = [result.split(',') for result in response_text.split(';') if result.strip()]
            
            # Ensure each result has exactly three parts
            results = [result for result in results if len(result) == 3]
            
            return results
        except Exception as e:
            if attempt < max_retries - 1:
                print(f"Error occurred: {e}. Retrying in 5 seconds...")
                time.sleep(5)
            else:
                print(f"Max retries reached. Skipping this batch.")
                return []


def process_names(df, batch_size=100, checkpoint_file='checkpoint.json'):
    results = []
    start_index = 0
    total_processed = 0

    # Load checkpoint if exists
    try:
        with open(checkpoint_file, 'r') as f:
            checkpoint = json.load(f)
        start_index = checkpoint['last_processed_index'] + 1
        results = checkpoint['results']
        total_processed = len(results)
        print(f"Resuming from index {start_index}")
    except FileNotFoundError:
        print("Starting from the beginning")

    for i in range(start_index, len(df), batch_size):
        if total_processed >= len(df):
            print("All names have been processed.")
            break

        end_index = min(i + batch_size, len(df))
        batch_names = df['Name_original'][i:end_index].tolist()
        batch_results = check_name_order_and_company_batch(batch_names)
        
        # Only add new results
        new_results = batch_results[:len(df) - total_processed]
        results.extend(new_results)
        total_processed += len(new_results)

        # Save checkpoint
        checkpoint = {
            'last_processed_index': end_index - 1,
            'results': results
        }
        with open(checkpoint_file, 'w') as f:
            json.dump(checkpoint, f)

        print(f"Processed up to index {end_index - 1}")
        time.sleep(1)  # Add a 1-second delay between batches

    return results

# Process the names
results = process_names(df_personen)


# just to be safe, store raw results
with open('output/results_gpt4o_full2.pickle', 'wb') as f:
    pickle.dump(results, f)

# Ensure results match DataFrame length
results = results[:len(df_personen)]
# Out:
# Starting from the beginning
# Processed up to index 99
# Processed up to index 199
# Processed up to index 299
# Processed up to index 399
# Processed up to index 499
# Processed up to index 599
# Processed up to index 699
# Processed up to index 799
# Processed up to index 899
# Processed up to index 999
# Processed up to index 1099
# Processed up to index 1199
# Processed up to index 1299
# Processed up to index 1399
# Processed up to index 1499
# Processed up to index 1599
# Processed up to index 1699
# Processed up to index 1799
# Processed up to index 1899
# Processed up to index 1999
# Processed up to index 2099
# Processed up to index 2199
# Processed up to index 2299
# Processed up to index 2399
# Processed up to index 2499
# Processed up to index 2599
# Processed up to index 2699
# Processed up to index 2799
# Processed up to index 2899
# Processed up to index 2999
# Processed up to index 3099
# Processed up to index 3199
# Processed up to index 3299
# Processed up to index 3399
# Processed up to index 3499
# Processed up to index 3599
# Processed up to index 3699
# Processed up to index 3799
# Processed up to index 3899
# Processed up to index 3999
# Processed up to index 4099
# Processed up to index 4199
# Processed up to index 4299
# Processed up to index 4399
# Processed up to index 4499
# Processed up to index 4599
# Processed up to index 4699
# Processed up to index 4799
# Processed up to index 4899
# Processed up to index 4999
# Processed up to index 5099
# Processed up to index 5199
# Processed up to index 5299
# Processed up to index 5399
# Processed up to index 5499
# Processed up to index 5599
# Processed up to index 5699
# Processed up to index 5799
# Processed up to index 5899
# Processed up to index 5999
# Processed up to index 6099
# Processed up to index 6199
# Processed up to index 6299
# Processed up to index 6399
# Processed up to index 6499
# Processed up to index 6599
# Processed up to index 6699
# Processed up to index 6799
# Processed up to index 6899
# Processed up to index 6999
# Processed up to index 7099
# Processed up to index 7199
# Processed up to index 7299
# Processed up to index 7399
# Processed up to index 7499
# Processed up to index 7599
# Processed up to index 7699
# Processed up to index 7799
# Processed up to index 7899
# Processed up to index 7999
# Processed up to index 8099
# Processed up to index 8199
# Processed up to index 8299
# Processed up to index 8399
# Processed up to index 8499
# Processed up to index 8599
# Processed up to index 8699
# Processed up to index 8799
# Processed up to index 8899
# Processed up to index 8999
# Processed up to index 9099
# Processed up to index 9199
# Processed up to index 9299
# Processed up to index 9399
# Processed up to index 9499
# Processed up to index 9599
# Processed up to index 9699
# Processed up to index 9799
# Processed up to index 9899
# Processed up to index 9999
# Processed up to index 10099
# Processed up to index 10199
# Processed up to index 10299
# Error occurred: Connection error.. Retrying in 5 seconds...
# Processed up to index 10399
# Processed up to index 10499
# Error occurred: Connection error.. Retrying in 5 seconds...
# Error occurred: Connection error.. Retrying in 5 seconds...
# Processed up to index 10599
# Processed up to index 10699
# Processed up to index 10799
# Processed up to index 10899
# Processed up to index 10999
# Processed up to index 11099
# Processed up to index 11199
# Processed up to index 11299
# Processed up to index 11399
# Processed up to index 11499
# Processed up to index 11599
# Processed up to index 11699
# Processed up to index 11799
# Processed up to index 11899
# Processed up to index 11999
# Processed up to index 12099
# Processed up to index 12199
# Processed up to index 12299
# Processed up to index 12399
# Processed up to index 12499
# Processed up to index 12599
# Processed up to index 12699
# Processed up to index 12799
# Processed up to index 12899
# Processed up to index 12999
# Processed up to index 13099
# Processed up to index 13199
# Processed up to index 13299
# Processed up to index 13399
# Processed up to index 13499
# Processed up to index 13599
# Processed up to index 13699
# Processed up to index 13799
# Processed up to index 13899
# Processed up to index 13999
# Processed up to index 14099
# Processed up to index 14199
# Processed up to index 14299
# Processed up to index 14399
# Processed up to index 14499
# Processed up to index 14599
# Processed up to index 14699
# Processed up to index 14799
# Processed up to index 14899
# Processed up to index 14999
# Processed up to index 15099
# Processed up to index 15199
# Processed up to index 15299
# Processed up to index 15399
# Processed up to index 15499
# Processed up to index 15599
# Processed up to index 15699
# Processed up to index 15799
# Processed up to index 15899
# Processed up to index 15999
# Processed up to index 16099
# Processed up to index 16199
# Processed up to index 16299
# Processed up to index 16399
# Processed up to index 16499
# Processed up to index 16599
# Processed up to index 16699
# Processed up to index 16799
# Processed up to index 16899
# Processed up to index 16999
# Processed up to index 17099
# Processed up to index 17199
# Processed up to index 17299
# Processed up to index 17399
# Processed up to index 17499
# Processed up to index 17599
# Processed up to index 17699
# Processed up to index 17799
# Processed up to index 17899
# Processed up to index 17999
# Processed up to index 18099
# Processed up to index 18199
# Processed up to index 18299
# Processed up to index 18399
# Processed up to index 18499
# Processed up to index 18599
# Processed up to index 18699
# Processed up to index 18799
# Processed up to index 18899
# Processed up to index 18999
# Processed up to index 19099
# Processed up to index 19199
# Processed up to index 19299
# Processed up to index 19399
# Processed up to index 19499
# Processed up to index 19599
# Processed up to index 19699
# Processed up to index 19799
# Processed up to index 19899
# Processed up to index 19999
# Processed up to index 20099
# Processed up to index 20199
# Processed up to index 20299
# Processed up to index 20399
# Processed up to index 20499
# Processed up to index 20599
# Processed up to index 20699
# Processed up to index 20799
# Processed up to index 20899
# Processed up to index 20999
# Processed up to index 21099
# Processed up to index 21199
# Processed up to index 21299
# Processed up to index 21399
# Processed up to index 21499
# Processed up to index 21599
# Processed up to index 21699
# Processed up to index 21799
# Processed up to index 21899
# Processed up to index 21999
# Processed up to index 22099
# Processed up to index 22199
# Processed up to index 22299
# Processed up to index 22399
# Processed up to index 22499
# Processed up to index 22599
# Processed up to index 22699
# Processed up to index 22799
# Processed up to index 22899
# Processed up to index 22999
# Processed up to index 23099
# Processed up to index 23199
# Processed up to index 23299
# Processed up to index 23399
# Processed up to index 23499
# Processed up to index 23599
# Processed up to index 23699
# Processed up to index 23799
# Processed up to index 23899
# Processed up to index 23999
# Processed up to index 24099
# Processed up to index 24199
# Processed up to index 24299
# Processed up to index 24399
# Processed up to index 24499
# Processed up to index 24599
# Processed up to index 24699
# Processed up to index 24799
# Processed up to index 24899
# Processed up to index 24999
# Processed up to index 25099
# Processed up to index 25199
# Processed up to index 25299
# Processed up to index 25399
# Processed up to index 25499
# Processed up to index 25599
# Processed up to index 25699
# Processed up to index 25799
# Processed up to index 25899
# Processed up to index 25999
# Processed up to index 26099
# Processed up to index 26199
# Processed up to index 26299
# Processed up to index 26399
# Processed up to index 26499
# Processed up to index 26599
# Processed up to index 26699
# Processed up to index 26799
# Processed up to index 26899
# Processed up to index 26999
# Processed up to index 27099
# Processed up to index 27199
# Processed up to index 27299
# Processed up to index 27399
# Processed up to index 27499
# Processed up to index 27599
# Processed up to index 27699
# Processed up to index 27799
# Processed up to index 27899
# Processed up to index 27999
# Processed up to index 28099
# Processed up to index 28199
# Processed up to index 28299
# Processed up to index 28399
# Processed up to index 28499
# Processed up to index 28599
# Processed up to index 28699
# Processed up to index 28799
# Processed up to index 28899
# Processed up to index 28999
# Processed up to index 29099
# Processed up to index 29199
# Processed up to index 29299
# Processed up to index 29399
# Processed up to index 29499
# Processed up to index 29599
# Processed up to index 29699
# Processed up to index 29799
# Processed up to index 29899
# Processed up to index 29999
# Processed up to index 30099
# Processed up to index 30199
# Processed up to index 30299
# Processed up to index 30399
# Processed up to index 30499
# Processed up to index 30599
# Processed up to index 30699
# Processed up to index 30799
# Processed up to index 30899
# Processed up to index 30999
# Processed up to index 31099
# Processed up to index 31199
# Processed up to index 31299
# Processed up to index 31399
# Processed up to index 31499
# Processed up to index 31599
# Processed up to index 31699
# Processed up to index 31799
# Processed up to index 31899
# Processed up to index 31999
# Processed up to index 32099
# Processed up to index 32199
# Processed up to index 32299
# Processed up to index 32399
# Processed up to index 32499
# Processed up to index 32599
# Processed up to index 32699
# Processed up to index 32799
# Processed up to index 32899
# Processed up to index 32999
# Processed up to index 33099
# Processed up to index 33199
# Processed up to index 33299
# Processed up to index 33399
# Processed up to index 33499
# Processed up to index 33599
# Processed up to index 33699
# Processed up to index 33799
# Processed up to index 33899
# Processed up to index 33999
# Processed up to index 34099
# Processed up to index 34199
# Processed up to index 34299
# Processed up to index 34399
# Processed up to index 34499
# Processed up to index 34599
# Processed up to index 34699
# Processed up to index 34799
# Processed up to index 34899
# Processed up to index 34999
# Processed up to index 35099
# Processed up to index 35199
# Processed up to index 35299
# Processed up to index 35399
# Processed up to index 35499
# Processed up to index 35599
# Processed up to index 35699
# Processed up to index 35799
# Processed up to index 35899
# Processed up to index 35999
# Processed up to index 36099
# Processed up to index 36199
# Processed up to index 36299
# Processed up to index 36399
# Processed up to index 36499
# Processed up to index 36599
# Processed up to index 36699
# Processed up to index 36799
# Processed up to index 36899
# Processed up to index 36999
# Processed up to index 37099
# Processed up to index 37199
# Processed up to index 37299
# Processed up to index 37399
# Processed up to index 37499
# Processed up to index 37599
# Processed up to index 37699
# Processed up to index 37799
# Processed up to index 37899
# Processed up to index 37999
# Processed up to index 38099
# Processed up to index 38199
# Processed up to index 38299
# Processed up to index 38399
# Processed up to index 38499
# Processed up to index 38599
# Processed up to index 38699
# Processed up to index 38799
# Processed up to index 38863

# %%
# Merge results to df_personen

# Create new columns with default values
df_personen['Name_incorrect'] = False
df_personen['Company_name'] = False

# Create a dictionary for faster lookup
name_dict = {row['Name_original'].strip(): i for i, row in df_personen.iterrows()}

# Loop through results
for result in results:
    name, order, entity_type = result
    name = name.strip()
    if name in name_dict:
        index = name_dict[name]
        df_personen.at[index, 'Name_incorrect'] = order.strip().lower() == 'no'
        df_personen.at[index, 'Company_name'] = entity_type.strip().lower() == 'company'

# After the loop, you may want to fill any remaining None values
# df_personen['Name_correct'].fillna(False, inplace=True)
# df_personen['Company_name'].fillna(False, inplace=True)

# Print some statistics to verify the results
print(f"Total names processed: {len(results)}")
print(f"Names found in DataFrame: {df_personen['Name_incorrect'].notnull().sum()}")
print(f"Incorrect names: {(df_personen['Name_incorrect']).sum()}")
print(f"Company names: {df_personen['Company_name'].sum()}")
# Out:
# Total names processed: 38861
# Names found in DataFrame: 38864
# Incorrect names: 563
# Company names: 149

# %%
df_personen_incorrect = df_personen[df_personen["Name_incorrect"] == True]
df_personen_sind_organisationen = df_personen[df_personen["Company_name"] == True]

# %%
cols_to_keep = ["ReferenceID", "Name_original", "Objekt_link", "address_full", "Versandart", "EMailAdresse", "VerknuepftesObjekt", "Verknuepfungsart", "VerknuepftesObjektID", "Produkt_rolle", "Produkt_RefID", "Geschaeftspartner", "Servicerole_string"]
# df_personen_incorrect[cols_to_keep].to_excel("output/Personen_VorNachnamen_vertauscht.xlsx", engine="openpyxl", index=False)



with pd.ExcelWriter('output/Personen_Name_checks4.xlsx', engine='openpyxl') as writer:
    df_personen_incorrect[cols_to_keep].to_excel(writer, sheet_name='Namen_vertauscht', index=False)
    df_personen_sind_organisationen[cols_to_keep].to_excel(writer, sheet_name='Organisationsnamen', index=False)

# %%
results
# Out:
# [['Karim Fassatoui', ' Yes', ' Person'],
#  [' Simon Kramis', ' Yes', ' Person'],
#  [' Patrick Leplat', ' Yes', ' Person'],
#  [' Joerg Schwarz', ' Yes', ' Person'],
#  [' Patrick Storz', ' Yes', ' Person'],
#  [' johann Frain', ' No', ' Person'],
#  [' Pedro Dias', ' Yes', ' Person'],
#  [' Paolo Ferrara', ' Yes', ' Person'],
#  [' Tobias Bichsel', ' Yes', ' Person'],
#  [' Valentin Wepfer', ' Yes', ' Person'],
#  [' Florian Vollmer', ' Yes', ' Person'],
#  [' Loris Bernardini', ' Yes', ' Person'],
#  [' Lorenzo De Pietri', ' Yes', ' Person'],
#  [' Bruno Dietrich', ' Yes', ' Person'],
#  [' Fabian Schafflützel', ' Yes', ' Person'],
#  [' Roger Geser', ' Yes', ' Person'],
#  [' KENNETH COSTANTINO', ' No', ' Person'],
#  [' Mirco Beerli', ' Yes', ' Person'],
#  [' Luca Tagli', ' Yes', ' Person'],
#  [' Jürg Rietmann', ' Yes', ' Person'],
#  [' Corinne Pfister', ' Yes', ' Person'],
#  [' Markus Keller', ' Yes', ' Person'],
#  [' Marco Furrer', ' Yes', ' Person'],
#  [' Andreas Grüner', ' Yes', ' Person'],
#  [' Sabine Schuitemaker', ' Yes', ' Person'],
#  [' Rada Boskovic', ' Yes', ' Person'],
#  [' Christelle Marclay', ' Yes', ' Person'],
#  [' bernd wagner', ' No', ' Person'],
#  [' Nicole Dechev', ' Yes', ' Person'],
#  [' Anne-Marie Dubuis', ' Yes', ' Person'],
#  [' Aida Morelli', ' Yes', ' Person'],
#  [' Martin Haller', ' Yes', ' Person'],
#  [' Michael Schirling', ' Yes', ' Person'],
#  [' Marco Villiger', ' Yes', ' Person'],
#  [' Marc Storck', ' Yes', ' Person'],
#  [' Walter Greter', ' Yes', ' Person'],
#  [' Manuela daSilva', ' Yes', ' Person'],
#  [' Claude Talaber', ' Yes', ' Person'],
#  [' Erradi El Khattab', ' Yes', ' Person'],
#  [' Jörg Becker', ' Yes', ' Person'],
#  [' Andre Hagen', ' Yes', ' Person'],
#  [' Santana Fonseca Mathieu Marineide', ' No', ' Person'],
#  [' Rainer Többicke', ' Yes', ' Person'],
#  [' Jean-Robert Oppliger', ' Yes', ' Person'],
#  [' Jeroen Hermans', ' Yes', ' Person'],
#  [' Leander Schüpfer', ' Yes', ' Person'],
#  [' Nico Zehnder', ' Yes', ' Person'],
#  [' Christof Moser', ' Yes', ' Person'],
#  [' Andrea Plieninger', ' Yes', ' Person'],
#  [' Gabriele Da Tos', ' Yes', ' Person'],
#  [' Marc Grosjean', ' Yes', ' Person'],
#  [' Boris Rapp', ' Yes', ' Person'],
#  [' Eduard Blenkers', ' Yes', ' Person'],
#  [' Doris Aebi', ' Yes', ' Person'],
#  [' Carole Croset', ' Yes', ' Person'],
#  [' Ferenc Hosszu', ' Yes', ' Person'],
#  [' Robert de Boer', ' Yes', ' Person'],
#  [' Peter Sterk', ' Yes', ' Person'],
#  [' Laurent Ducasse', ' Yes', ' Person'],
#  [' Felix Weber', ' Yes', ' Person'],
#  [' Janosch Nikolic', ' Yes', ' Person'],
#  [' Marc Nagel', ' Yes', ' Person'],
#  [' André Stoller', ' Yes', ' Person'],
#  [' arlo gonser', ' No', ' Person'],
#  [' Raphael lutz', ' No', ' Person'],
#  [' Cetin Alpan', ' Yes', ' Person'],
#  [' Lukas Häfliger', ' Yes', ' Person'],
#  [' Arben Himaj', ' Yes', ' Person'],
#  [' Christoph Kohler', ' Yes', ' Person'],
#  [' Patrick Meylan', ' Yes', ' Person'],
#  [' Graziella Chakroun-Ciglie', ' Yes', ' Person'],
#  [' Anton Wanner', ' Yes', ' Person'],
#  [' Christoph Helbling', ' Yes', ' Person'],
#  [' Stefan Sterchi', ' Yes', ' Person'],
#  [' Florentina Heer', ' Yes', ' Person'],
#  [' Redha Houari', ' Yes', ' Person'],
#  [' Aude Girod', ' Yes', ' Person'],
#  [' Krenar Kuci', ' Yes', ' Person'],
#  [' Raquel Brea', ' Yes', ' Person'],
#  [' Anastasiia Tkachova', ' Yes', ' Person'],
#  [' Ian Kaltenrieder', ' Yes', ' Person'],
#  [' Christiana Wild', ' Yes', ' Person'],
#  [' Patrick AUCHLIN', ' No', ' Person'],
#  [' Eric Schmalz', ' Yes', ' Person'],
#  [' Heinz Isken', ' Yes', ' Person'],
#  [' Hauser Kanton', ' Yes', ' Person'],
#  [' Samuel Meier', ' Yes', ' Person'],
#  [' Mark Lammert', ' Yes', ' Person'],
#  [' Silvio Kämpf', ' Yes', ' Person'],
#  [' Florian Hagen', ' Yes', ' Person'],
#  [' Kareen Martin', ' Yes', ' Person'],
#  [' Jochen Nüchter', ' Yes', ' Person'],
#  [' Ewald Struggl', ' Yes', ' Person'],
#  [' Ersin Rahimi', ' Yes', ' Person'],
#  [' Michael Glatz', ' Yes', ' Person'],
#  [' Laura Dubach', ' Yes', ' Person'],
#  [' Pauline Elisabeth Bétrisey Nanchen', ' No', ' Person'],
#  [' Joëlle Egger', ' Yes', ' Person'],
#  [' Martin Adama', ' Yes', ' Person'],
#  [' Roger Berner', ' Yes', ' Person'],
#  ['Tamara Poggiolini', ' Yes', ' Person'],
#  [' Peter Rubi', ' Yes', ' Person'],
#  [' Andrea Kalita', ' Yes', ' Person'],
#  [' François Weissmann', ' Yes', ' Person'],
#  [' Charles Jaggi', ' Yes', ' Person'],
#  [' Chevalley Chevalley', ' Yes', ' Person'],
#  [' Isabelle Voisard', ' Yes', ' Person'],
#  [' Jacqueline Perriot', ' Yes', ' Person'],
#  [' Christoph Studer', ' Yes', ' Person'],
#  [' Steven Dobson', ' Yes', ' Person'],
#  [' Urs Daniel Schmid', ' Yes', ' Person'],
#  [' Marie-Clarie Bürgy', ' Yes', ' Person'],
#  [' Elena Portmann', ' Yes', ' Person'],
#  [' Ramiz Kastrati', ' Yes', ' Person'],
#  [' Elio Benassi', ' Yes', ' Person'],
#  [' Andreas Dannmeyer', ' Yes', ' Person'],
#  [' Volkan Celebi', ' Yes', ' Person'],
#  [' Peter Weber', ' Yes', ' Person'],
#  [' Edgar Hupfer', ' Yes', ' Person'],
#  [' Evgeny Boltukhov', ' Yes', ' Person'],
#  [' Florence Corbaz', ' Yes', ' Person'],
#  [' Enrico Buchs', ' Yes', ' Person'],
#  [' Kurt Berger', ' Yes', ' Person'],
#  [' Ambre Souverain', ' Yes', ' Person'],
#  [' Daniel Kyburz', ' Yes', ' Person'],
#  [' Harold Barnes', ' Yes', ' Person'],
#  [' Jean-François Lanleau', ' Yes', ' Person'],
#  [' Andrea Beneforti', ' Yes', ' Person'],
#  [' Thomas Dantz', ' Yes', ' Person'],
#  [' Goncalo Nuno Joia', ' Yes', ' Person'],
#  [' Christoph Richner', ' Yes', ' Person'],
#  [' Monika Schmid', ' Yes', ' Person'],
#  [' Sandro Pauli', ' Yes', ' Person'],
#  [' Roland Fritschi', ' Yes', ' Person'],
#  [' Thomas Kundert', ' Yes', ' Person'],
#  [' Diana Peneva', ' Yes', ' Person'],
#  [' Markus Hatt', ' Yes', ' Person'],
#  [' Willy Bürgin', ' Yes', ' Person'],
#  [' Julian Friedli', ' Yes', ' Person'],
#  [' Nico Wild', ' Yes', ' Person'],
#  [' Martin Schuler', ' Yes', ' Person'],
#  [' dummy doublette', ' No', ' Person'],
#  [' Adrian Roth', ' Yes', ' Person'],
#  [' Mathias Tgetgel', ' Yes', ' Person'],
#  [' Allison Weber', ' Yes', ' Person'],
#  [' Ina Martinuci', ' Yes', ' Person'],
#  [' Sheila Buletti', ' Yes', ' Person'],
#  [' Muhammed Vilic', ' Yes', ' Person'],
#  [' Lukacs Attila', ' Yes', ' Person'],
#  [' Lisbeth Bühler', ' Yes', ' Person'],
#  [' Madabeni B. AG Walter Kasper', ' Yes', ' Company'],
#  [' Gabriele Gianolli', ' Yes', ' Person'],
#  [' Karen Kruse', ' Yes', ' Person'],
#  [' Jürg Gubler', ' Yes', ' Person'],
#  [' Christiane Sottas', ' Yes', ' Person'],
#  [' Hans-Otto Walkling', ' Yes', ' Person'],
#  [' Reto Steiner', ' Yes', ' Person'],
#  [' Johann Furrer', ' Yes', ' Person'],
#  [' Pierre Müller', ' Yes', ' Person'],
#  [' Christoph Scheuermann', ' Yes', ' Person'],
#  [' Marcel Fischer', ' Yes', ' Person'],
#  [' Günther Wasser', ' Yes', ' Person'],
#  [' Pascale Hoch', ' Yes', ' Person'],
#  [' Michel Gomes', ' Yes', ' Person'],
#  [' Dominique BOULBES', ' Yes', ' Person'],
#  [' Simon Gantner', ' Yes', ' Person'],
#  [' Francisco Baños', ' Yes', ' Person'],
#  [' Paul Diener', ' Yes', ' Person'],
#  [' Patricia Kettner', ' Yes', ' Person'],
#  [' Thomas Mumenthaler', ' Yes', ' Person'],
#  [' Thomas Saner', ' Yes', ' Person'],
#  [' David Perrot', ' Yes', ' Person'],
#  [' Sylvestre Vecchi', ' Yes', ' Person'],
#  [' Lutz Schneider', ' Yes', ' Person'],
#  [' Markus Kast', ' Yes', ' Person'],
#  [' Christian Bigger', ' Yes', ' Person'],
#  [' Michael Wierz', ' Yes', ' Person'],
#  [' Joachim Schlumpf', ' Yes', ' Person'],
#  [' Patrick Guisolan', ' Yes', ' Person'],
#  [' René Halbherr', ' Yes', ' Person'],
#  [' Gergana Rohner', ' Yes', ' Person'],
#  [' Patrick Guélat', ' Yes', ' Person'],
#  [' Gentile Jean-Charles', ' Yes', ' Person'],
#  [' Christian Wege', ' Yes', ' Person'],
#  [' Helmut Borer', ' Yes', ' Person'],
#  [' Thierry Kramis', ' Yes', ' Person'],
#  [' Samuel ten Doornkaat', ' Yes', ' Person'],
#  [' Anouchka Maret', ' Yes', ' Person'],
#  [' Francis Cobbi', ' Yes', ' Person'],
#  [' Benny Reiter', ' Yes', ' Person'],
#  [' Niall Stive', ' Yes', ' Person'],
#  [' Hans Brühlmann', ' Yes', ' Person'],
#  [' Dieter Baldensperger', ' Yes', ' Person'],
#  [' Johann Widmer', ' Yes', ' Person'],
#  [' Peter Gabriel', ' Yes', ' Person'],
#  [' Alexander Häusler', ' Yes', ' Person'],
#  [' Peter Anderegg', ' Yes', ' Person'],
#  [' Markus Frauenfelder', ' Yes', ' Person'],
#  [' Thomas Lang', ' Yes', ' Person'],
#  [' Claude Hofer', ' Yes', ' Person.'],
#  ['marcel zimmermann', ' Yes', ' Person'],
#  [' Herve Andrieu', ' Yes', ' Person'],
#  [' Juliette Pauline Arter', ' Yes', ' Person'],
#  [' Antoine Delva', ' Yes', ' Person'],
#  [' Mirco Signorell', ' Yes', ' Person'],
#  [' Canna Beringer', ' Yes', ' Person'],
#  [' Consuelo Rudolf', ' Yes', ' Person'],
#  [' Rolf Widmer', ' Yes', ' Person'],
#  [' Sébastien Baumann', ' Yes', ' Person'],
#  [' Dominik Gasser', ' Yes', ' Person'],
#  [' Andy Michel Straubhaar', ' Yes', ' Person'],
#  [' Torsten Auerbach', ' Yes', ' Person'],
#  [' Ludivine Kaenel', ' Yes', ' Person'],
#  [' Matthias Forster', ' Yes', ' Person'],
#  [' Carole Koller', ' Yes', ' Person'],
#  [' Thomas Schange', ' Yes', ' Person'],
#  [' Pascal Cadonau', ' Yes', ' Person'],
#  [' Franco Tonizzo', ' Yes', ' Person'],
#  [' Anne-Marie Devaux', ' Yes', ' Person'],
#  [' Christine Lanz', ' Yes', ' Person'],
#  [' Urs Walthert', ' Yes', ' Person'],
#  [' Damian Zahnd', ' Yes', ' Person'],
#  [' Yakup Cifci', ' Yes', ' Person'],
#  [' Michel Carigiet', ' Yes', ' Person'],
#  [' Matthias Luchsinger', ' Yes', ' Person'],
#  [' Andreas Glarner', ' Yes', ' Person'],
#  [' Frédéric Wyss', ' Yes', ' Person'],
#  [' Dejan Simovic', ' Yes', ' Person'],
#  [' Adrian Harnisch', ' Yes', ' Person'],
#  [' Roman Dobler', ' Yes', ' Person'],
#  [" Fatimétou N'GAIDE-DIOUF", ' Yes', ' Person'],
#  [' Johannes Kisling', ' Yes', ' Person'],
#  [' Mauerer Hans', ' Yes', ' Person'],
#  [' Tiziana Pichon-Leccese', ' Yes', ' Person'],
#  [' Thomas Stauffer', ' Yes', ' Person'],
#  [' Eric Alberto Marco Bartolmoei', ' Yes', ' Person'],
#  [' Roberto Hayer', ' Yes', ' Person'],
#  [' Ellen Goris', ' Yes', ' Person'],
#  [' Pascal Grun', ' Yes', ' Person'],
#  [' Manuel Zurita Garcia', ' Yes', ' Person'],
#  [' Romaine In-Albon', ' Yes', ' Person'],
#  [' Marcel Rüdlinger', ' Yes', ' Person'],
#  [' Jean-Michel Galley', ' Yes', ' Person'],
#  [' Simon Schläppi', ' Yes', ' Person'],
#  [' . Buchhaltung', ' No', ' Company'],
#  [' Stefan Aregger', ' Yes', ' Person'],
#  [' Nicola De Ieso', ' Yes', ' Person'],
#  [' Paolo Romani', ' Yes', ' Person'],
#  [' Marcel Kipfer', ' Yes', ' Person'],
#  [' Thomas Balmer', ' Yes', ' Person'],
#  [' Daniel Theiler', ' Yes', ' Person'],
#  [' Gerd Frera', ' Yes', ' Person'],
#  [' Eric Drigatti', ' Yes', ' Person'],
#  [' S. Wüst', ' Yes', ' Person'],
#  [' John Barret', ' Yes', ' Person'],
#  [' Ana Isabel Nascimento dos Santos', ' Yes', ' Person'],
#  [' Timo Nothhelfer', ' Yes', ' Person'],
#  [' Conti Saverio', ' Yes', ' Person'],
#  [' Regula Modolo', ' Yes', ' Person'],
#  [' Jerez Belen', ' Yes', ' Person'],
#  [' Bastien Meier', ' Yes', ' Person'],
#  [' Gabor Barsi', ' Yes', ' Person'],
#  [' Silvana Petrillo', ' Yes', ' Person'],
#  [' Roman Feierabend', ' Yes', ' Person'],
#  [' Fabrice JOUANNEAU', ' Yes', ' Person'],
#  [' Urs Röthlisberger', ' Yes', ' Person'],
#  [' Sven Rohner', ' Yes', ' Person'],
#  [' Ajsella Shala-Murtezi', ' Yes', ' Person'],
#  [' Oliver Comi', ' Yes', ' Person'],
#  [' Vasco Manente', ' Yes', ' Person'],
#  [' Mathias Müller', ' Yes', ' Person'],
#  [' Hans Beer', ' Yes', ' Person'],
#  [' Jan Körbitz', ' Yes', ' Person'],
#  [' Ference Kovacs', ' Yes', ' Person'],
#  [' Carmine De Simone', ' Yes', ' Person'],
#  [' Peter Besmer', ' Yes', ' Person'],
#  [' Jérémy Christillin', ' Yes', ' Person'],
#  [' Jurgen M. J. Borgt', ' Yes', ' Person'],
#  [' Daniel Haas', ' Yes', ' Person'],
#  [' Tristan Brockelmanns', ' Yes', ' Person'],
#  [' Ralf Sturzenegger', ' Yes', ' Person'],
#  [' Martin Huber', ' Yes', ' Person'],
#  [' Martin Adama', ' Yes', ' Person'],
#  [' Cornelia Richard', ' Yes', ' Person'],
#  [' Bajna Philippe', ' Yes', ' Person'],
#  [' Peter Farmer', ' Yes', ' Person'],
#  [' Ray Brand', ' Yes', ' Person'],
#  [' Armin Rohner', ' Yes', ' Person'],
#  [' Matteo Riva', ' Yes', ' Person'],
#  [' Urs Aregger', ' Yes', ' Person'],
#  [' Catherine De chambrier', ' Yes', ' Person'],
#  [' David Crisinel', ' Yes', ' Person'],
#  [' Juergen GUENTHER', ' Yes', ' Person'],
#  [' Alex Kromwel', ' Yes', ' Person'],
#  [' Patrick Grassler', ' Yes', ' Person'],
#  [' Ahmet Yilmaz', ' Yes', ' Person'],
#  [' Julia Binder', ' Yes', ' Person'],
#  [' Emilie DELBARRE', ' Yes', ' Person'],
#  [' Evelyne Diaz', ' Yes', ' Person'],
#  [' Roland Marti', ' Yes', ' Person'],
#  ['Roger Wassmer', ' Yes', ' Person'],
#  [' Clara-Ann Gordon', ' Yes', ' Person'],
#  [' Hans-Peter AMANN', ' Yes', ' Person'],
#  [' André Twerenbold', ' Yes', ' Person'],
#  [' Andreas Fink', ' Yes', ' Person'],
#  [' Eric Brouwer', ' Yes', ' Person'],
#  [' Hans Mosimann', ' Yes', ' Person'],
#  [' Michael Geissmann', ' Yes', ' Person'],
#  [' Martin Hüppi', ' Yes', ' Person'],
#  [' Michel Oestreich', ' Yes', ' Person'],
#  [' Michal Lato', ' Yes', ' Person'],
#  [' Andree van Boven', ' Yes', ' Person'],
#  [' Jessica Zwahlen', ' Yes', ' Person'],
#  [' Steve Cand', ' Yes', ' Person'],
#  [' Aldo Britschgi', ' Yes', ' Person'],
#  [' Marcel Eckstein', ' Yes', ' Person'],
#  [' Andreas Casutt', ' Yes', ' Person'],
#  [' Danijel Podbreznik', ' Yes', ' Person'],
#  [' Victor Gnehm', ' Yes', ' Person'],
#  [' Bernard Peyresblanques', ' Yes', ' Person'],
#  [' Doriana Sabbatini', ' Yes', ' Person'],
#  [' Gabriel Jäger', ' Yes', ' Person'],
#  [' Bernard Verdonnet', ' Yes', ' Person'],
#  [' Matthieu Carbonnier', ' Yes', ' Person'],
#  [' Stephan Wick', ' Yes', ' Person'],
#  [' Beat Flepp', ' Yes', ' Person'],
#  [' Victoria Grunholzer', ' Yes', ' Person'],
#  [' Stéphane Panchaud', ' Yes', ' Person'],
#  [' Christian Ribeaud', ' Yes', ' Person'],
#  [' Andrea Gut', ' Yes', ' Person'],
#  [' Celia Alayo Argumedo', ' Yes', ' Person'],
#  [' Beat Ritschard', ' Yes', ' Person'],
#  [' Paul Messmer', ' Yes', ' Person'],
#  [' sté rapidofoos sa', ' No', ' Company'],
#  [' Gutter Patrick', ' Yes', ' Person'],
#  [' EFE DEMIR', ' Yes', ' Person'],
#  [' Marcel Andrey', ' Yes', ' Person'],
#  [' Val Ilchenko', ' Yes', ' Person'],
#  [' M. Bertschinger', ' Yes', ' Person'],
#  [' Luca Bernasconi', ' Yes', ' Person'],
#  [' Jean-Luc Schenk', ' Yes', ' Person'],
#  [' Martin Fluck', ' Yes', ' Person'],
#  [' Dali Horvat', ' Yes', ' Person'],
#  [' George Studer', ' Yes', ' Person'],
#  [' Daniel Bärtschi', ' Yes', ' Person'],
#  [' Berger Jimmy', ' Yes', ' Person'],
#  [' Aaron Herceg', ' Yes', ' Person'],
#  [' Willy Oppliger', ' Yes', ' Person'],
#  [' Beatrice Bähr', ' Yes', ' Person'],
#  [' Simone Edera', ' Yes', ' Person'],
#  [' Giuseppe Gioiello', ' Yes', ' Person'],
#  [' Bruno Huber', ' Yes', ' Person'],
#  [' Erkan Yilmaz', ' Yes', ' Person'],
#  [' Daniel Waldner', ' Yes', ' Person'],
#  [' Nicola LoPresti', ' Yes', ' Person'],
#  [' Pierre Abramowski', ' Yes', ' Person'],
#  [' Belinda Lehmann', ' Yes', ' Person'],
#  [' Ulrich Link', ' Yes', ' Person'],
#  [' Martin Becker', ' Yes', ' Person'],
#  [' Andreas Pöll', ' Yes', ' Person'],
#  [' Herwig Bonin', ' Yes', ' Person'],
#  [' Johnson Francis', ' Yes', ' Person'],
#  [' Otto Reinmann', ' Yes', ' Person'],
#  [' Ursula Kaya', ' Yes', ' Person'],
#  [' Daniel Müller', ' Yes', ' Person'],
#  [' Simone Cicalissi', ' Yes', ' Person'],
#  [' Séverin Voisin', ' Yes', ' Person'],
#  [' Linus Bläsi', ' Yes', ' Person'],
#  [' Charles Smith', ' Yes', ' Person'],
#  [' Christine Horner', ' Yes', ' Person'],
#  [' Monika Fricker', ' Yes', ' Person'],
#  [' BERGKVIST PETER', ' Yes', ' Person'],
#  [' Bernd Büdenbender', ' Yes', ' Person'],
#  [' Urs Schläpfer', ' Yes', ' Person'],
#  [' Carlo Laudati', ' Yes', ' Person'],
#  [' Francine Ludinard', ' Yes', ' Person'],
#  [' Phil Newman', ' Yes', ' Person'],
#  [' Beat Aeschlimann', ' Yes', ' Person'],
#  [' Giancarlo De Giorgi', ' Yes', ' Person'],
#  [' Marcel Fehr', ' Yes', ' Person'],
#  [' Mario Steiger', ' Yes', ' Person'],
#  [' Claudia Beck', ' Yes', ' Person'],
#  [' Max Muster', ' Yes', ' Person'],
#  [' Brian Boroff', ' Yes', ' Person'],
#  [' Fredj Trabelsi', ' Yes', ' Person'],
#  [' Jessica Da Silva Villacastin', ' Yes', ' Person'],
#  [' Stefan Huber', ' Yes', ' Person'],
#  [' Jorge DA SILVA', ' Yes', ' Person'],
#  [' Auf der Maur David', ' Yes', ' Person'],
#  [' Olivier Bianco', ' Yes', ' Person'],
#  [' Marc Walpoth', ' Yes', ' Person'],
#  [' James Ibbetson', ' Yes', ' Person'],
#  [' Karnjanart Breu', ' Yes', ' Person'],
#  [' Jürg Robert Karlen', ' Yes', ' Person'],
#  [' Onno Behr', ' Yes', ' Person'],
#  [' Lars Begert', ' Yes', ' Person'],
#  [' Manieri Filomena', ' Yes', ' Person'],
#  [' Marco Pulfer', ' Yes', ' Person'],
#  [' Sarah Waller', ' Yes', ' Person'],
#  [' Vincent Peek', ' Yes', ' Person.'],
#  ['Andy Russ', ' Yes', ' Person'],
#  [' manuela Schweighofer', ' No', ' Person'],
#  [' Sandie Lancashire', ' Yes', ' Person'],
#  [' Jean-Claude Dehl', ' Yes', ' Person'],
#  [' Fredy Riner', ' Yes', ' Person'],
#  [' Nadine Cohen', ' Yes', ' Person'],
#  [' Bondier Nicolas', ' Yes', ' Person'],
#  [' Rene von Euw', ' Yes', ' Person'],
#  [' Ingrid Häfelin', ' Yes', ' Person'],
#  [' Alessia Sicilia', ' Yes', ' Person'],
#  [' Raphaël Perruchoud', ' Yes', ' Person'],
#  [' David Lämmler', ' Yes', ' Person'],
#  [' Maya Repele', ' Yes', ' Person'],
#  [' Arnaud Claivaz', ' Yes', ' Person'],
#  [' Alexander Esslinger', ' Yes', ' Person'],
#  [' Benedikt Fassbind', ' Yes', ' Person'],
#  [' Cédric Bossart', ' Yes', ' Person'],
#  [' Verena Saxer', ' Yes', ' Person'],
#  [' Galvin Ernest', ' Yes', ' Person'],
#  [' Manuela Cadan', ' Yes', ' Person'],
#  [' Rainer Feldner', ' Yes', ' Person'],
#  [' Hakan Oezkan', ' Yes', ' Person'],
#  [' Andrea Mondini', ' Yes', ' Person'],
#  [' Nebi Nuh Akcakaya', ' Yes', ' Person'],
#  [' Marlene Schadegg', ' Yes', ' Person'],
#  [' Angineh Gevorken', ' Yes', ' Person'],
#  [' Christian Weber', ' Yes', ' Person'],
#  [' STEFAN WEISS', ' Yes', ' Person'],
#  [' Aurélie Ledermann', ' Yes', ' Person'],
#  [' Epsilon Legal', ' Yes', ' Company'],
#  [' Claudia Bisagno', ' Yes', ' Person'],
#  [' Michael Edion', ' Yes', ' Person'],
#  [' Alfredo Ciciulla', ' Yes', ' Person'],
#  [' Johannes Iten', ' Yes', ' Person'],
#  [' André Brice', ' Yes', ' Person'],
#  [' Davide Alfano', ' Yes', ' Person'],
#  [' Joen Fricker', ' Yes', ' Person'],
#  [' Vincenzo Vito', ' Yes', ' Person'],
#  [' Gregory Lanz', ' Yes', ' Person'],
#  [' Frédéric Fischlin', ' Yes', ' Person'],
#  [' Kurt Gerne', ' Yes', ' Person'],
#  [' Beate Noll', ' Yes', ' Person'],
#  [' Stockier', ' No', ' Person'],
#  [' Michel Müller', ' Yes', ' Person'],
#  [' keine Person', ' No', ' Person'],
#  [' Peter Hässig', ' Yes', ' Person'],
#  [' Mirand Murseli', ' Yes', ' Person'],
#  [' Marco von Gunten', ' Yes', ' Person'],
#  [' Richard Martin', ' Yes', ' Person'],
#  [' Thierry Weckner', ' Yes', ' Person'],
#  [' Daniel Schär', ' Yes', ' Person'],
#  [' Arianna Alexander', ' Yes', ' Person'],
#  [' Marlon Marasligil', ' Yes', ' Person'],
#  [' Franziska Schweizer', ' Yes', ' Person'],
#  [' Maica Labella Romera', ' Yes', ' Person'],
#  [' Corinne Besson', ' Yes', ' Person'],
#  [' Martin Kuratli', ' Yes', ' Person'],
#  [' Maria Finardi', ' Yes', ' Person'],
#  [' Izone Kuhnen Barras', ' Yes', ' Person'],
#  [' Luigi Carrisi', ' Yes', ' Person'],
#  [' Yildiz Bülent', ' Yes', ' Person'],
#  [' Tina Salerno', ' Yes', ' Person'],
#  [' Süleyman Oygur', ' Yes', ' Person'],
#  [' Alexandre Del Zenero', ' Yes', ' Person'],
#  [' Orlando TOGNINA', ' Yes', ' Person'],
#  [' Jonas Kümin', ' Yes', ' Person'],
#  [' Roxana Cuepa', ' Yes', ' Person'],
#  [' G. Rhyner', ' Yes', ' Person'],
#  [' Mario Maldini', ' Yes', ' Person'],
#  [' Sabrina Nourine', ' Yes', ' Person'],
#  [' Romeo Minini', ' Yes', ' Person'],
#  [' Gian Piero Cervellera', ' Yes', ' Person'],
#  [' Müller Ueli', ' Yes', ' Person'],
#  [' Suzanne Lienhard', ' Yes', ' Person'],
#  [' Nicola Schwegler', ' Yes', ' Person'],
#  [' Claude Fahrni', ' Yes', ' Person'],
#  [' Patrick Meier', ' Yes', ' Person'],
#  [' Celestina Neto', ' Yes', ' Person'],
#  [' BERNARD KACZMAREK', ' Yes', ' Person'],
#  [' Peter Leemann', ' Yes', ' Person'],
#  [' marie-françoise trottet', ' No', ' Person'],
#  [' Christina Vetsch', ' Yes', ' Person'],
#  [' Thomas Streit', ' Yes', ' Person'],
#  [' Manuela Schaffner', ' Yes', ' Person'],
#  [' Kathrin Schläppi', ' Yes', ' Person'],
#  [' Görkem Yilmazer', ' Yes', ' Person'],
#  [' Amer Barjaktarevic', ' Yes', ' Person'],
#  [' Anne Ngono', ' Yes', ' Person'],
#  [' KIEFFER PHILIPPE', ' Yes', ' Person'],
#  [' Samuel Manz', ' Yes', ' Person'],
#  [' Karin Annen', ' Yes', ' Person'],
#  [' Alain Bulliard', ' Yes', ' Person'],
#  [' Emilio Guerini', ' Yes', ' Person'],
#  [' Ralf Tonezzer', ' Yes', ' Person'],
#  [' Yannick Evrard', ' Yes', ' Person'],
#  [' Franziska Sigrist', ' Yes', ' Person'],
#  [' Paul Euler', ' Yes', ' Person'],
#  [' Hanspeter Weisskopf', ' Yes', ' Person'],
#  [' Nikolaos Velentzas', ' Yes', ' Person'],
#  [' Nicole Darioli', ' Yes', ' Person'],
#  ['Sara Tanner', ' Yes', ' Person'],
#  [' Barbara Thür', ' Yes', ' Person'],
#  [' Tiziana Pichon Leccese', ' Yes', ' Person'],
#  [' David Hosslin', ' Yes', ' Person'],
#  [' Markus Nickel', ' Yes', ' Person'],
#  [' Erika Schmidlin', ' Yes', ' Person'],
#  [' Anaïs Güdel', ' Yes', ' Person'],
#  [' Vincent Meyer', ' Yes', ' Person'],
#  [' Regula Senn', ' Yes', ' Person'],
#  [' Ursula Barker', ' Yes', ' Person'],
#  [' Jörg Kramer', ' Yes', ' Person'],
#  [' Timcke Henning', ' Yes', ' Person'],
#  [' Beat Stettler', ' Yes', ' Person'],
#  [' Florian Gygax', ' Yes', ' Person'],
#  [' Tommy Frei', ' Yes', ' Person'],
#  [' Roger Gassmann', ' Yes', ' Person'],
#  [' Lara Luci', ' Yes', ' Person'],
#  [' Aydin Yilmaz', ' Yes', ' Person'],
#  [' Susanne Bärtschi', ' Yes', ' Person'],
#  [' Dagmar Anderes', ' Yes', ' Person'],
#  [' Cédric Burkhalter', ' Yes', ' Person'],
#  [' Rachel Montandon', ' Yes', ' Person'],
#  [' Sonja Loop', ' Yes', ' Person'],
#  [' Chris Weingartner', ' Yes', ' Person'],
#  [' Eric Gilliard', ' Yes', ' Person'],
#  [' Wilfred Mathanaraj', ' Yes', ' Person'],
#  [' Giambattista Ravanne', ' Yes', ' Person'],
#  [' Abejón Beatriz', ' Yes', ' Person'],
#  [' Pier Sciurti', ' Yes', ' Person'],
#  [' Serpil Oruc', ' Yes', ' Person'],
#  [' Claudio PISANI', ' Yes', ' Person'],
#  [' Nicole Perrin', ' Yes', ' Person'],
#  [' Nicolas Wyss', ' Yes', ' Person'],
#  [' Marc Aeschlimann', ' Yes', ' Person'],
#  [' Dominik P. Rubli', ' Yes', ' Person'],
#  [' Salah Walo', ' Yes', ' Person'],
#  [' Maria Georgiou', ' Yes', ' Person'],
#  [' Margarita Gonzalez', ' Yes', ' Person'],
#  [' Gerda Grisiger', ' Yes', ' Person'],
#  [' Kalliopi Sotiropoulou', ' Yes', ' Person'],
#  [' Ben Amer Walid', ' Yes', ' Person'],
#  [' Sandra Leutenegger', ' Yes', ' Person'],
#  [' Marc Ott', ' Yes', ' Person'],
#  [' Vincent Jambou', ' Yes', ' Person'],
#  [' Kristina Mülhauser', ' Yes', ' Person'],
#  [' Guido Melzer', ' Yes', ' Person'],
#  [' pia bieri', ' No', ' Person'],
#  [' Jane Flückiger', ' Yes', ' Person'],
#  [' Daniel Hitz', ' Yes', ' Person'],
#  [' Manfred Zosso', ' Yes', ' Person'],
#  [' Dominique Chassot', ' Yes', ' Person'],
#  [' Marco Jörg', ' Yes', ' Person'],
#  [' François Brun', ' Yes', ' Person'],
#  [' Damien Wilhelm', ' Yes', ' Person'],
#  [' Alan Saklican', ' Yes', ' Person'],
#  [' Claudio Gubitosa', ' Yes', ' Person'],
#  [' DAVID COHEN', ' Yes', ' Person'],
#  [' Rudolf Widmer', ' Yes', ' Person'],
#  [' Denise Stofer', ' Yes', ' Person'],
#  [' Oliver Jäger', ' Yes', ' Person'],
#  [' Daniel Aebi', ' Yes', ' Person'],
#  [' Fathi Hajjaji', ' Yes', ' Person'],
#  [' Maass Matthias', ' Yes', ' Person'],
#  [' Niklas Heimer', ' Yes', ' Person'],
#  [' Jocelyn Evequoz', ' Yes', ' Person'],
#  [' Pierre Alian Carruzzo', ' Yes', ' Person'],
#  [' Roland Mettler', ' Yes', ' Person'],
#  [' Dominik Bettler', ' Yes', ' Person'],
#  [' Thierry Laurence', ' Yes', ' Person'],
#  [' Peter Burkhalter', ' Yes', ' Person'],
#  [' Rita Barros', ' Yes', ' Person'],
#  [' Ivo Haerdi', ' Yes', ' Person'],
#  [' Boris Trinkler', ' Yes', ' Person'],
#  [' Charly Lee', ' Yes', ' Person'],
#  [' Bruno Wolf', ' Yes', ' Person'],
#  [' Kathy Berset', ' Yes', ' Person'],
#  [' Claudio Sartorelli', ' Yes', ' Person'],
#  [' Jean-Paul Holenstein', ' Yes', ' Person'],
#  [' Felipe Solari', ' Yes', ' Person'],
#  [' Philippe Herzog', ' Yes', ' Person'],
#  [' Hansrudolf Kull', ' Yes', ' Person'],
#  [' Marcel Bachmann', ' Yes', ' Person'],
#  [' Katja Locher', ' Yes', ' Person'],
#  [' Roberto Cabot', ' Yes', ' Person'],
#  [' Devorah Debever', ' Yes', ' Person'],
#  [' Ivana Cosic', ' Yes', ' Person'],
#  [' Sara Zanon', ' Yes', ' Person'],
#  [' Jürg Weilenmann', ' Yes', ' Person'],
#  [' Pascal Pegaz Paquet', ' Yes', ' Person'],
#  [' Angela Glükler', ' Yes', ' Person'],
#  [' Stefan Scharrenbroich', ' Yes', ' Person'],
#  [' Jessica Salvi', ' Yes', ' Person'],
#  [' Pedro Marta', ' Yes', ' Person'],
#  [' Marcello Tonini', ' Yes', ' Person'],
#  [' Richard Landheer', ' Yes', ' Person'],
#  [' Carla Fidecaro', ' Yes', ' Person'],
#  [' Antonio Brigant', ' Yes', ' Person'],
#  [' Thomas Boillat', ' Yes', ' Person'],
#  [' Harry Bucklar', ' Yes', ' Person'],
#  [' Rick Bollard', ' Yes', ' Person.'],
#  ['Michael Geilenkirchen', ' Yes', ' Person'],
#  [' Margot Annen', ' Yes', ' Person'],
#  [' Andreas Gisler', ' Yes', ' Person'],
#  [' Ant Stone', ' Yes', ' Person'],
#  [' Daniel Ducret', ' Yes', ' Person'],
#  [' Dagmar Wegmann', ' Yes', ' Person'],
#  [' Margrit Hard', ' Yes', ' Person'],
#  [' Jean Philippe Dr. Haesler', ' Yes', ' Person'],
#  [' Patrick Donzel', ' Yes', ' Person'],
#  [' Peter Maurer', ' Yes', ' Person'],
#  [' Peter Müller', ' Yes', ' Person'],
#  [' Lydia Lambert', ' Yes', ' Person'],
#  [' Benjamin Freisberg', ' Yes', ' Person'],
#  [' Susanna Göldi', ' Yes', ' Person'],
#  [' Helen Begert', ' Yes', ' Person'],
#  [' Cornelia Lehne', ' Yes', ' Person'],
#  [' Brigitta Kunz', ' Yes', ' Person'],
#  [' Reinhold Müller', ' Yes', ' Person'],
#  [' Niky Alexander Thomet', ' Yes', ' Person'],
#  [' Stéphane MOGNOL', ' Yes', ' Person'],
#  [' Stiepan Kovac', ' Yes', ' Person'],
#  [' Thomas Leisenberg', ' Yes', ' Person'],
#  [' Andreas Glarner', ' Yes', ' Person'],
#  [' Werner Fuchs', ' Yes', ' Person'],
#  [' Daniel Ruiz', ' Yes', ' Person'],
#  [' Stefan Gächter', ' Yes', ' Person'],
#  [' Lurko Gombay', ' Yes', ' Person'],
#  [' Christel Muri', ' Yes', ' Person'],
#  [' Amanda Casagrande', ' Yes', ' Person'],
#  [' Philippe Carron', ' Yes', ' Person'],
#  [' christine zaghet', ' Yes', ' Person'],
#  [' Urs Hafner', ' Yes', ' Person'],
#  [' Christian Hutter', ' Yes', ' Person'],
#  [' Jerry Lay', ' Yes', ' Person'],
#  [' Thomas Scheurer', ' Yes', ' Person'],
#  [' Marcel Wappler', ' Yes', ' Person'],
#  [' Rosmarie Hunziker', ' Yes', ' Person'],
#  [' Robert Berger', ' Yes', ' Person'],
#  [' Oskar Fehr', ' Yes', ' Person'],
#  [' Hamblin Damani', ' Yes', ' Person'],
#  [' François Martel', ' Yes', ' Person'],
#  [' Hansruedi Huber', ' Yes', ' Person'],
#  [' Stefan Althaus', ' Yes', ' Person'],
#  [' Sabine Bandi', ' Yes', ' Person'],
#  [' Kelley Diana', ' Yes', ' Person'],
#  [' Andreas Borer', ' Yes', ' Person'],
#  [' Obuchowski Adam', ' Yes', ' Person'],
#  [' Claudia Giorgetti', ' Yes', ' Person'],
#  [' Roger Matter', ' Yes', ' Person'],
#  [' Christophe Vila', ' Yes', ' Person'],
#  [' Milena Filomena La Cioppa', ' Yes', ' Person'],
#  [' Martin Gerber', ' Yes', ' Person'],
#  [' Mohsin Ehsan Butt', ' Yes', ' Person'],
#  [' René Rahm', ' Yes', ' Person'],
#  [' Marco Dahinden', ' Yes', ' Person'],
#  [' Lawrence Blakeley', ' Yes', ' Person'],
#  [' Nicolas Sieger', ' Yes', ' Person'],
#  [' Gyozo Kmethy', ' Yes', ' Person'],
#  [' Anne-Laure Haissly', ' Yes', ' Person'],
#  [' Marc Meyer', ' Yes', ' Person'],
#  [' Alain Valentino', ' Yes', ' Person'],
#  [' Thomas Goodwin', ' Yes', ' Person'],
#  [' Olivier Rey', ' Yes', ' Person'],
#  [' Rainer Hollenstein', ' Yes', ' Person'],
#  [' Remo Buetikofer', ' Yes', ' Person'],
#  [' Andreas Jermann', ' Yes', ' Person'],
#  [' Ariane Perny', ' Yes', ' Person'],
#  [' Adrian Spahn', ' Yes', ' Person'],
#  [' Martin Tichy-Ruch', ' Yes', ' Person'],
#  [' Isabelle Sahli', ' Yes', ' Person'],
#  [' Joerg Kessler', ' Yes', ' Person'],
#  [' Christian Donatsch', ' Yes', ' Person'],
#  [' Armin Ris', ' Yes', ' Person'],
#  [' Frank Valley', ' Yes', ' Person'],
#  [' Thomas Hiltbrunner', ' Yes', ' Person'],
#  [' James Salvador', ' Yes', ' Person'],
#  [' Roman Dissauer', ' Yes', ' Person'],
#  [' Fernando Marques', ' Yes', ' Person'],
#  [' Jorge Luis Mariuzzo', ' Yes', ' Person'],
#  [' Luc van Deuzen', ' Yes', ' Person'],
#  [' Eduard Kolly', ' Yes', ' Person'],
#  [' Giger', ' No', ' Person'],
#  [' Jacqueline Oertle', ' Yes', ' Person'],
#  [' Oskar Bernauer', ' Yes', ' Person'],
#  [' Oliver Ernst', ' Yes', ' Person'],
#  [' Bülent Yildiz', ' Yes', ' Person'],
#  [' Rohregger Bernd', ' Yes', ' Person'],
#  [' Hürlimann Elsbeth', ' Yes', ' Person'],
#  [' Urs Buchwalder', ' Yes', ' Person'],
#  [' Erich Staub', ' Yes', ' Person'],
#  [' Thierry Affolter', ' Yes', ' Person'],
#  [' Richard Landheer', ' Yes', ' Person'],
#  [' Carlo Franchini', ' Yes', ' Person'],
#  [' Peter Link', ' Yes', ' Person'],
#  [' Pierre Schoeffel', ' Yes', ' Person'],
#  [' Pius Häfliger', ' Yes', ' Person'],
#  [' Lorenz Altenhoff', ' Yes', ' Person'],
#  [' Daniel Arni', ' Yes', ' Person'],
#  [' Alexandra Denervaud', ' Yes', ' Person'],
#  [' Monika Ursula Vodica', ' Yes', ' Person.'],
#  ['Maurice B. Grosjean', ' Yes', ' Person'],
#  [' Myrta Estermann', ' Yes', ' Person'],
#  [' Beaudelaire KATEU', ' Yes', ' Person'],
#  [' David Valente', ' Yes', ' Person'],
#  [' Patrick Studer', ' Yes', ' Person'],
#  [' Giuliana Tedesco', ' Yes', ' Person'],
#  [' Holger Reinking', ' Yes', ' Person'],
#  [' maria-dolores lopez-germano', ' No', ' Person'],
#  [' Aydin Sar', ' Yes', ' Person'],
#  [' Julio Anivaro', ' Yes', ' Person'],
#  [' Laurent Schaffter', ' Yes', ' Person'],
#  [' Stefanie Schmid', ' Yes', ' Person'],
#  [' Jean-Charles Petignat', ' Yes', ' Person'],
#  [' Alban Suljevic', ' Yes', ' Person'],
#  [' Andreas Gössnitzer', ' Yes', ' Person'],
#  [' Martine Partouche', ' Yes', ' Person'],
#  [' Karim Abdus Salam Subhan', ' Yes', ' Person'],
#  [' Hugh Reeves', ' Yes', ' Person'],
#  [' Sarah Emonet', ' Yes', ' Person'],
#  [' damien briet', ' No', ' Person'],
#  [' Kerim Rozajac', ' Yes', ' Person'],
#  [' Roger Müller', ' Yes', ' Person'],
#  [' Marco Bellini', ' Yes', ' Person'],
#  [' René-Michel Voegeli', ' Yes', ' Person'],
#  [' Carole Even', ' Yes', ' Person'],
#  [' Dixa Friends', ' No', ' Company'],
#  [' Sibel Yurdakan', ' Yes', ' Person'],
#  [' . Arc Jurassien Déchets', ' No', ' Company'],
#  [' Fabio Tommasi', ' Yes', ' Person'],
#  [' Jeremy Zimmermann', ' Yes', ' Person'],
#  [' Claude R. Etique', ' Yes', ' Person'],
#  [' Dimitris Panayotis Schön', ' Yes', ' Person'],
#  [' Georges Sallouk', ' Yes', ' Person'],
#  [' Heinrich Luder', ' Yes', ' Person'],
#  [' Céline Mollet', ' Yes', ' Person'],
#  [' Silvio Schöchlin', ' Yes', ' Person'],
#  [' Souhail Matoussi', ' Yes', ' Person'],
#  [' Esra Karagenc', ' Yes', ' Person'],
#  [' Rahel Hirt', ' Yes', ' Person'],
#  [' Eckhard Reinhardt', ' Yes', ' Person'],
#  [' Gianfranco Di Stefano', ' Yes', ' Person'],
#  [' Cyrille Wyse', ' Yes', ' Person'],
#  [' Manoharan Kandasamy', ' Yes', ' Person'],
#  [' Birgitta Robustelli', ' Yes', ' Person'],
#  [' Torben Heinert', ' Yes', ' Person'],
#  [' Mario Tschan', ' Yes', ' Person'],
#  [' Daniel Testa', ' Yes', ' Person'],
#  [' Céline Morey', ' Yes', ' Person'],
#  [' Michael Herbst', ' Yes', ' Person'],
#  [' Kloyjai Deutsch', ' Yes', ' Person'],
#  [' juan klammer', ' No', ' Person'],
#  [' Gian Sandro Genna', ' Yes', ' Person'],
#  [' Marco Blind', ' Yes', ' Person'],
#  [' Andreas ELBEL', ' Yes', ' Person'],
#  [' Paul Zurgilgen', ' Yes', ' Person'],
#  [' Arturik Martins', ' Yes', ' Person'],
#  [' Rui Filipe Barbosa da Silva', ' Yes', ' Person'],
#  [' Maxime Petrement', ' Yes', ' Person'],
#  [' Raphael Gübelin', ' Yes', ' Person'],
#  [' Markus Breitenmoser', ' Yes', ' Person'],
#  [' Tamara Chironi', ' Yes', ' Person'],
#  [' Bertrand Roduit', ' Yes', ' Person'],
#  [' Michael Oberlin', ' Yes', ' Person'],
#  [' Peter Schnüriger', ' Yes', ' Person'],
#  [' Francisco Ferreira de Jesus', ' Yes', ' Person'],
#  [' keine Person', ' No', ' Person'],
#  [' Thomas Dreher', ' Yes', ' Person'],
#  [' Philippe Chappuis', ' Yes', ' Person'],
#  [' Naara Leuenberger', ' Yes', ' Person'],
#  [' Lionel Beier', ' Yes', ' Person'],
#  [' Nilson Bosshard', ' Yes', ' Person'],
#  [' Gaby Rubin', ' Yes', ' Person'],
#  [' Monika Gattiker', ' Yes', ' Person'],
#  [' Jongkon Sigrist', ' Yes', ' Person'],
#  [' Markus Lenherr', ' Yes', ' Person'],
#  [' Mario Paulo Martins Torres Barbosa', ' Yes', ' Person'],
#  [' Ludovic Sottas', ' Yes', ' Person'],
#  [' Marianne Gerhard', ' Yes', ' Person'],
#  [' Tommaso Cosentino', ' Yes', ' Person'],
#  [' Carmine Ciarmiello', ' Yes', ' Person'],
#  [' Adrian Allenbach', ' Yes', ' Person'],
#  [' Beat C. Lutz', ' Yes', ' Person'],
#  [' Jérôme Thiriet', ' Yes', ' Person'],
#  [' Heinz Schmid', ' Yes', ' Person'],
#  [' Murielle Isenegger', ' Yes', ' Person'],
#  [' Hosting Hosting', ' No', ' Company'],
#  [' Valery Eshuis', ' Yes', ' Person'],
#  [' Thierry Schütz', ' Yes', ' Person'],
#  [' Mirko Stanic', ' Yes', ' Person'],
#  [' Syed Abbas', ' Yes', ' Person'],
#  [' Christian Dreyer', ' Yes', ' Person'],
#  [' Angela Diethelm', ' Yes', ' Person'],
#  [' Suzie Thakur', ' Yes', ' Person'],
#  [' Mike sebaut', ' No', ' Person'],
#  [' Matthias Koch', ' Yes', ' Person'],
#  [' Dario Filomena', ' Yes', ' Person'],
#  [' Martin Heller', ' Yes', ' Person'],
#  [' Regula Wylenmann', ' Yes', ' Person'],
#  [' Jürg Kauer', ' Yes', ' Person'],
#  [' Franco Todaro', ' Yes', ' Person.'],
#  ['Max Sartory', ' Yes', ' Person'],
#  [' Necip Karagenc', ' Yes', ' Person'],
#  [' Nikolai Schramenko', ' Yes', ' Person'],
#  [' Patrick Zaugg', ' Yes', ' Person'],
#  [' Manuel Schweizer', ' Yes', ' Person'],
#  [' Joana Pereira', ' Yes', ' Person'],
#  [' Ralf Maack', ' Yes', ' Person'],
#  [' Felix Bosshart', ' Yes', ' Person'],
#  [' Isabelle Knoblauch', ' Yes', ' Person'],
#  [' Heinz Kundert', ' Yes', ' Person'],
#  [' René Conzelmann', ' Yes', ' Person'],
#  [' Mohamed Beji', ' Yes', ' Person'],
#  [' Patrick Barlocchi', ' Yes', ' Person'],
#  [' Philippe Lenherr', ' Yes', ' Person'],
#  [' Christel Muri', ' Yes', ' Person'],
#  [' Cristina Gigliotti', ' Yes', ' Person'],
#  [' Christophe Roh', ' Yes', ' Person'],
#  [' Hugo Graber', ' Yes', ' Person'],
#  [' Marc Bruschta', ' Yes', ' Person'],
#  [' Richard Cooper', ' Yes', ' Person'],
#  [' Loïc Deslarzes', ' Yes', ' Person'],
#  [' S. Nardi', ' Yes', ' Person'],
#  [' Edmund Leemann', ' Yes', ' Person'],
#  [' Anda Amariei', ' Yes', ' Person'],
#  [' Livio Vetsch', ' Yes', ' Person'],
#  [' Zlatko Bicanic', ' Yes', ' Person'],
#  [' Gina Sarah Schneider-Frei', ' Yes', ' Person'],
#  [' Martin von Allmen', ' Yes', ' Person'],
#  [' Jasmin Mertens', ' Yes', ' Person'],
#  [' Philip Michael', ' Yes', ' Person'],
#  [' Christoph Koch', ' Yes', ' Person'],
#  [' Ramona Miron', ' Yes', ' Person'],
#  [' Hanspeter Vetsch', ' Yes', ' Person'],
#  [' Christian Götsch', ' Yes', ' Person'],
#  [' Martin Frey', ' Yes', ' Person'],
#  [' Bernard Pauchard', ' Yes', ' Person'],
#  [' Laurent Mastromauro', ' Yes', ' Person'],
#  [' Maurizio Carrer', ' Yes', ' Person'],
#  [' Marcello Tonini', ' Yes', ' Person'],
#  [' Benjamin Leuenberger', ' Yes', ' Person'],
#  [' Evelyn Hohberg', ' Yes', ' Person'],
#  [' Bernd Pfaff', ' Yes', ' Person'],
#  [' Thomas Glasmacher', ' Yes', ' Person'],
#  [' Fouad Yehia', ' Yes', ' Person'],
#  [' Thomas Schönberger', ' Yes', ' Person'],
#  [' Dieter Lang', ' Yes', ' Person'],
#  [' Leslie Wohlgroth', ' Yes', ' Person'],
#  [' Stephane Cherix', ' Yes', ' Person'],
#  [' Willy Berdoz', ' Yes', ' Person'],
#  [' Theurer Felix', ' Yes', ' Person'],
#  [' Makrem Ben Mrad', ' Yes', ' Person'],
#  [' José Luis Herrero', ' Yes', ' Person'],
#  [' Patrick Maire', ' Yes', ' Person'],
#  [' Raphael Boullet', ' Yes', ' Person'],
#  [' Matthias Cramer', ' Yes', ' Person'],
#  [' Rémi Perhuisot', ' Yes', ' Person'],
#  [' Fabian Schubert', ' Yes', ' Person'],
#  [' Jeremy Helms', ' Yes', ' Person'],
#  [' José Tulleuda', ' Yes', ' Person'],
#  [' Gianluca Preite', ' Yes', ' Person'],
#  [' Katherina Aeschbacher', ' Yes', ' Person'],
#  [' Daniel Schnyder', ' Yes', ' Person'],
#  [' Mickaël MENDES', ' Yes', ' Person'],
#  [' Alessandro De Bernardi', ' Yes', ' Person'],
#  [' Agnes Mallard', ' Yes', ' Person'],
#  [' Emanuela Tuccimei', ' Yes', ' Person'],
#  [' Felicia Balea', ' Yes', ' Person'],
#  [' Katja Schori', ' Yes', ' Person'],
#  [' William De Filippo', ' Yes', ' Person'],
#  [' Christian Stuker', ' Yes', ' Person'],
#  [' Nicola Benz', ' Yes', ' Person'],
#  [' Roger Erb', ' Yes', ' Person'],
#  [' Katharina Hermes', ' Yes', ' Person'],
#  [' Marc Imfeld', ' Yes', ' Person'],
#  [' Martin Zaugg', ' Yes', ' Person'],
#  [' Rene Bosshard', ' Yes', ' Person'],
#  [' Matthias Grossglauser', ' Yes', ' Person'],
#  [' Heinz Stampfl', ' Yes', ' Person'],
#  [' Jordan Warne', ' Yes', ' Person'],
#  [' Rolf Engel', ' Yes', ' Person'],
#  [' nicola battisti', ' Yes', ' Person'],
#  [' Eric Haegler', ' Yes', ' Person'],
#  [' Simon Aebischer', ' Yes', ' Person'],
#  [' Martin Kunz', ' Yes', ' Person'],
#  [' Frédéric Piancastelli', ' Yes', ' Person'],
#  [' Dieter Wälti', ' Yes', ' Person'],
#  [' Hans Fischer', ' Yes', ' Person'],
#  [' Kevin Stuber', ' Yes', ' Person'],
#  [' Matthias Fiechter', ' Yes', ' Person'],
#  [' Thomas Grand', ' Yes', ' Person'],
#  [' Braun Erhard', ' Yes', ' Person'],
#  [' Marco Derungs', ' Yes', ' Person'],
#  [' Markus Plischke', ' Yes', ' Person'],
#  [' Monique Haag', ' Yes', ' Person'],
#  [' Steve Chautems', ' Yes', ' Person'],
#  [' Sadik Hafizovic', ' Yes', ' Person'],
#  [' Gianmaria Parini', ' Yes', ' Person'],
#  [' Meret Gebistorf', ' Yes', ' Person'],
#  [' Daniel Thommen', ' Yes', ' Person'],
#  [' Patrik Björklund', ' Yes', ' Person.'],
#  ['Alex Herren', ' Yes', ' Person'],
#  [' Brigitte Pythoud', ' Yes', ' Person'],
#  [' Yvonne Gilomen', ' Yes', ' Person'],
#  [' Brian Hick', ' Yes', ' Person'],
#  [' Niklaus Zürcher', ' Yes', ' Person'],
#  [' Rolf Dinkelmann', ' Yes', ' Person'],
#  [' Pierre Gardet', ' Yes', ' Person'],
#  [' Reto Furter', ' Yes', ' Person'],
#  [' Dominique Chambettaz', ' Yes', ' Person'],
#  [' Dominik Hunziker', ' Yes', ' Person'],
#  [' Ozan Akkaya', ' Yes', ' Person'],
#  [' Philipp Zeder', ' Yes', ' Person'],
#  [' Alexis Caceda', ' Yes', ' Person'],
#  [' Matthieu Kressmann', ' Yes', ' Person'],
#  [' Marie Chantale Fuchs', ' Yes', ' Person'],
#  [' Pan Barz', ' Yes', ' Person'],
#  [' Jean Philippe Ottmann', ' Yes', ' Person'],
#  [' Alessio Gianoli', ' Yes', ' Person'],
#  [' Fausto Delli Bovi', ' Yes', ' Person'],
#  [' Cutraro Flavio', ' Yes', ' Person'],
#  [' Hannes Püschel', ' Yes', ' Person'],
#  [' Jun Bruderer', ' Yes', ' Person'],
#  [' Danielle Ayer', ' Yes', ' Person'],
#  [' Ratl Amine', ' Yes', ' Person'],
#  [' Pina Zimmermann', ' Yes', ' Person'],
#  [' Marlen Robmann', ' Yes', ' Person'],
#  [' Gander Friedli', ' Yes', ' Person'],
#  [' Dimitri Ikonomou', ' Yes', ' Person'],
#  [' Thomas Lutter', ' Yes', ' Person'],
#  [' Ali Barouc', ' Yes', ' Person'],
#  [' Carmen Alvarez', ' Yes', ' Person'],
#  [' Roger Bieri', ' Yes', ' Person'],
#  [' Stefan Kyburz', ' Yes', ' Person'],
#  [' Benno von Deschwanden', ' Yes', ' Person'],
#  [' Yvonne Ritschard', ' Yes', ' Person'],
#  [' Monika Ludwig', ' Yes', ' Person'],
#  [' Patrick Rochat', ' Yes', ' Person'],
#  [' Reto Schwarzenbach', ' Yes', ' Person'],
#  [' Vinko Ribic', ' Yes', ' Person'],
#  [' Radziewicz Cliff', ' Yes', ' Person'],
#  [' Bruno Zaugg', ' Yes', ' Person'],
#  [' Axel Horisberger', ' Yes', ' Person'],
#  [' Hervé Balzano', ' Yes', ' Person'],
#  [' Rene Schubiger', ' Yes', ' Person'],
#  [' Urs Schmitt', ' Yes', ' Person'],
#  [' René Schiefer', ' Yes', ' Person'],
#  [' Jean Sottas', ' Yes', ' Person'],
#  [' Philipp Bucheli', ' Yes', ' Person'],
#  [' Rico Romagnoli', ' Yes', ' Person'],
#  [' Manfred Flück', ' Yes', ' Person'],
#  [' Joachim Krump', ' Yes', ' Person'],
#  [' Jeff Busch', ' Yes', ' Person'],
#  [' Rolf Auf der Maur', ' Yes', ' Person'],
#  [' bastiaan vernier', ' Yes', ' Person'],
#  [' Hervé Blanc', ' Yes', ' Person'],
#  [' Gabriela Nauer', ' Yes', ' Person'],
#  [' Nicolas Brigger', ' Yes', ' Person'],
#  [' Haci Sarac', ' Yes', ' Person'],
#  [' Dominik Müller-Weich', ' Yes', ' Person'],
#  [' Walter Läderach', ' Yes', ' Person'],
#  [' Andreas Diehl', ' Yes', ' Person'],
#  [' Thomas Bernasconi', ' Yes', ' Person'],
#  [' Astrid Baumgartner', ' Yes', ' Person'],
#  [' Martina Nef', ' Yes', ' Person'],
#  [' Aliz Hevesine Major', ' Yes', ' Person'],
#  [' Sebastian Fohrer', ' Yes', ' Person'],
#  [' Mauro Sbicego', ' Yes', ' Person'],
#  [' Pascal Dumont', ' Yes', ' Person'],
#  [' Alvin Lustig', ' Yes', ' Person'],
#  [' Stefan Witschard', ' Yes', ' Person'],
#  [' Ulrich Schäper', ' Yes', ' Person'],
#  [' Marcel Böni', ' Yes', ' Person'],
#  [' Lindita Rizvani', ' Yes', ' Person'],
#  [' Reto Ryf', ' Yes', ' Person'],
#  [' Emilio Guerini', ' Yes', ' Person'],
#  [' Jennifer Peluso', ' Yes', ' Person'],
#  [' Eliano Catelli', ' Yes', ' Person'],
#  [' Jean-Bernard May', ' Yes', ' Person'],
#  [' Vanessa Borel', ' Yes', ' Person'],
#  [' Chantal Busz', ' Yes', ' Person'],
#  [' Santiago Caneiro', ' Yes', ' Person'],
#  [' Odile Badoud', ' Yes', ' Person'],
#  [' Andrew Ashley', ' Yes', ' Person'],
#  [' Konrad Schwarz', ' Yes', ' Person'],
#  [' André Grüter', ' Yes', ' Person'],
#  [' René Wehrle', ' Yes', ' Person'],
#  [' Kurt Frischknecht', ' Yes', ' Person'],
#  [' Pascal Rocha da Silva', ' Yes', ' Person'],
#  [' Elisabeth Pohl', ' Yes', ' Person'],
#  [' Daniel Leuenberger', ' Yes', ' Person'],
#  [' Isabelle Räss', ' Yes', ' Person'],
#  [' Station BRNA', ' No', ' Person'],
#  [' Aykut Cebeci', ' Yes', ' Person'],
#  [' Karin Kunz', ' Yes', ' Person'],
#  [' Ole Svane Nielsen', ' Yes', ' Person'],
#  [' Barbara Vouillamoz', ' Yes', ' Person'],
#  [' Filippo Diliberto', ' Yes', ' Person'],
#  [' Danièle Benz', ' Yes', ' Person'],
#  [' Ian Metcalfe', ' Yes', ' Person'],
#  [' Laurence Schonenberger', ' Yes', ' Person.'],
#  ...]

# %%
results

for item in results:
    if item[1].strip().lower() == 'no':
        print(item)
# Out:
# [' johann Frain', ' No', ' Person']
# [' KENNETH COSTANTINO', ' No', ' Person']
# [' bernd wagner', ' No', ' Person']
# [' Santana Fonseca Mathieu Marineide', ' No', ' Person']
# [' arlo gonser', ' No', ' Person']
# [' Raphael lutz', ' No', ' Person']
# [' Patrick AUCHLIN', ' No', ' Person']
# [' Pauline Elisabeth Bétrisey Nanchen', ' No', ' Person']
# [' dummy doublette', ' No', ' Person']
# [' . Buchhaltung', ' No', ' Company']
# [' sté rapidofoos sa', ' No', ' Company']
# [' manuela Schweighofer', ' No', ' Person']
# [' Stockier', ' No', ' Person']
# [' keine Person', ' No', ' Person']
# [' marie-françoise trottet', ' No', ' Person']
# [' pia bieri', ' No', ' Person']
# [' Giger', ' No', ' Person']
# [' maria-dolores lopez-germano', ' No', ' Person']
# [' damien briet', ' No', ' Person']
# [' Dixa Friends', ' No', ' Company']
# [' . Arc Jurassien Déchets', ' No', ' Company']
# [' juan klammer', ' No', ' Person']
# [' keine Person', ' No', ' Person']
# [' Hosting Hosting', ' No', ' Company']
# [' Mike sebaut', ' No', ' Person']
# [' Station BRNA', ' No', ' Person']
# [' marco marnrecaj', ' No', ' Person']
# [' Diem cpl 4733', ' No', ' Person']
# [' Sans Souci', ' No', ' Person']
# [' Direkt AG', ' No', ' Company']
# [' laurent tournay', ' No', ' Person']
# [' c/o SIRON Massimo Fumagalli', ' No', ' Company']
# [' vanessa borel miceli', ' No', ' Person']
# [' Wohn- u.Pflegezentrum Berghof', ' No', ' Company']
# [' lukas blabol', ' No', ' Person']
# [' ronald schmid', ' No', ' Person']
# [' Hubacher Esther', ' No', ' Person']
# [' Dave Alkesm', ' No', ' Person']
# [' ILARDI Stefano', ' No', ' Person']
# [' TERENCE NIBA', ' No', ' Person']
# [' Leutenegger Carla', ' No', ' Person']
# [' M Räber', ' No', ' Person.']
# [' Oliver keine Produkte Paschaweh', ' No', ' Person']
# [' churchill robert', ' No', ' Person']
# [' Magnin', ' No', ' Person']
# [' z.H.v. Geschäftsleitung', ' No', ' Company']
# [' sensitive Lebensberatung für die Frau', ' No', ' Company']
# [' thorsten jung', ' No', ' Person']
# [' romain zlotykamien', ' No', ' Person']
# [' wadid skander', ' No', ' Person']
# [' Caritas Ticino', ' No', ' Company']
# [' Abteilung Network', ' No', ' Company']
# [' Empfang Paraplegie', ' No', ' Company']
# [' Test Muster', ' No', ' Person']
# [' alain gerber', ' No', ' Person']
# [' Oliver keine Produkte Paschaweh', ' No', ' Person']
# [' Grenzpaket Pilss 82897 Dinah K Grenzpaket Pilss 82897 Dinah K', ' No', ' Company']
# [' dummy datenmüll', ' No', ' Person']
# [' NTT Cloud Communications SAS', ' No', ' Company']
# [' . .', ' No', ' Person']
# [' . Hohl', ' No', ' Person']
# [' luljeta nreca', ' No', ' Person']
# [' Maël Nicolo Serge calvados', ' No', ' Person']
# [' Dietler', ' No', ' Person']
# [' Y. von Rotz', ' No', ' Person']
# [' Court', ' No', ' Person']
# [' M. Dal Bosco', ' No', ' Person']
# [' Simon-Pierre weber', ' No', ' Person']
# [' Sektion Funkkonzessionen', ' No', ' Company']
# [' Ambauen', ' No', ' Person']
# [' x y', ' No', ' Person']
# [' therese schneider', ' No', ' Person']
# [' G. Bianchi', ' No', ' Person']
# [' S. Contratto', ' No', ' Person']
# [' ROGER ZUCCHERO', ' No', ' Person']
# [' Aka TIGORI', ' No', ' Person']
# [' reichen sébastien', ' No', ' Person']
# [' Jordan Fiduciaire', ' No', ' Person']
# [' Chrisitian Jacquet', ' No', ' Person']
# [' Jean-baptiste Mottiez', ' No', ' Person']
# [' miguel casimiro', ' No', ' Person']
# [' Gebhard', ' No', ' Person']
# [' dummy doublette', ' No', ' Person']
# [' Oliver keine Produkte Paschaweh', ' No', ' Person']
# [' rahel sandoz', ' No', ' Person']
# [' tester tester', ' No', ' Person']
# [' Entner', ' No', ' Person']
# [' yvan schneeberger', ' No', ' Person']
# [' - -', ' No', ' Person']
# [' Lichtensteiger', ' No', ' Person']
# [' keine Person', ' No', ' Person']
# [' pl vairavan', ' No', ' Person']
# [' Silling', ' No', ' Person']
# [' Swisscom Fixnet', ' No', ' Company']
# [' Kontakt Korrespondenz', ' No', ' Company']
# [' - -', ' No', ' Person']
# [' carlo de marinis', ' No', ' Person']
# [' ROCCO ZARBA', ' No', ' Person']
# [' sebastien reichen', ' No', ' Person']
# [' Leandro Ota Kanashiro', ' No', ' Person']
# [' arnaud janin', ' No', ' Person']
# [' Ouvre', ' No', ' Person']
# [' Bauer', ' No', ' Person']
# [' J. Ehrler', ' No', ' Person']
# [' S. Schober', ' No', ' Person']
# [' Vorstand RaBe', ' No', ' Company']
# [' Stoffel', ' No', ' Person']
# [' Schweizerische Post Telefonie Fachdienst IT17.21', ' No', ' Company']
# [' Blattner', ' No', ' Person']
# [' Webmaster WestLakeChurch', ' No', ' Company']
# [' Firma Accs GmbH', ' No', ' Company']
# [' Rüegg', ' No', ' Person']
# [' Fiberlink Operation', ' No', ' Company']
# [' Colt Technology', ' No', ' Company']
# [' BAKOM #Ansprechperson', ' No', ' Company']
# [' ferdy de martin', ' No', ' Person']
# [' Riesner', ' No', ' Person']
# [' raphael jost', ' No', ' Person']
# [' Tabea & Matthias Rieder', ' No', ' Person']
# [' enzo stretti', ' No', ' Person']
# [' Lenggenhager', ' No', ' Person']
# [' Gerber', ' No', ' Company']
# [' VeryFile SAGL VeryFile SAGL', ' No', ' Company']
# [' Oliver keine Produkte Paschaweh', ' No', ' Person']
# [' Filomene Belardi Denis Leygue', ' No', ' Person']
# [' Konstantin', ' No', ' Person']
# [' Raphaël/Thierry/Pierluigi Laub/Luc/Orunesu', ' No', ' Person']
# [' Administrator CANA', ' No', ' Company']
# [' Marco Kälin Arztpraxis', ' No', ' Company']
# [' Grimm Dr. A.', ' No', ' Person']
# [' - -', ' No', ' Person']
# [' Brulhart', ' No', ' Person']
# [' agron Selimi', ' No', ' Person']
# [' x x', ' No', ' Person']
# [' laurent Benhamou', ' No', ' Person']
# [' L. Schöb', ' No', ' Person']
# [' Muszynski Norbert', ' No', ' Person']
# [' lionel taisne', ' No', ' Person']
# [' Brunner', ' No', ' Person']
# [' Kaptan', ' No', ' Person']
# [' B Gaillard', ' No', ' Person']
# [' Refile Satir', ' No', ' Person']
# [' daniel De rosier', ' No', ' Person']
# [' .ch Marschall', ' No', ' Person']
# [' O Verheijen', ' No', ' Person']
# [' Augsburger', ' No', ' Company']
# [' Peter Dr. Wiehl', ' No', ' Person']
# [' Hoseneder Michael', ' No', ' Person']
# [' sprechzeit24.de GmbH', ' No', ' Company']
# [' Patricia WALTER-OUSSET', ' No', ' Person']
# [' Firma Telefonica di TL SAS', ' No', ' Company']
# [' Lecompte', ' No', ' Person']
# [' forca lina', ' No', ' Person']
# [' xxx', ' No', ' Person']
# [' pavel izmaylov', ' No', ' Person']
# [' olivier imesch', ' No', ' Person']
# [' frank Metzker', ' No', ' Person']
# [' Häni', ' No', ' Person']
# [' Kantonsuser Schaffhausen', ' No', ' Company']
# [' janin arnaud', ' No', ' Person']
# [' Mirta kujundzic', ' No', ' Person']
# [' Grotta', ' No', ' Company']
# [' Cina', ' No', ' Person']
# [' Pieter-Jan TER KUILE', ' No', ' Person']
# [' Filippo Carlino-Cosma', ' No', ' Person']
# [' Angst', ' No', ' Person']
# [' Fischer', ' No', ' Person']
# [' richard di feliciantonio', ' No', ' Person']
# [' Bernasconi Michele', ' No', ' Person']
# [' Angelegenheit Mühsam', ' No', ' Person']
# [' Schneider Andreas', ' No', ' Person']
# [' Elia Davide Matteo Ponti', ' No', ' Person']
# [' Samuel [zu deaktivieren] Mäder', ' No', ' Person']
# [' juan-manuel widmer', ' No', ' Person']
# [' Galli', ' No', ' Person']
# [' Bernardini Loris Carlo', ' No', ' Person']
# [' jugoslav ilic', ' No', ' Person']
# [' Hubertus & Rico Hollenweger', ' No', ' Company']
# [' Bender', ' No', ' Person']
# [' System Administrator [CTYS]', ' No', ' Company']
# [' Support Naef', ' No', ' Company']
# [' Gächler', ' No', ' Person']
# [' P. Hörig', ' No', ' Person']
# [' J. Tender', ' No', ' Person']
# [' SPYRIDOn KOUFOs', ' No', ' Person']
# [' walbert pierre', ' No', ' Person']
# [' clara eelbode', ' No', ' Person']
# [' Spasic Sasa', ' No', ' Person']
# [' Roland Marti (Privat)', ' No', ' Person']
# [' Beisheim', ' No', ' Company']
# [' Werner baumann', ' No', ' Person']
# [' sonia cotting', ' No', ' Person']
# [' U V', ' No', ' Person']
# [' Kantonsuser Bern', ' No', ' Company']
# [' Oliver keine Produkte Paschaweh', ' No', ' Person']
# [' SMVA-ZLIA Location', ' No', ' Company']
# [' Max schnydrig', ' No', ' Person']
# [' florim krasniqi', ' No', ' Person']
# [' Paul jun. von Arx', ' No', ' Person']
# [' skender neziraj', ' No', ' Person']
# [' Pascal MARTELON', ' No', ' Person']
# [' A. Blaser', ' No', ' Person']
# [' Abdelaziz RAHMOUNE', ' No', ' Person']
# [' M. Hänni', ' No', ' Person']
# [' F. Bruhin', ' No', ' Person']
# [' Hofer Bettina', ' No', ' Person']
# [' Ogielegua Philip Philip', ' No', ' Person']
# [' RICHARD COL', ' No', ' Company']
# [' Beer Alois Radiotelevisiun Svizra Rumants', ' No', ' Company']
# [' Roland Jung Triotel AG', ' No', ' Company']
# [' Elmar Isler Edorex', ' No', ' Company']
# [' Programm Melder', ' No', ' Company']
# [' Bereichsleiter Systems Engineering', ' No', ' Company']
# [' Global Liquidity Jean-Marc Beyler', ' No', ' Company']
# [' Maxime Rue du Léman 14', ' No', ' Company']
# [' Cyberlife Sàrl', ' No', ' Company']
# [' Dini Pusteblueme AG', ' No', ' Company']
# [' ICT Support Telecom', ' No', ' Company']
# [' - -', ' No', ' Person']
# [' Management SA GCC', ' No', ' Company']
# [' IT Support', ' No', ' Company']
# [' eric gautier', ' No', ' Person']
# [' Level7 Systems', ' No', ' Company']
# [' Wessels', ' No', ' Person']
# [' susana gimeno', ' No', ' Person']
# [' Ivan camponovo', ' No', ' Person']
# [' Küpfer', ' No', ' Person.']
# [' corinne roduit', ' No', ' Person']
# [' IT Department', ' No', ' Company']
# [' Sandra Müller Buro', ' No', ' Company']
# [' Securitas AG', ' No', ' Company']
# [' Shelduck Production', ' No', ' Company']
# [' andreas wirz', ' No', ' Person']
# [' arno janin', ' No', ' Person']
# [' peter frauchiger', ' No', ' Person']
# [' ivan miric', ' No', ' Person']
# [' Ztelcom', ' No', ' Company']
# [' Fritz + Caspar Jenny', ' No', ' Company']
# [' giorgio turri', ' No', ' Person']
# [' janin arnaud', ' No', ' Person']
# [' KATIA CRANTOR', ' No', ' Person']
# [' basile laune', ' No', ' Person']
# [' Evequoz', ' No', ' Person']
# [' Ammann Daniel', ' No', ' Person']
# [' - -', ' No', ' Person']
# [' joel barata', ' No', ' Person']
# [' Jean-James NATTIER LUX MANACOM JCR', ' No', ' Person']
# [' Markus / Henning Dudler / Luedtke', ' No', ' Person']
# [' Network Team Network Team', ' No', ' Company']
# [' Thüler', ' No', ' Person']
# [' Spitzhorn', ' No', ' Person']
# [' B. Greil', ' No', ' Person']
# [' ENT LU Technik', ' No', ' Company']
# [' Pak', ' No', ' Person']
# [' Oliver Hort c/o Hygolet AG', ' No', ' Company']
# [' Elektro Brühlmann', ' No', ' Company']
# [' Kuoni Network', ' No', ' Company']
# [' TP-NA Secrétariat', ' No', ' Company']
# [' vick capt', ' No', ' Person']
# [' Da Silva', ' No', ' Person']
# [' Wüst', ' No', ' Person']
# [' Oliver keine Produkte Paschaweh', ' No', ' Person']
# [' jesus sauca', ' No', ' Person']
# [' Jan René Perret-Gentil Dreifuss', ' No', ' Person']
# [' nurten avci', ' No', ' Person']
# [' Regamey', ' No', ' Person']
# [' christoph risler', ' No', ' Person']
# [' Sennhauser', ' No', ' Person']
# [' Massimo c/o SIRON Fumagalli', ' No', ' Company']
# [' Pascale Rérat c/o A. Le Moal', ' No', ' Company']
# [' Jensen Nils Erik', ' No', ' Person']
# [' Graziella Ben Amara - Puglisi', ' No', ' Person']
# [' Dr. Mourad Aichi', ' No', ' Person']
# [' Eric Jean V-BOUCHET', ' No', ' Person']
# [' e huber', ' No', ' Person']
# [' walter Fumagalli', ' No', ' Person']
# [' e müller', ' No', ' Person']
# [' juan crétin', ' No', ' Person']
# [' Sonja Meier', ' No', ' Person']
# [' Kipfer', ' No', ' Person']
# [' Weilenmann', ' No', ' Person']
# [' Vogel', ' No', ' Person']
# [' Kettle Mark', ' No', ' Person']
# [' Aptel', ' No', ' Person']
# [' VoiceSolutionCenter EMEA', ' No', ' Company']
# [' AG Effems', ' No', ' Company']
# [' Hübscher Matthias', ' No', ' Person']
# [' Schädler', ' No', ' Person']
# [' G. Moser', ' No', ' Person']
# [' Stücklin', ' No', ' Person']
# [' Trajanov', ' No', ' Person']
# [' sebastien weiss', ' No', ' Person']
# [' dummy doublette', ' No', ' Person']
# [' da Silva Rui', ' No', ' Person']
# [' rudolf Brauchli', ' No', ' Person']
# [' Rufnummernverwaltung', ' No', ' Company']
# [' Schürmann', ' No', ' Person']
# [' Buck', ' No', ' Person']
# [' R. Schmid', ' No', ' Person']
# [' Willi Kühnis / G. Gerdes', ' No', ' Person']
# [' Kummer', ' No', ' Person']
# [' M. Ansermot', ' No', ' Person']
# [' A. Bauer', ' No', ' Person']
# [' W. Schwarzwälder', ' No', ' Person']
# [' HB9VC', ' No', ' Person']
# [' Jürg Huber Präsident', ' No', ' Person']
# [' Iseppi', ' No', ' Person']
# [' Syrup', ' No', ' Person']
# ['Jean-luc Charmillot', ' No', ' Person']
# [' Pierre-Alain Artique', ' No', ' Person']
# [' Christian Strubel / Hermann Spring', ' No', ' Person']
# [' c/o Thomas Benz', ' No', ' Person']
# [' yann LE BOUAR', ' No', ' Person']
# [' LAMINE MBAYE', ' No', ' Person']
# [' Hr. Riederer', ' No', ' Person']
# [' Alain Marcel Borgeaud-dit-Avocat', ' No', ' Person']
# [' Werner u. Denise Kälin', ' No', ' Person']
# [' Rolf Paul + Eva Zahnd Gross', ' No', ' Person']
# [' Ballongruppe Zentralschweiz', ' No', ' Company']
# ['Marie Claire Mireille Delvecchio', ' No', ' Person']
# [' Matthew Thomas Reiter', ' No', ' Person']
# [' Jean-Pierre Sauvain', ' No', ' Person']
# [' Barnabas Csoport', ' No', ' Company']
# [' Davide Cafiero-Donadini', ' No', ' Person']
# [' BAKOMONLINE TESTS', ' No', ' Company']
# [' marco romano scherini', ' No', ' Person']
# [' samuel Clot', ' No', ' Person']
# [' David Valentino Franz Krammer', ' No', ' Person']
# [' Giacomo Andrea Adolfo Castioni', ' No', ' Person']
# [' Jean Arnaud de Mestral', ' No', ' Person']
# [' Morell Arne Westermann', ' No', ' Person']
# [' Romina Claudia Schachner-Bäriswyl', ' No', ' Person']
# [' Achille Aloys Corminboeuf', ' No', ' Person']
# [' Alexandre François Perrochet', ' No', ' Person']
# ['Helmut Gerhard Hendrik Werdin', ' No', ' Person']
# [' Markus Christian Schneider', ' No', ' Person']
# [' Simon Urs Hämmerli', ' No', ' Person']
# [' Giovan Maria Tattarletti', ' No', ' Person']
# [' Andreas Hans Hoffmann', ' No', ' Person']
# [' Jean-Jacques Bogno', ' No', ' Person']
# [' Yvonne Meier-Bukowiecki', ' No', ' Person']
# [' Michael Stefan Räss', ' No', ' Person']
# [' Hans Jürg Grieder', ' No', ' Person']
# [' Michael Müller-Schweikart', ' No', ' Person']
# [' Jürg Reto Roffler', ' No', ' Person']
# [' Madeleine Edith Rüesch Mauchle', ' No', ' Person']
# [' Jean-Claude Maillard', ' No', ' Person']
# [' Roger Daniel Hesse', ' No', ' Person']
# [' christoph uhlmann', ' No', ' Person']
# [' Rene Hügli', ' No', ' Person']
# [' Nina und Andreas Lehmann', ' No', ' Person']
# [' PATLICO AG', ' No', ' Company']
# [' oliver senn', ' No', ' Person']
# [' julien sangouard', ' No', ' Person']
# [' Peter Von Gunten', ' No', ' Person']
# [' Thierry Werner Raphael Kramis', ' No', ' Person']
# [' Marie Paule Lentillon-Destefani', ' No', ' Person']
# [' Claire Van Geert-Henry', ' No', ' Person']
# ['Alain Léo Paul Marcel Vaissade', ' No', ' Person']
# [' Delivery Service', ' No', ' Company']
# [' Radio Gwendalyn', ' No', ' Person']
# [' Bonacin', ' No', ' Person']
# [' Miserez', ' No', ' Person']
# [' Adler', ' No', ' Person']
# [' Goar [zu deaktivieren] Schweizer', ' No', ' Person']
# [' G. Stäheli', ' No', ' Person']
# [' West', ' No', ' Person']
# [' Web Master MMservizi', ' No', ' Company']
# [' pascal urbani', ' No', ' Person']
# [' Jvan Giuseppe Mastrototaro', ' No', ' Person']
# [' WFS Communications Service GmbH', ' No', ' Company']
# [' Vinzio', ' No', ' Person']
# [' Informatik Center', ' No', ' Company']
# [' IT ECNE', ' No', ' Company']
# [' Pascale DETROIT', ' No', ' Company']
# [' Würmli', ' No', ' Company']
# [' yvana cauvarel', ' No', ' Person']
# [' aurora bianchi', ' No', ' Person']
# [' F. Lauber', ' No', ' Person']
# [' K. Ott', ' No', ' Person']
# [' F. Meyer', ' No', ' Person']
# [' Service-Center CH/LI Kiwanis', ' No', ' Company']
# [' Catherine c/o Ecovie Sàrl Tourinan', ' No', ' Company']
# [' Vendor contracts', ' No', ' Company']
# [' AS Marlink', ' No', ' Company']
# [' S. Simeon', ' No', ' Person']
# [' Bellarmino Bellarmino', ' No', ' Person']
# [' Koller', ' No', ' Person']
# [' Montanhas', ' No', ' Person']
# [' tim Seidel', ' No', ' Person']
# [' Schwarzinger Dietrich', ' No', ' Person']
# [' Hr. Fenner', ' No', ' Person']
# [' Krienbühl', ' No', ' Person']
# [' A. Buralli', ' No', ' Person']
# [' dummy datenmüll', ' No', ' Person']
# [' Ja No', ' No', ' Person']
# [' Halter', ' No', ' Person']
# [' Servicedesk Post', ' No', ' Company']
# [' Jean-philippe Suter', ' No', ' Person']
# [' Wegmann', ' No', ' Company']
# [' paolo colia', ' No', ' Person']
# [' KATIA DE PASCALI', ' No', ' Person']
# [' Remi SEBAG', ' No', ' Person']
# [' guy roland jipguep', ' No', ' Person']
# [' Einwohnergemeinde Brügg Soziale Dienste', ' No', ' Company']
# [' Abt. TTEC Peter Wurmet', ' No', ' Company']
# [' Schweizer Verband Tel143 Die Dargebotene Hand', ' No', ' Company']
# [' anonymous', ' No', ' Person']
# [' Redaelli', ' No', ' Person']
# [' F Merki', ' No', ' Person']
# [' Pichler', ' No', ' Person']
# [' A. Steiner', ' No', ' Person']
# [' Ferrari Geo', ' No', ' Company']
# [' Roger Widmer@upag.ch', ' No', ' Person']
# [' adj J. Beuchat Coordinateur technique', ' No', ' Person']
# [" d'éléctricité TEAMELEC S.à.r.l.", ' No', ' Company']
# [' Unité Telecom DSI - CEI', ' No', ' Company']
# [' keine Person', ' No', ' Person']
# [' Borel', ' No', ' Person']
# [' Kadiatou Sarr Gaspoz C/o Burgy Nicolas', ' No', ' Person']
# [' e huber', ' No', ' Person']
# [' ncdh ncdh', ' No', ' Person']
# [' juan crétin', ' No', ' Person']
# [' D. Graziano', ' No', ' Person']
# [' ltd blue cristal', ' No', ' Company']
# [' Louis v.Heaven', ' No', ' Person']
# [' Michaël Haroun Case postale 265', ' No', ' Person']
# [' Sutter', ' No', ' Person']
# [' R. Pulfer', ' No', ' Person']
# [' sergio manuel de oliveira martins', ' No', ' Person']
# [' Hanspeter Burri+ Vivi Pfiffner', ' No', ' Person']
# [' Ing. HTL Peter Mrotzek', ' No', ' Person']
# [' madvee solay', ' No', ' Person']
# [' Bühler Urs Seematter AG', ' No', ' Company']
# [' Toller Unternehmungen AG', ' No', ' Company']
# [' ICT.CH Astara', ' No', ' Company']
# [' rezn Produktmanagement', ' No', ' Company']
# [' - -', ' No', ' Person']
# [' - -', ' No', ' Person']
# [' x y', ' No', ' Person']
# [' - -', ' No', ' Person']
# [' Anupama Fraknlin', ' No', ' Person']
# [' Procurement team', ' No', ' Company']
# [' - -', ' No', ' Person']
# [' - -', ' No', ' Person']
# [' jonas buehler', ' No', ' Person']
# [' anna munz', ' No', ' Person']
# [' - -', ' No', ' Person']

# %%
df_results[df_results["Name_incorrect"] == True]
# Out:
#                                      Name Name_order Entity_type  \
# 5                            johann Frain         No      Person
# 16                     KENNETH COSTANTINO         No      Person
# 27                           bernd wagner         No      Person
# 41      Santana Fonseca Mathieu Marineide         No      Person
# 63                            arlo gonser         No      Person
# ...                                   ...        ...         ...
# 38678                                 - -         No      Person
# 38692                                 - -         No      Person
# 38700                       jonas buehler         No      Person
# 38740                           anna munz         No      Person
# 38743                                 - -         No      Person
#
#        Name_incorrect  company_name
# 5                True         False
# 16               True         False
# 27               True         False
# 41               True         False
# 63               True         False
# ...               ...           ...
# 38678            True         False
# 38692            True         False
# 38700            True         False
# 38740            True         False
# 38743            True         False
#
# [448 rows x 5 columns]

# %%
# After processing the results and updating the DataFrame
# Save results to pickle
with open('output/Personen_Namen_check.pickle', 'wb') as f:
    pickle.dump(df_personen, f)

# You can also save just the results if you prefer
# with open('output/results.pickle', 'wb') as f:
#     pickle.dump(results, f)

print("Results saved to pickle file.")

# To load the pickle file later:
# with open('output/Personen_Namen_check.pickle', 'rb') as f:
#     loaded_df = pickle.load(f)
# Out:
# Results saved to pickle file.

# %%
with open('output/Personen_Namen_check.pickle', 'rb') as f:
    gpt_output = pickle.load(f)

# %%
gpt_output
# Out:
#                                 ReferenceID            Objekt  \
# 0      0000D9C7-6B29-4B1F-9FA0-3685B47682D3   Fassatoui Karim
# 1      0003c120-f044-4df6-84ef-330fb82d911e      Kramis Simon
# 2      0004ABC1-956E-4EFD-A6B1-EE142BE3EF09    Leplat Patrick
# 3      00066A4F-0A0C-48BC-B0BF-30CBC471C1BE     Schwarz Joerg
# 4      0008BCBB-7FCE-4A26-9407-4880934BA14B     Storz Patrick
# ...                                     ...               ...
# 38853  ff390915-f6e8-43d6-a007-f61ce66932e0   Deslarzes David
# 38854  ff82fc37-603c-4b1e-9262-192229d175b2       Schmid Ivan
# 38855  ff85f15d-c67b-4407-9808-a183ca1d87b5    Tuskan Mustafa
# 38856  ff9c0b4e-979f-47bc-9386-a5f27db33af9     Raoux Mathieu
# 38857  ffc4b701-8171-4e83-aa3e-ffb753a3d2d3  Freienstein Eric
#
#                    Name     Typ  Aktiv           UID_CHID  Zeile2  \
# 0       karim fassatoui  Person   True                        NaN
# 1          simon kramis  Person   True                        NaN
# 2        patrick leplat  Person   True                        NaN
# 3         joerg schwarz  Person   True                        NaN
# 4         patrick storz  Person   True  NotRegisteredCHId     NaN
# ...                 ...     ...    ...                ...     ...
# 38853   david deslarzes  Person   True  NotRegisteredCHId     NaN
# 38854       ivan schmid  Person   True  NotRegisteredCHId     NaN
# 38855    mustafa tuskan  Person   True  NotRegisteredCHId     NaN
# 38856     mathieu raoux  Person   True           11100069     NaN
# 38857  eric freienstein  Person   True            8715832     NaN
#
#        Zeile2Laenge  Zeile3  Zeile3Laenge  ... Produkt_rolle Produkt_RefID  \
# 0                 0     NaN             0  ...            []            []
# 1                 0     NaN             0  ...            []            []
# 2                 0     NaN             0  ...            []            []
# 3                 0     NaN             0  ...            []            []
# 4                 0     NaN             0  ...            []            []
# ...             ...     ...           ...  ...           ...           ...
# 38853             0     NaN             0  ...            []            []
# 38854             0     NaN             0  ...            []            []
# 38855             0     NaN             0  ...            []            []
# 38856             0     NaN             0  ...            []            []
# 38857             0     NaN             0  ...            []            []
#
#       Geschaeftspartner                              Verknuepfungsart_list  \
# 0                    []                                        [Sonstiges]
# 1                    []                                                 []
# 2                    []                                      [Mitarbeiter]
# 3                    []                                      [Mitarbeiter]
# 4                    []                                    [Administrator]
# ...                 ...                                                ...
# 38853                []                                                 []
# 38854                []                                    [Administrator]
# 38855                []                                    [Administrator]
# 38856                []  [Administrator, Administrator, Administrator, ...
# 38857                []                                 [Geschäftspartner]
#
#                                  VerknuepftesObjekt_list  \
# 0                                      [Fassatoui Karim]
# 1                                                     []
# 2                                       [RCI Finance SA]
# 3                                [Girgin Switzerland AG]
# 4                                     [Great Stuff GmbH]
# ...                                                  ...
# 38853                                                 []
# 38854                                       [Payrexx AG]
# 38855                                       [Modissa AG]
# 38856  [GVVN - Groupe de vol à voile Neuchâtel, Group...
# 38857                        [Freienstein Eric - 415030]
#
#                                VerknuepftesObjektID_list  \
# 0                 [966E1EA1-F258-4F75-A030-350CFAEEBC15]
# 1                                                     []
# 2                 [D604A8C4-A867-44F3-BE02-FE9E8FEEBC6C]
# 3                 [AD4E87D0-A044-4AD8-8AC1-26C94A362812]
# 4                 [6436C7FD-2BCD-4692-B6DF-0908DA51D4D0]
# ...                                                  ...
# 38853                                                 []
# 38854             [1b81f7e2-6e24-4b65-88f4-15c4cbf580b1]
# 38855             [46a10715-613b-449b-acba-b01c47fde57f]
# 38856  [31910cb0-818d-42c4-9a82-51009d22072e, CUSTOME...
# 38857             [0B9E1B86-FBB3-4406-B23E-97D69BE2EC6B]
#
#       Geschaeftspartner_list UID_CHID_check score  \
# 0                         []              0     0
# 1                         []              0   120
# 2                         []              0    50
# 3                         []              0    50
# 4                         []              1   170
# ...                      ...            ...   ...
# 38853                     []              1    80
# 38854                     []              1   170
# 38855                     []              1   170
# 38856                     []              2   810
# 38857                     []              2   450
#
#                                            score_details
# 0
# 1                       Servicerole_string 100, Email 20
# 2                                    Verknuepfungsart 50
# 3                                    Verknuepfungsart 50
# 4                 UID 50, Verknuepfungsart 100, Email 20
# ...                                                  ...
# 38853                  UID 50, ObjektZeiger 10, Email 20
# 38854             UID 50, Verknuepfungsart 100, Email 20
# 38855             UID 50, Verknuepfungsart 100, Email 20
# 38856  Geschaeftsobjekte 180, UID 100, Verknuepfungsa...
# 38857  Geschaeftsobjekte 90, UID 100, Versandart 100,...
#
# [38858 rows x 52 columns]

# %% [markdown]
# # Singular Personen
# Personen die weder eine Verbindung zu anderen Organisationen, noch irgendwelche Produkte haben

# %%
import os
import datetime

# pickle_file_path = "../GraphViewerApp/data/calculated/personen_organisationen_dfs_processed.pickle"
pickle_file_path = "data/calculated/personen_organisationen_dfs_processed.pickle"

# Display the last modified time of the pickle file
last_modified_time = os.path.getmtime(pickle_file_path)
print("Last modified time:", datetime.datetime.fromtimestamp(last_modified_time))

with open(pickle_file_path, "rb") as file:
    dfs = pickle.load(file)
df_personen = dfs["personen"]
df_organisationen = dfs["organisationen"]
# Out:
# Last modified time: 2024-11-15 10:26:20.841578

# %%
df_singular_personen = df_personen[
    (df_personen["Produkt_rolle"].apply(lambda x: len(x) == 0)) &
    (df_personen["Verknuepfungsart_list"].apply(lambda x: x == [''])) &
    (df_personen["Geschaeftspartner_list"].apply(lambda x: len(x) == 0)) &
    (df_personen["Servicerole_string"] == "") &
    (df_personen["AnzahlGeschaeftsobjekte"] == 0)
]

df_singular_personen
# Out:
#                                 ReferenceID               Objekt  \
# 24     0058455e-307a-4021-ac82-57276e017754        Boskovic Rada
# 48     00A8F7A9-B8E0-4814-8CF8-22E47F1C5B70      Da Tos Gabriele
# 81     016A0287-9984-4D80-98C1-A768AE05E804         Schmalz Eric
# 94     01ABA361-D9D3-49C2-A334-C16E3F22A75C         Egger Joëlle
# 164    02f23790-bac9-41f3-9a1d-a0c17b357be7      Baños Francisco
# ...                                     ...                  ...
# 38154  e86958b1-8ec5-4d7b-83e7-4dde36b00677    Beltrami Maurizio
# 38241  f4cae53e-c592-4278-a5b0-429c6d42fde9  Auger Jean-François
# 38260  f8541ba2-fd50-4dd0-9e6e-3deb4417e681     Berthold Nicolas
# 38292  fc01aff1-5f74-40b9-b941-5988c195fc58        Nannini Elisa
# 38314  ff390915-f6e8-43d6-a007-f61ce66932e0      Deslarzes David
#
#                       Name     Typ  Aktiv           UID_CHID  Zeile2  \
# 24           rada boskovic  Person   True            9806205     NaN
# 48         gabriele da tos  Person   True            7501556     NaN
# 81            eric schmalz  Person   True            8157583     NaN
# 94            joëlle egger  Person   True            7875343     NaN
# 164        francisco baños  Person   True           10047295     NaN
# ...                    ...     ...    ...                ...     ...
# 38154    maurizio beltrami  Person   True            8846613     NaN
# 38241  jean-françois auger  Person   True            9380927     NaN
# 38260     nicolas berthold  Person   True            9203129     NaN
# 38292        elisa nannini  Person   True            9378881     NaN
# 38314      david deslarzes  Person   True  NotRegisteredCHId     NaN
#
#        Zeile2Laenge  Zeile3  Zeile3Laenge  ... Produkt_rolle Produkt_RefID  \
# 24                0     NaN             0  ...            []            []
# 48                0     NaN             0  ...            []            []
# 81                0     NaN             0  ...            []            []
# 94                0     NaN             0  ...            []            []
# 164               0     NaN             0  ...            []            []
# ...             ...     ...           ...  ...           ...           ...
# 38154             0     NaN             0  ...            []            []
# 38241             0     NaN             0  ...            []            []
# 38260             0     NaN             0  ...            []            []
# 38292             0     NaN             0  ...            []            []
# 38314             0     NaN             0  ...            []            []
#
#       Geschaeftspartner Verknuepfungsart_list VerknuepftesObjekt_list  \
# 24                   []                    []                      []
# 48                   []                    []                      []
# 81                   []                    []                      []
# 94                   []                    []                      []
# 164                  []                    []                      []
# ...                 ...                   ...                     ...
# 38154                []                    []                      []
# 38241                []                    []                      []
# 38260                []                    []                      []
# 38292                []                    []                      []
# 38314                []                    []                      []
#
#       VerknuepftesObjektID_list Geschaeftspartner_list UID_CHID_check score  \
# 24                           []                     []              2   220
# 48                           []                     []              2   220
# 81                           []                     []              2   210
# 94                           []                     []              2   220
# 164                          []                     []              2   210
# ...                         ...                    ...            ...   ...
# 38154                        []                     []              2   210
# 38241                        []                     []              2   210
# 38260                        []                     []              2   210
# 38292                        []                     []              2   210
# 38314                        []                     []              1    80
#
#                            score_details
# 24     UID 100, Versandart 100, Email 20
# 48     UID 100, Versandart 100, Email 20
# 81     UID 100, Versandart 100, Email 10
# 94     UID 100, Versandart 100, Email 20
# 164    UID 100, Versandart 100, Email 10
# ...                                  ...
# 38154  UID 100, Versandart 100, Email 10
# 38241  UID 100, Versandart 100, Email 10
# 38260  UID 100, Versandart 100, Email 10
# 38292  UID 100, Versandart 100, Email 10
# 38314  UID 50, ObjektZeiger 10, Email 20
#
# [501 rows x 52 columns]

# %%
cols_to_keep=["ReferenceID", "Name_original", "Objekt_link", "UID_CHID", "address_full", "EMailAdresse", "Telefonnummer"]
df_singular_personen[cols_to_keep].to_excel('output/Personen_ohne_Verbindungen_ohne_Produkte.xlsx', index=False)

# %%
df_personen[df_personen["Produkt_rolle"].apply(lambda x: len(x) == 0)]
# Out:
#                                 ReferenceID            Objekt  \
# 0      0003c120-f044-4df6-84ef-330fb82d911e      Kramis Simon
# 1      0004ABC1-956E-4EFD-A6B1-EE142BE3EF09    Leplat Patrick
# 2      00066A4F-0A0C-48BC-B0BF-30CBC471C1BE     Schwarz Joerg
# 3      0008BCBB-7FCE-4A26-9407-4880934BA14B     Storz Patrick
# 4      0009AC82-AFBE-4A44-8C92-D2DB0EE4E736      Frain johann
# ...                                     ...               ...
# 38121  ff390915-f6e8-43d6-a007-f61ce66932e0   Deslarzes David
# 38122  ff82fc37-603c-4b1e-9262-192229d175b2       Schmid Ivan
# 38123  ff85f15d-c67b-4407-9808-a183ca1d87b5    Tuskan Mustafa
# 38124  ff9c0b4e-979f-47bc-9386-a5f27db33af9     Raoux Mathieu
# 38125  ffc4b701-8171-4e83-aa3e-ffb753a3d2d3  Freienstein Eric
#
#                    Name     Typ  Aktiv           UID_CHID  Zeile2  \
# 0          simon kramis  Person   True                        NaN
# 1        patrick leplat  Person   True                        NaN
# 2         joerg schwarz  Person   True                        NaN
# 3         patrick storz  Person   True  NotRegisteredCHId     NaN
# 4          johann frain  Person   True                        NaN
# ...                 ...     ...    ...                ...     ...
# 38121   david deslarzes  Person   True  NotRegisteredCHId     NaN
# 38122       ivan schmid  Person   True  NotRegisteredCHId     NaN
# 38123    mustafa tuskan  Person   True  NotRegisteredCHId     NaN
# 38124     mathieu raoux  Person   True           11100069     NaN
# 38125  eric freienstein  Person   True            8715832     NaN
#
#        Zeile2Laenge  Zeile3  Zeile3Laenge  ... Produkt_rolle Produkt_RefID  \
# 0                 0     NaN             0  ...            []            []
# 1                 0     NaN             0  ...            []            []
# 2                 0     NaN             0  ...            []            []
# 3                 0     NaN             0  ...            []            []
# 4                 0     NaN             0  ...            []            []
# ...             ...     ...           ...  ...           ...           ...
# 38121             0     NaN             0  ...            []            []
# 38122             0     NaN             0  ...            []            []
# 38123             0     NaN             0  ...            []            []
# 38124             0     NaN             0  ...            []            []
# 38125             0     NaN             0  ...            []            []
#
#       Geschaeftspartner                              Verknuepfungsart_list  \
# 0                    []                                                 []
# 1                    []                                      [Mitarbeiter]
# 2                    []                                      [Mitarbeiter]
# 3                    []                                    [Administrator]
# 4                    []                                      [Mitarbeiter]
# ...                 ...                                                ...
# 38121                []                                                 []
# 38122                []                                    [Administrator]
# 38123                []                                    [Administrator]
# 38124                []  [Administrator, Administrator, Administrator, ...
# 38125                []                                 [Geschäftspartner]
#
#                                  VerknuepftesObjekt_list  \
# 0                                                     []
# 1                                       [RCI Finance SA]
# 2                                [Girgin Switzerland AG]
# 3                                     [Great Stuff GmbH]
# 4                                         [Frain Johann]
# ...                                                  ...
# 38121                                                 []
# 38122                                       [Payrexx AG]
# 38123                                       [Modissa AG]
# 38124  [Groupe de vol à voile, GVVN - Groupe de vol à...
# 38125                        [Freienstein Eric - 415030]
#
#                                VerknuepftesObjektID_list  \
# 0                                                     []
# 1                 [D604A8C4-A867-44F3-BE02-FE9E8FEEBC6C]
# 2                 [AD4E87D0-A044-4AD8-8AC1-26C94A362812]
# 3                 [6436C7FD-2BCD-4692-B6DF-0908DA51D4D0]
# 4                 [A1422499-91B5-4D4C-9AA2-D66F3486D728]
# ...                                                  ...
# 38121                                                 []
# 38122             [1b81f7e2-6e24-4b65-88f4-15c4cbf580b1]
# 38123             [46a10715-613b-449b-acba-b01c47fde57f]
# 38124  [CUSTOMER#619241, 31910cb0-818d-42c4-9a82-5100...
# 38125             [0B9E1B86-FBB3-4406-B23E-97D69BE2EC6B]
#
#       Geschaeftspartner_list UID_CHID_check score  \
# 0                         []              0   120
# 1                         []              0    50
# 2                         []              0    50
# 3                         []              1   170
# 4                         []              0    60
# ...                      ...            ...   ...
# 38121                     []              1    80
# 38122                     []              1   170
# 38123                     []              1   170
# 38124                     []              2   810
# 38125                     []              2   450
#
#                                            score_details
# 0                       Servicerole_string 100, Email 20
# 1                                    Verknuepfungsart 50
# 2                                    Verknuepfungsart 50
# 3                 UID 50, Verknuepfungsart 100, Email 20
# 4                   Verknuepfungsart 50, ObjektZeiger 10
# ...                                                  ...
# 38121                  UID 50, ObjektZeiger 10, Email 20
# 38122             UID 50, Verknuepfungsart 100, Email 20
# 38123             UID 50, Verknuepfungsart 100, Email 20
# 38124  Geschaeftsobjekte 180, UID 100, Verknuepfungsa...
# 38125  Geschaeftsobjekte 90, UID 100, Versandart 100,...
#
# [28184 rows x 52 columns]
